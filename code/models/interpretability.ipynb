# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

PATH_PROJECT = '/home/julie/Documents/cours/5A/IAF/defi_IA'
PATH_IMAGE = os.path.join(PATH_PROJECT,'images')
PATH_UTILITIES = os.path.join(PATH_PROJECT,'code/utilities')
os.chdir(PATH_UTILITIES)

import data_loading as DL
import data_preparation_for_models as DP

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor

# %%
data,Y,var_quant,var_quali,var_quali_to_encode = DL.main_load_data()
X_train,X_vali,X_train_renorm,Y_train,X_vali_renorm,Y_vali,X_test_renorm = DP.main_prepare_train_vali_data(data,Y,var_quant,var_quali,var_quali_to_encode)
# Out:
# /home/julie/anaconda3/lib/python3.8/site-packages/category_encoders/target_encoder.py:122: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# /home/julie/anaconda3/lib/python3.8/site-packages/category_encoders/target_encoder.py:127: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."
# /home/julie/Documents/cours/5A/IAF/defi_IA/code/utilities/data_preparation_for_models.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Feature importance

# %%
# linear regression
lr = make_pipeline(StandardScaler(),LinearRegression())
lr.fit(X_train_renorm, Y_train)
y_pred_lr = lr.predict(X_vali_renorm)

# coefficient linear regression
coefs_lr = pd.concat([pd.DataFrame(X_train_renorm.columns,columns=['variables']),pd.DataFrame(abs(lr[1].coef_.T),columns=['coefficients'])],axis=1)
coefs_lr.sort_values(by='coefficients', ascending=False)[:25]
# Out:
#                    variables  coefficients
# 40        group_Boss Western  1.464652e+11
# 42         group_Independant  9.908642e+10
# 3            hotel_id_target  7.333304e+10
# 44            group_Yin Yang  7.286781e+10
# 46        brand_Boss Western  5.621454e+10
# 52      brand_J.Halliday Inn  5.295841e+10
# 58             brand_Safitel  4.768817e+10
# 48             brand_Corlton  4.466222e+10
# 53             brand_Marcure  4.317817e+10
# 54             brand_Morriot  3.954166e+10
# 50                brand_Ibas  3.899906e+10
# 55             brand_Navatel  3.624476e+10
# 49           brand_CourtYord  3.594267e+10
# 41  group_Chillton Worldwide  2.981270e+10
# 56       brand_Quadrupletree  1.847421e+10
# 47    brand_Chill Garden Inn  1.812302e+10
# 59          brand_Tripletree  1.789743e+10
# 51         brand_Independant  1.400050e+10
# 1                  cost_life  7.609267e+09
# 12              city_vilnius  5.030489e+09
# 9                 city_sofia  4.974588e+09
# ...

# %%
print(list(coefs_lr.sort_values(by='coefficients', ascending=False)['variables']))
# Out:
# ['group_Boss Western', 'group_Independant', 'hotel_id_target', 'group_Yin Yang', 'brand_Boss Western', 'brand_J.Halliday Inn', 'brand_Safitel', 'brand_Corlton', 'brand_Marcure', 'brand_Morriot', 'brand_Ibas', 'brand_Navatel', 'brand_CourtYord', 'group_Chillton Worldwide', 'brand_Quadrupletree', 'brand_Chill Garden Inn', 'brand_Tripletree', 'brand_Independant', 'cost_life', 'city_vilnius', 'city_sofia', 'city_madrid', 'city_rome', 'city_valletta', 'city_copenhagen', 'group_Morriott International', 'city_vienna', 'city_paris', 'brand_Royal Lotus', 'brand_Ardisson', 'stock_mod', 'language_slovakian', 'language_hungarian', 'language_bulgarian', 'language_estonian', 'pool_1', 'language_romanian', 'language_czech', 'language_luxembourgish', 'language_german', 'language_italian', 'language_french', 'language_dutch', 'language_belgian', 'language_slovene', 'language_croatian', 'children_policy_2', 'language_maltese', 'language_polish', 'language_spanish', 'language_lithuanian', 'children_pol
# ...

# %% [markdown]
# Les features les plus importantes d'après la regression linéaire sont les groupes Boss_Western et indépendants, ainsi que hotel_id. Viennent ensuite diverses marques et groupes, puis la variable cost_life et les villes.

# %%
features_to_plot = ['group_Boss Western', 'Longitude']
inter1 = pdp.pdp_interact(model=model, dataset=X_train_renorm, model_features=feature_names, features=features_to_plot)

pdp.pdp_interact_plot(pdp_interact_out=inter1, feature_names=features_to_plot, plot_type='contour')
plt.show()
