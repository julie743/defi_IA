# %% [markdown]
# # Notebook défi IA - Préparation des données

# %%
#Librairies 
import itertools
import pandas as pd 
import random
import requests
import numpy as np
import copy
import json

# %%
#Requêtes 
import urllib.parse

domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)

# %% [markdown]
# ## 1 - Labels et valeurs

# %%
# les paramètres du jeu de données : 
request_var = ["language","city","date","mobile"]
city = ["amsterdam","copenhagen","madrid","paris","rome","sofia","valletta","vienna","vilnius"]
date = list(range(0,45))
language = ["austrian", "belgian", "bulgarian", "croatian", "cypriot", "czech", "danish", "dutch", "estonian", "finnish", "french",
"german", "greek", "hungarian", "irish", "italian", "latvian", "lithuanian", "luxembourgish", "maltese", "polish", "portuguese", 
            "romanian", "slovakian", "slovene", "spanish", "swedish"]
mobile = [0,1]

dic_language_country = pd.Series({"amsterdam":"dutch",
                                   "copenhagen":"danish",
                                   "madrid":"spanish",
                                   "paris" : "french",
                                   "rome": "italian",
                                   "sofia": "bulgarian",
                                   "valletta": "maltese",
                                   "vienna" : "austrian",
                                   "vilnius" : "lithuanian"})

dic_similar_language = {"french" : ["belgian"],
                       "belgian" : ["french"], 
                       "german" : ["austrian","luxembourgish"],
                       "austrian" : ["german","luxembourgish"],
                       "luxembourgish" : ["german","austrian"]}

# %% [markdown]
# ## 2 - Paramètres

# %%
# les paramètres des fonctions pour générer les requêtes : 
nb_users = 4100 #3*700 + 2000
max_requetes = 1 
max_jours = 44
threshold_city = 0.02
threshold_language = 0.02

# %% [markdown]
# ## 3 - Création des avatars

# %%
#Création des avatars 
user_id = '82a030f2-958a-4824-8ee0-85cde6f5668c'

for i in range(3100,nb_users) :
    name = "turtles" + str(i)
    r = requests.post(path(f'avatars/{user_id}/{name}'))

# %%
#Vérification création des avatars 
r = requests.get(path(f"avatars/{user_id}"))  
names = []

for avatar in r.json():
    print(avatar['id'], avatar['name'])
    names.append(avatar['name'])
# Out:
# 3530 first_avatar
# 3531 turtles1
# 3532 turtles2
# 4527 turtles0
# 4528 turtles3
# 4529 turtles4
# 4530 turtles5
# 4531 turtles6
# 4532 turtles7
# 4533 turtles8
# 4534 turtles9
# 29408 turtles46
# 29409 turtles47
# 29410 turtles48
# 29411 turtles49
# 29412 turtles50
# 29413 turtles51
# 29414 turtles52
# 29415 turtles53
# 29416 turtles54
# 29417 turtles55
# 29419 turtles56
# 29420 turtles57
# 29421 turtles58
# 29422 turtles59
# 29372 turtles10
# 29373 turtles11
# 29374 turtles12
# 29375 turtles13
# 29376 turtles14
# 29377 turtles15
# 29378 turtles16
# 29379 turtles17
# 29380 turtles18
# 29381 turtles19
# 29382 turtles20
# 29383 turtles21
# 29384 turtles22
# 29385 turtles23
# 29386 turtles24
# 29387 turtles25
# 29388 turtles26
# 29389 turtles27
# 29390 turtles28
# 29391 turtles29
# 29392 turtles30
# 29393 turtles31
# 29394 turtles32
# 29395 turtles33
# 29396 turtles34
# 29397 turtles35
# 29398 turtles36
# 29399 turtles37
# 29400 turtles38
# 29401 turtles39
# 29402 turtles40
# 29403 turtles41
# 29404 turtles42
# 29405 turtles43
# 29406 turtles44
# 29407 turtles45
# 29441 turtles77
# 29442 turtles78
# 29443 turtles79
# 29444 turtles80
# 29445 turtles81
# 29446 turtles82
# 29447 turtles83
# 29448 turtles84
# 29449 turtles85
# 29450 turtles86
# 29451 turtles87
# 29452 turtles88
# 29453 turtles89
# 29454 turtles90
# 29423 turtles60
# 29424 turtles61
# 29425 turtles62
# 29426 turtles63
# 29427 turtles64
# 29428 turtles65
# 29429 turtles66
# 29431 turtles67
# 29432 turtles68
# 29433 turtles69
# 29434 turtles70
# 29435 turtles71
# 29436 turtles72
# 29437 turtles73
# 29438 turtles74
# 29439 turtles75
# 29440 turtles76
# 29456 turtles92
# 29457 turtles93
# 29458 turtles94
# 29459 turtles95
# 29460 turtles96
# 29461 turtles97
# 29475 turtles111
# 29476 turtles112
# 29477 turtles113
# 29478 turtles114
# 29479 turtles115
# 29480 turtles116
# 29487 turtles123
# 29488 turtles124
# 29489 turtles125
# 29490 turtles126
# 29491 turtles127
# 29492 turtles128
# 29493 turtles129
# 29515 turtles151
# 29516 turtles152
# 29517 turtles153
# 29518 turtles154
# 29519 turtles155
# 29520 turtles156
# 29521 turtles157
# 29522 turtles158
# 29523 turtles159
# 29524 turtles160
# 29525 turtles161
# 29526 turtles162
# 29527 turtles163
# 29528 turtles164
# 29529 turtles165
# 29531 turtles166
# 29532 turtles167
# 29533 turtles168
# 29545 turtles180
# 29546 turtles181
# 29547 turtles182
# 29557 turtles192
# 29558 turtles193
# 29559 turtles194
# 29560 turtles195
# 29561 turtles196
# 29562 turtles197
# 29563 turtles198
# 29564 turtles199
# 29572 turtles207
# 29574 turtles209
# 29575 turtles210
# 29576 turtles211
# 29577 turtles212
# 29578 turtles213
# 29579 turtles214
# 29580 turtles215
# 29581 turtles216
# 29582 turtles217
# 29583 turtles218
# 29584 turtles219
# 29585 turtles220
# 29586 turtles221
# 29588 turtles223
# 29597 turtles232
# 29598 turtles233
# 29600 turtles235
# 29601 turtles236
# 29604 turtles239
# 29605 turtles240
# 29606 turtles241
# 29607 turtles242
# 29608 turtles243
# 29609 turtles244
# 29610 turtles245
# 29611 turtles246
# 29612 turtles247
# 29639 turtles273
# 29640 turtles274
# 29641 turtles275
# 29642 turtles276
# 29643 turtles277
# 29644 turtles278
# 29645 turtles279
# 29646 turtles280
# 29647 turtles281
# 29648 turtles282
# 29649 turtles283
# 29650 turtles284
# 29651 turtles285
# 29652 turtles286
# 29653 turtles287
# 29654 turtles288
# 29655 turtles289
# 29656 turtles290
# 29657 turtles291
# 29662 turtles296
# 29664 turtles298
# 29665 turtles299
# 29666 turtles300
# 29671 turtles305
# 29672 turtles306
# 29455 turtles91
# 29462 turtles98
# 29463 turtles99
# 29464 turtles100
# 29465 turtles101
# 29466 turtles102
# 29467 turtles103
# 29468 turtles104
# 29469 turtles105
# 29470 turtles106
# 29471 turtles107
# 29472 turtles108
# 29473 turtles109
# 29474 turtles110
# 29481 turtles117
# 29482 turtles118
# 29483 turtles119
# 29484 turtles120
# 29485 turtles121
# 29486 turtles122
# 29494 turtles130
# 29495 turtles131
# 29496 turtles132
# 29497 turtles133
# 29498 turtles134
# 29499 turtles135
# 29500 turtles136
# 29501 turtles137
# 29502 turtles138
# 29503 turtles139
# 29504 turtles140
# 29505 turtles141
# 29506 turtles142
# 29507 turtles143
# 29508 turtles144
# 29509 turtles145
# 29510 turtles146
# 29511 turtles147
# 29512 turtles148
# 29513 turtles149
# 29514 turtles150
# 29534 turtles169
# 29535 turtles170
# 29536 turtles171
# 29537 turtles172
# 29538 turtles173
# 29539 turtles174
# 29540 turtles175
# 29541 turtles176
# 29542 turtles177
# 29543 turtles178
# 29544 turtles179
# 29548 turtles183
# 29549 turtles184
# 29550 turtles185
# 29551 turtles186
# 29552 turtles187
# 29553 turtles188
# 29554 turtles189
# 29555 turtles190
# 29556 turtles191
# 29565 turtles200
# 29566 turtles201
# 29567 turtles202
# 29568 turtles203
# 29569 turtles204
# 29570 turtles205
# 29571 turtles206
# 29573 turtles208
# 29587 turtles222
# 29589 turtles224
# 29590 turtles225
# 29591 turtles226
# 29592 turtles227
# 29593 turtles228
# 29594 turtles229
# 29595 turtles230
# 29596 turtles231
# 29599 turtles234
# 29602 turtles237
# 29603 turtles238
# 29613 turtles248
# 29614 turtles249
# 29615 turtles250
# 29616 turtles251
# 29617 turtles252
# 29618 turtles253
# 29619 turtles254
# 29620 turtles255
# 29621 turtles256
# 29622 turtles257
# 29623 turtles258
# 29624 turtles259
# 29625 turtles260
# 29626 turtles261
# 29627 turtles262
# 29628 turtles263
# 29629 turtles264
# 29630 turtles265
# 29631 turtles266
# 29632 turtles267
# 29633 turtles268
# 29634 turtles269
# 29635 turtles270
# 29637 turtles271
# 29638 turtles272
# 29658 turtles292
# 29659 turtles293
# 29660 turtles294
# 29661 turtles295
# 29663 turtles297
# 29667 turtles301
# 29668 turtles302
# 29669 turtles303
# 29670 turtles304
# 29699 turtles333
# 29700 turtles334
# 29701 turtles335
# 29702 turtles336
# 29673 turtles307
# 29674 turtles308
# 29675 turtles309
# 29676 turtles310
# 29677 turtles311
# 29678 turtles312
# 29679 turtles313
# 29680 turtles314
# 29681 turtles315
# 29682 turtles316
# 29683 turtles317
# 29684 turtles318
# 29685 turtles319
# 29686 turtles320
# 29687 turtles321
# 29688 turtles322
# 29689 turtles323
# 29690 turtles324
# 29691 turtles325
# 29692 turtles326
# 29693 turtles327
# 29694 turtles328
# 29695 turtles329
# 29696 turtles330
# 29697 turtles331
# 29698 turtles332
# 29704 turtles338
# 29705 turtles339
# 29706 turtles340
# 29707 turtles341
# 29708 turtles342
# 29709 turtles343
# 29711 turtles345
# 29712 turtles346
# 29713 turtles347
# 29714 turtles348
# 29715 turtles349
# 29716 turtles350
# 29717 turtles351
# 29718 turtles352
# 29719 turtles353
# 29720 turtles354
# 29721 turtles355
# 29722 turtles356
# 29723 turtles357
# 29726 turtles360
# 29727 turtles361
# 29728 turtles362
# 29729 turtles363
# 29732 turtles366
# 29745 turtles379
# 29746 turtles380
# 29747 turtles381
# 29749 turtles382
# 29750 turtles383
# 29751 turtles384
# 29752 turtles385
# 29753 turtles386
# 29754 turtles387
# 29755 turtles388
# 29756 turtles389
# 29757 turtles390
# 29758 turtles391
# 29759 turtles392
# 29760 turtles393
# 29768 turtles401
# 29770 turtles403
# 29771 turtles404
# 29772 turtles405
# 29773 turtles406
# 29774 turtles407
# 29776 turtles409
# 29784 turtles417
# 29800 turtles433
# 29801 turtles434
# 29802 turtles435
# 29805 turtles438
# 29806 turtles439
# 29808 turtles441
# 29812 turtles445
# 29822 turtles455
# 29826 turtles459
# 29827 turtles460
# 29833 turtles466
# 29834 turtles467
# 29839 turtles472
# 29840 turtles473
# 29843 turtles476
# 29844 turtles477
# 29847 turtles480
# 29850 turtles483
# 29851 turtles484
# 29858 turtles490
# 29861 turtles493
# 29863 turtles495
# 29864 turtles496
# 29868 turtles500
# 29870 turtles502
# 29873 turtles505
# 29879 turtles511
# 29880 turtles512
# 29882 turtles514
# 29883 turtles515
# 29884 turtles516
# 29885 turtles517
# 29888 turtles520
# 29893 turtles525
# 29897 turtles529
# 29902 turtles534
# 29903 turtles535
# 29906 turtles538
# 29907 turtles539
# 29912 turtles544
# 29916 turtles548
# 29920 turtles552
# 29924 turtles556
# 29925 turtles557
# 29926 turtles558
# 29930 turtles562
# 29703 turtles337
# 29710 turtles344
# 29724 turtles358
# 29725 turtles359
# 29730 turtles364
# 29731 turtles365
# 29733 turtles367
# 29734 turtles368
# 29735 turtles369
# 29736 turtles370
# 29737 turtles371
# 29738 turtles372
# 29739 turtles373
# 29740 turtles374
# 29741 turtles375
# 29742 turtles376
# 29743 turtles377
# 29744 turtles378
# 29761 turtles394
# 29762 turtles395
# 29763 turtles396
# 29764 turtles397
# 29765 turtles398
# 29766 turtles399
# 29767 turtles400
# 29769 turtles402
# 29775 turtles408
# 29777 turtles410
# 29778 turtles411
# 29779 turtles412
# 29780 turtles413
# 29781 turtles414
# 29782 turtles415
# 29783 turtles416
# 29785 turtles418
# 29786 turtles419
# 29787 turtles420
# 29788 turtles421
# 29789 turtles422
# 29790 turtles423
# 29791 turtles424
# 29792 turtles425
# 29793 turtles426
# 29794 turtles427
# 29795 turtles428
# 29796 turtles429
# 29797 turtles430
# 29798 turtles431
# 29799 turtles432
# 29803 turtles436
# 29804 turtles437
# 29807 turtles440
# 29809 turtles442
# 29810 turtles443
# 29811 turtles444
# 29813 turtles446
# 29814 turtles447
# 29815 turtles448
# 29816 turtles449
# 29817 turtles450
# 29818 turtles451
# 29819 turtles452
# 29820 turtles453
# 29821 turtles454
# 29823 turtles456
# 29824 turtles457
# 29825 turtles458
# 29828 turtles461
# 29829 turtles462
# 29830 turtles463
# 29831 turtles464
# 29832 turtles465
# 29835 turtles468
# 29836 turtles469
# 29837 turtles470
# 29838 turtles471
# 29841 turtles474
# 29842 turtles475
# 29845 turtles478
# 29846 turtles479
# 29848 turtles481
# 29849 turtles482
# 29852 turtles485
# 29853 turtles486
# 29854 turtles487
# 29855 turtles488
# 29856 turtles489
# 29859 turtles491
# 29860 turtles492
# 29862 turtles494
# 29865 turtles497
# 29866 turtles498
# 29867 turtles499
# 29869 turtles501
# 29871 turtles503
# 29872 turtles504
# 29874 turtles506
# 29875 turtles507
# 29876 turtles508
# 29877 turtles509
# 29878 turtles510
# 29881 turtles513
# 29886 turtles518
# 29887 turtles519
# 29889 turtles521
# 29890 turtles522
# 29891 turtles523
# 29892 turtles524
# 29894 turtles526
# 29895 turtles527
# 29896 turtles528
# 29898 turtles530
# 29899 turtles531
# 29900 turtles532
# 29901 turtles533
# 29904 turtles536
# 29905 turtles537
# 29908 turtles540
# 29909 turtles541
# 29910 turtles542
# 29913 turtles545
# 29914 turtles546
# 29917 turtles549
# 29918 turtles550
# 29921 turtles553
# 29922 turtles554
# 29927 turtles559
# 29931 turtles563
# 29936 turtles568
# 29937 turtles569
# 29940 turtles572
# 29942 turtles574
# 29946 turtles578
# 29950 turtles582
# 29954 turtles586
# 29956 turtles588
# 29960 turtles592
# 29964 turtles596
# 29968 turtles600
# 29973 turtles605
# 29974 turtles606
# 29977 turtles609
# 29978 turtles610
# 29981 turtles613
# 29982 turtles614
# 29985 turtles617
# 29986 turtles618
# 29990 turtles622
# 29994 turtles626
# 29999 turtles631
# 30001 turtles633
# 30005 turtles637
# 30009 turtles641
# 30014 turtles646
# 30015 turtles647
# 30018 turtles650
# 30019 turtles651
# 30025 turtles657
# 30026 turtles658
# 30029 turtles661
# 30030 turtles662
# 30033 turtles665
# 30034 turtles666
# 30037 turtles669
# 30038 turtles670
# 30044 turtles676
# 30045 turtles677
# 30048 turtles680
# 30049 turtles681
# 30052 turtles684
# 30053 turtles685
# 30056 turtles688
# 30058 turtles690
# 30062 turtles694
# 30066 turtles698
# 29911 turtles543
# 29915 turtles547
# 29919 turtles551
# 29923 turtles555
# 29928 turtles560
# 29929 turtles561
# 29932 turtles564
# 29933 turtles565
# 29938 turtles570
# 29941 turtles573
# 29945 turtles577
# 29949 turtles581
# 29953 turtles585
# 29955 turtles587
# 29958 turtles590
# 29959 turtles591
# 29962 turtles594
# 29963 turtles595
# 29966 turtles598
# 29967 turtles599
# 29972 turtles604
# 29976 turtles608
# 29980 turtles612
# 29983 turtles615
# 29988 turtles620
# 29989 turtles621
# 29992 turtles624
# 29993 turtles625
# 29998 turtles630
# 30002 turtles634
# 30006 turtles638
# 30010 turtles642
# 30012 turtles644
# 30016 turtles648
# 30020 turtles652
# 30022 turtles654
# 30024 turtles656
# 30028 turtles660
# 30032 turtles664
# 30036 turtles668
# 30040 turtles672
# 30042 turtles674
# 30046 turtles678
# 30050 turtles682
# 30055 turtles687
# 30059 turtles691
# 30060 turtles692
# 30063 turtles695
# 30064 turtles696
# 30067 turtles699
# 29934 turtles566
# 29935 turtles567
# 29939 turtles571
# 29943 turtles575
# 29944 turtles576
# 29947 turtles579
# 29948 turtles580
# 29951 turtles583
# 29952 turtles584
# 29957 turtles589
# 29961 turtles593
# 29965 turtles597
# 29969 turtles601
# 29970 turtles602
# 29971 turtles603
# 29975 turtles607
# 29979 turtles611
# 29984 turtles616
# 29987 turtles619
# 29991 turtles623
# 29995 turtles627
# 29996 turtles628
# 29997 turtles629
# 30000 turtles632
# 30003 turtles635
# 30004 turtles636
# 30007 turtles639
# 30008 turtles640
# 30011 turtles643
# 30013 turtles645
# 30017 turtles649
# 30021 turtles653
# 30023 turtles655
# 30027 turtles659
# 30031 turtles663
# 30035 turtles667
# 30039 turtles671
# 30041 turtles673
# 30043 turtles675
# 30047 turtles679
# 30051 turtles683
# 30054 turtles686
# 30057 turtles689
# 30061 turtles693
# 30065 turtles697
# 68466 turtles700
# 68467 turtles701
# 68468 turtles702
# 68469 turtles703
# 68470 turtles704
# 68471 turtles705
# 68472 turtles706
# 68473 turtles707
# 68474 turtles708
# 68475 turtles709
# 68476 turtles710
# 68477 turtles711
# 68478 turtles712
# 68479 turtles713
# 68480 turtles714
# 68481 turtles715
# 68482 turtles716
# 68483 turtles717
# 68484 turtles718
# 68485 turtles719
# 68486 turtles720
# 68487 turtles721
# 68488 turtles722
# 68489 turtles723
# 68490 turtles724
# 68491 turtles725
# 68492 turtles726
# 68493 turtles727
# 68494 turtles728
# 68495 turtles729
# 68496 turtles730
# 68497 turtles731
# 68498 turtles732
# 68499 turtles733
# 68500 turtles734
# 68501 turtles735
# 68502 turtles736
# 68503 turtles737
# 68504 turtles738
# 68505 turtles739
# 68506 turtles740
# 68507 turtles741
# 68508 turtles742
# 68509 turtles743
# 68510 turtles744
# 68511 turtles745
# 68512 turtles746
# 68513 turtles747
# 68514 turtles748
# 68515 turtles749
# 68516 turtles750
# 68517 turtles751
# 68518 turtles752
# 68519 turtles753
# 68520 turtles754
# 68521 turtles755
# 68522 turtles756
# 68523 turtles757
# 68524 turtles758
# 68525 turtles759
# 68526 turtles760
# 68527 turtles761
# 68528 turtles762
# 68529 turtles763
# 68530 turtles764
# 68531 turtles765
# 68532 turtles766
# 68533 turtles767
# 68534 turtles768
# 68535 turtles769
# 68536 turtles770
# 68537 turtles771
# 68538 turtles772
# 68539 turtles773
# 68540 turtles774
# 68541 turtles775
# 68542 turtles776
# 68543 turtles777
# 68544 turtles778
# 68545 turtles779
# 68546 turtles780
# 68547 turtles781
# 68548 turtles782
# 68549 turtles783
# 68550 turtles784
# 68551 turtles785
# 68552 turtles786
# 68553 turtles787
# 68554 turtles788
# 68555 turtles789
# 68556 turtles790
# 68557 turtles791
# 68558 turtles792
# 68559 turtles793
# 68560 turtles794
# 68561 turtles795
# 68562 turtles796
# 68563 turtles797
# 68564 turtles798
# 68565 turtles799
# 68566 turtles800
# 68567 turtles801
# 68568 turtles802
# 68569 turtles803
# 68570 turtles804
# 68571 turtles805
# 68572 turtles806
# 68573 turtles807
# 68574 turtles808
# 68575 turtles809
# 68576 turtles810
# 68577 turtles811
# 68578 turtles812
# 68579 turtles813
# 68580 turtles814
# 68581 turtles815
# 68582 turtles816
# 68583 turtles817
# 68584 turtles818
# 68585 turtles819
# 68586 turtles820
# 68587 turtles821
# 68588 turtles822
# 68589 turtles823
# 68590 turtles824
# 68591 turtles825
# 68592 turtles826
# 68593 turtles827
# 68594 turtles828
# 68595 turtles829
# 68596 turtles830
# 68597 turtles831
# 68598 turtles832
# 68599 turtles833
# 68600 turtles834
# 68601 turtles835
# 68602 turtles836
# 68603 turtles837
# 68604 turtles838
# 68605 turtles839
# 68606 turtles840
# 68607 turtles841
# 68608 turtles842
# 68609 turtles843
# 68610 turtles844
# 68611 turtles845
# 68612 turtles846
# 68613 turtles847
# 68614 turtles848
# 68615 turtles849
# 68616 turtles850
# 68617 turtles851
# 68618 turtles852
# 68619 turtles853
# 68620 turtles854
# 68621 turtles855
# 68622 turtles856
# 68623 turtles857
# 68624 turtles858
# 68625 turtles859
# 68626 turtles860
# 68627 turtles861
# 68628 turtles862
# 68629 turtles863
# 68630 turtles864
# 68631 turtles865
# 68632 turtles866
# 68633 turtles867
# 68634 turtles868
# 68635 turtles869
# 68636 turtles870
# 68637 turtles871
# 68638 turtles872
# 68639 turtles873
# 68640 turtles874
# 68641 turtles875
# 68642 turtles876
# 68643 turtles877
# 68644 turtles878
# 68645 turtles879
# 68646 turtles880
# 68647 turtles881
# 68648 turtles882
# 68649 turtles883
# 68650 turtles884
# 68651 turtles885
# 68652 turtles886
# 68653 turtles887
# 68654 turtles888
# 68655 turtles889
# 68656 turtles890
# 68657 turtles891
# 68658 turtles892
# 68659 turtles893
# 68660 turtles894
# 68661 turtles895
# 68662 turtles896
# 68663 turtles897
# 68664 turtles898
# 68665 turtles899
# 68666 turtles900
# 68667 turtles901
# 68668 turtles902
# 68669 turtles903
# 68670 turtles904
# 68671 turtles905
# 68672 turtles906
# 68673 turtles907
# 68674 turtles908
# 68675 turtles909
# 68676 turtles910
# 68677 turtles911
# 68678 turtles912
# 68679 turtles913
# 68680 turtles914
# 68681 turtles915
# 68682 turtles916
# 68683 turtles917
# 68684 turtles918
# 68685 turtles919
# 68686 turtles920
# 68687 turtles921
# 68688 turtles922
# 68689 turtles923
# 68690 turtles924
# 68691 turtles925
# 68692 turtles926
# 68693 turtles927
# 68694 turtles928
# 68695 turtles929
# 68696 turtles930
# 68697 turtles931
# 68698 turtles932
# 68699 turtles933
# 68700 turtles934
# 68701 turtles935
# 68702 turtles936
# 68703 turtles937
# 68704 turtles938
# 68705 turtles939
# 68706 turtles940
# 68707 turtles941
# 68708 turtles942
# 68709 turtles943
# 68710 turtles944
# 68711 turtles945
# 68712 turtles946
# 68713 turtles947
# 68714 turtles948
# 68715 turtles949
# 68716 turtles950
# 68717 turtles951
# 68718 turtles952
# 68719 turtles953
# 68720 turtles954
# 68721 turtles955
# 68722 turtles956
# 68723 turtles957
# 68724 turtles958
# 68725 turtles959
# 68726 turtles960
# 68727 turtles961
# 68728 turtles962
# 68729 turtles963
# 68730 turtles964
# 68731 turtles965
# 68732 turtles966
# 68733 turtles967
# 68734 turtles968
# 68735 turtles969
# 68736 turtles970
# 68737 turtles971
# 68738 turtles972
# 68739 turtles973
# 68740 turtles974
# 68741 turtles975
# 68742 turtles976
# 68743 turtles977
# 68744 turtles978
# 68745 turtles979
# 68746 turtles980
# 68747 turtles981
# 68748 turtles982
# 68749 turtles983
# 68750 turtles984
# 68751 turtles985
# 68752 turtles986
# 68753 turtles987
# 68754 turtles988
# 68755 turtles989
# 68756 turtles990
# 68757 turtles991
# 68758 turtles992
# 68759 turtles993
# 68760 turtles994
# 68761 turtles995
# 68762 turtles996
# 68763 turtles997
# 68764 turtles998
# 68765 turtles999
# 68766 turtles1000
# 68767 turtles1001
# 68768 turtles1002
# 68769 turtles1003
# 68770 turtles1004
# 68771 turtles1005
# 68772 turtles1006
# 68773 turtles1007
# 68774 turtles1008
# 68775 turtles1009
# 68776 turtles1010
# 68777 turtles1011
# 68778 turtles1012
# 68779 turtles1013
# 68780 turtles1014
# 68781 turtles1015
# 68782 turtles1016
# 68783 turtles1017
# 68784 turtles1018
# 68785 turtles1019
# 68786 turtles1020
# 68787 turtles1021
# 68788 turtles1022
# 68789 turtles1023
# 68790 turtles1024
# 68791 turtles1025
# 68792 turtles1026
# 68793 turtles1027
# 68794 turtles1028
# 68795 turtles1029
# 68796 turtles1030
# 68797 turtles1031
# 68798 turtles1032
# 68799 turtles1033
# 68800 turtles1034
# 68801 turtles1035
# 68802 turtles1036
# 68803 turtles1037
# 68804 turtles1038
# 68805 turtles1039
# 68806 turtles1040
# 68807 turtles1041
# 68808 turtles1042
# 68809 turtles1043
# 68810 turtles1044
# 68811 turtles1045
# 68812 turtles1046
# 68813 turtles1047
# 68814 turtles1048
# 68815 turtles1049
# 68816 turtles1050
# 68817 turtles1051
# 68818 turtles1052
# 68819 turtles1053
# 68820 turtles1054
# 68821 turtles1055
# 68822 turtles1056
# 68823 turtles1057
# 68824 turtles1058
# 68825 turtles1059
# 68826 turtles1060
# 68827 turtles1061
# 68828 turtles1062
# 68829 turtles1063
# 68830 turtles1064
# 68831 turtles1065
# 68832 turtles1066
# 68833 turtles1067
# 68834 turtles1068
# 68835 turtles1069
# 68836 turtles1070
# 68837 turtles1071
# 68838 turtles1072
# 68839 turtles1073
# 68840 turtles1074
# 68841 turtles1075
# 68842 turtles1076
# 68843 turtles1077
# 68844 turtles1078
# 68845 turtles1079
# 68846 turtles1080
# 68847 turtles1081
# 68848 turtles1082
# 68849 turtles1083
# 68850 turtles1084
# 68851 turtles1085
# 68852 turtles1086
# 68853 turtles1087
# 68854 turtles1088
# 68855 turtles1089
# 68856 turtles1090
# 68857 turtles1091
# 68858 turtles1092
# 68859 turtles1093
# 68860 turtles1094
# 68861 turtles1095
# 68862 turtles1096
# 68863 turtles1097
# 68864 turtles1098
# 68865 turtles1099
# 68866 turtles1100
# 68867 turtles1101
# 68868 turtles1102
# 68869 turtles1103
# 68870 turtles1104
# 68871 turtles1105
# 68872 turtles1106
# 68873 turtles1107
# 68874 turtles1108
# 68875 turtles1109
# 68876 turtles1110
# 68877 turtles1111
# 68878 turtles1112
# 68879 turtles1113
# 68880 turtles1114
# 68881 turtles1115
# 68882 turtles1116
# 68883 turtles1117
# 68884 turtles1118
# 68885 turtles1119
# 68886 turtles1120
# 68887 turtles1121
# 68888 turtles1122
# 68889 turtles1123
# 68890 turtles1124
# 68891 turtles1125
# 68892 turtles1126
# 68893 turtles1127
# 68894 turtles1128
# 68895 turtles1129
# 68896 turtles1130
# 68897 turtles1131
# 68898 turtles1132
# 68899 turtles1133
# 68900 turtles1134
# 68901 turtles1135
# 68902 turtles1136
# 68903 turtles1137
# 68904 turtles1138
# 68905 turtles1139
# 68906 turtles1140
# 68907 turtles1141
# 68908 turtles1142
# 68909 turtles1143
# 68910 turtles1144
# 68911 turtles1145
# 68912 turtles1146
# 68913 turtles1147
# 68914 turtles1148
# 68915 turtles1149
# 68916 turtles1150
# 68917 turtles1151
# 68918 turtles1152
# 68919 turtles1153
# 68920 turtles1154
# 68921 turtles1155
# 68922 turtles1156
# 68923 turtles1157
# 68924 turtles1158
# 68925 turtles1159
# 68926 turtles1160
# 68927 turtles1161
# 68928 turtles1162
# 68929 turtles1163
# 68930 turtles1164
# 68931 turtles1165
# 68932 turtles1166
# 68933 turtles1167
# 68934 turtles1168
# 68935 turtles1169
# 68936 turtles1170
# 68937 turtles1171
# 68938 turtles1172
# 68939 turtles1173
# 68940 turtles1174
# 68941 turtles1175
# 68942 turtles1176
# 68943 turtles1177
# 68944 turtles1178
# 68945 turtles1179
# 68946 turtles1180
# 68947 turtles1181
# 68948 turtles1182
# 68949 turtles1183
# 68950 turtles1184
# 68951 turtles1185
# 68952 turtles1186
# 68953 turtles1187
# 68954 turtles1188
# 68955 turtles1189
# 68956 turtles1190
# 68957 turtles1191
# 68958 turtles1192
# 68959 turtles1193
# 68960 turtles1194
# 68961 turtles1195
# 68962 turtles1196
# 68963 turtles1197
# 68964 turtles1198
# 68965 turtles1199
# 68966 turtles1200
# 68967 turtles1201
# 68968 turtles1202
# 68969 turtles1203
# 68970 turtles1204
# 68971 turtles1205
# 68972 turtles1206
# 68973 turtles1207
# 68974 turtles1208
# 68975 turtles1209
# 68976 turtles1210
# 68977 turtles1211
# 68978 turtles1212
# 68979 turtles1213
# 68980 turtles1214
# 68981 turtles1215
# 68982 turtles1216
# 68983 turtles1217
# 68984 turtles1218
# 68985 turtles1219
# 68986 turtles1220
# 68987 turtles1221
# 68988 turtles1222
# 68989 turtles1223
# 68990 turtles1224
# 68991 turtles1225
# 68992 turtles1226
# 68993 turtles1227
# 68994 turtles1228
# 68995 turtles1229
# 68996 turtles1230
# 68997 turtles1231
# 68998 turtles1232
# 68999 turtles1233
# 69000 turtles1234
# 69001 turtles1235
# 69002 turtles1236
# 69003 turtles1237
# 69004 turtles1238
# 69005 turtles1239
# 69006 turtles1240
# 69007 turtles1241
# 69008 turtles1242
# 69009 turtles1243
# 69010 turtles1244
# 69011 turtles1245
# 69012 turtles1246
# 69013 turtles1247
# 69014 turtles1248
# 69015 turtles1249
# 69016 turtles1250
# 69017 turtles1251
# 69018 turtles1252
# 69019 turtles1253
# 69020 turtles1254
# 69021 turtles1255
# 69022 turtles1256
# 69023 turtles1257
# 69024 turtles1258
# 69025 turtles1259
# 69026 turtles1260
# 69027 turtles1261
# 69028 turtles1262
# 69029 turtles1263
# 69030 turtles1264
# 69031 turtles1265
# 69032 turtles1266
# 69033 turtles1267
# 69034 turtles1268
# 69035 turtles1269
# 69036 turtles1270
# 69037 turtles1271
# 69038 turtles1272
# 69039 turtles1273
# 69040 turtles1274
# 69041 turtles1275
# 69042 turtles1276
# 69043 turtles1277
# 69044 turtles1278
# 69045 turtles1279
# 69046 turtles1280
# 69047 turtles1281
# 69048 turtles1282
# 69049 turtles1283
# 69050 turtles1284
# 69051 turtles1285
# 69052 turtles1286
# 69053 turtles1287
# 69054 turtles1288
# 69055 turtles1289
# 69056 turtles1290
# 69057 turtles1291
# 69058 turtles1292
# 69059 turtles1293
# 69060 turtles1294
# 69061 turtles1295
# 69062 turtles1296
# 69063 turtles1297
# 69064 turtles1298
# 69065 turtles1299
# 69066 turtles1300
# 69067 turtles1301
# 69068 turtles1302
# 69069 turtles1303
# 69070 turtles1304
# 69071 turtles1305
# 69072 turtles1306
# 69073 turtles1307
# 69074 turtles1308
# 69075 turtles1309
# 69076 turtles1310
# 69077 turtles1311
# 69078 turtles1312
# 69079 turtles1313
# 69080 turtles1314
# 69081 turtles1315
# 69082 turtles1316
# 69083 turtles1317
# 69084 turtles1318
# 69085 turtles1319
# 69086 turtles1320
# 69087 turtles1321
# 69088 turtles1322
# 69089 turtles1323
# 69090 turtles1324
# 69091 turtles1325
# 69092 turtles1326
# 69093 turtles1327
# 69094 turtles1328
# 69095 turtles1329
# 69096 turtles1330
# 69097 turtles1331
# 69098 turtles1332
# 69099 turtles1333
# 69100 turtles1334
# 69101 turtles1335
# 69102 turtles1336
# 69103 turtles1337
# 69104 turtles1338
# 69105 turtles1339
# 69106 turtles1340
# 69107 turtles1341
# 69108 turtles1342
# 69109 turtles1343
# 69110 turtles1344
# 69111 turtles1345
# 69112 turtles1346
# 69113 turtles1347
# 69114 turtles1348
# 69115 turtles1349
# 69116 turtles1350
# 69117 turtles1351
# 69118 turtles1352
# 69119 turtles1353
# 69120 turtles1354
# 69121 turtles1355
# 69122 turtles1356
# 69123 turtles1357
# 69124 turtles1358
# 69125 turtles1359
# 69126 turtles1360
# 69127 turtles1361
# 69128 turtles1362
# 69129 turtles1363
# 69130 turtles1364
# 69131 turtles1365
# 69132 turtles1366
# 69133 turtles1367
# 69134 turtles1368
# 69135 turtles1369
# 69136 turtles1370
# 69137 turtles1371
# 69138 turtles1372
# 69139 turtles1373
# 69140 turtles1374
# 69141 turtles1375
# 69142 turtles1376
# 69143 turtles1377
# 69144 turtles1378
# 69145 turtles1379
# 69146 turtles1380
# 69147 turtles1381
# 69148 turtles1382
# 69149 turtles1383
# 69150 turtles1384
# 69151 turtles1385
# 69152 turtles1386
# 69153 turtles1387
# 69154 turtles1388
# 69155 turtles1389
# 69156 turtles1390
# 69157 turtles1391
# 69158 turtles1392
# 69159 turtles1393
# 69160 turtles1394
# 69161 turtles1395
# 69162 turtles1396
# 69163 turtles1397
# 69164 turtles1398
# 69165 turtles1399
# 112120 turtles1400
# 112123 turtles1403
# 112126 turtles1406
# 112129 turtles1409
# 112132 turtles1412
# 112135 turtles1415
# 112138 turtles1418
# 112141 turtles1421
# 112144 turtles1424
# 112147 turtles1427
# 112150 turtles1430
# 112153 turtles1433
# 112156 turtles1436
# 112159 turtles1439
# 112162 turtles1442
# 112165 turtles1445
# 112168 turtles1448
# 112171 turtles1451
# 112174 turtles1454
# 112177 turtles1457
# 112180 turtles1460
# 112183 turtles1463
# 112186 turtles1466
# 112189 turtles1469
# 112192 turtles1472
# 112195 turtles1475
# 112198 turtles1478
# 112201 turtles1481
# 112204 turtles1484
# 112207 turtles1487
# 112210 turtles1490
# 112213 turtles1493
# 112216 turtles1496
# 112219 turtles1499
# 112222 turtles1502
# 112225 turtles1505
# 112228 turtles1508
# 112231 turtles1511
# 112121 turtles1401
# 112124 turtles1404
# 112127 turtles1407
# 112130 turtles1410
# 112133 turtles1413
# 112136 turtles1416
# 112139 turtles1419
# 112142 turtles1422
# 112145 turtles1425
# 112148 turtles1428
# 112151 turtles1431
# 112154 turtles1434
# 112157 turtles1437
# 112160 turtles1440
# 112163 turtles1443
# 112166 turtles1446
# 112169 turtles1449
# 112172 turtles1452
# 112175 turtles1455
# 112178 turtles1458
# 112181 turtles1461
# 112184 turtles1464
# 112187 turtles1467
# 112190 turtles1470
# 112193 turtles1473
# 112196 turtles1476
# 112199 turtles1479
# 112202 turtles1482
# 112205 turtles1485
# 112208 turtles1488
# 112211 turtles1491
# 112214 turtles1494
# 112217 turtles1497
# 112220 turtles1500
# 112223 turtles1503
# 112226 turtles1506
# 112229 turtles1509
# 112232 turtles1512
# 112235 turtles1515
# 112238 turtles1518
# 112241 turtles1521
# 112244 turtles1524
# 112247 turtles1527
# 112250 turtles1530
# 112253 turtles1533
# 112256 turtles1536
# 112259 turtles1539
# 112262 turtles1542
# 112265 turtles1545
# 112268 turtles1548
# 112271 turtles1551
# 112274 turtles1554
# 112277 turtles1557
# 112280 turtles1560
# 112283 turtles1563
# 112286 turtles1566
# 112289 turtles1569
# 112292 turtles1572
# 112295 turtles1575
# 112298 turtles1578
# 112301 turtles1581
# 112304 turtles1584
# 112307 turtles1587
# 112310 turtles1590
# 112313 turtles1593
# 112316 turtles1596
# 112319 turtles1599
# 112322 turtles1602
# 112325 turtles1605
# 112328 turtles1608
# 112331 turtles1611
# 112334 turtles1614
# 112337 turtles1617
# 112340 turtles1620
# 112343 turtles1623
# 112346 turtles1626
# 112349 turtles1629
# 112352 turtles1632
# 112355 turtles1635
# 112358 turtles1638
# 112361 turtles1641
# 112364 turtles1644
# 112367 turtles1647
# 112370 turtles1650
# 112375 turtles1655
# 112378 turtles1658
# 112381 turtles1661
# 112384 turtles1664
# 112387 turtles1667
# 112390 turtles1670
# 112393 turtles1673
# 112396 turtles1676
# 112399 turtles1679
# 112402 turtles1682
# 112405 turtles1685
# 112408 turtles1688
# 112411 turtles1691
# 112414 turtles1694
# 112417 turtles1697
# 112420 turtles1700
# 112423 turtles1703
# 112426 turtles1706
# 112429 turtles1709
# 112432 turtles1712
# 112435 turtles1715
# 112438 turtles1718
# 112441 turtles1721
# 112444 turtles1724
# 112447 turtles1727
# 112450 turtles1730
# 112453 turtles1733
# 112456 turtles1736
# 112459 turtles1739
# 112462 turtles1742
# 112465 turtles1745
# 112468 turtles1748
# 112234 turtles1514
# 112237 turtles1517
# 112240 turtles1520
# 112243 turtles1523
# 112246 turtles1526
# 112122 turtles1402
# 112125 turtles1405
# 112128 turtles1408
# 112131 turtles1411
# 112134 turtles1414
# 112137 turtles1417
# 112140 turtles1420
# 112143 turtles1423
# 112146 turtles1426
# 112149 turtles1429
# 112152 turtles1432
# 112155 turtles1435
# 112158 turtles1438
# 112161 turtles1441
# 112164 turtles1444
# 112167 turtles1447
# 112170 turtles1450
# 112173 turtles1453
# 112176 turtles1456
# 112179 turtles1459
# 112182 turtles1462
# 112185 turtles1465
# 112188 turtles1468
# 112191 turtles1471
# 112194 turtles1474
# 112197 turtles1477
# 112200 turtles1480
# 112203 turtles1483
# 112206 turtles1486
# 112209 turtles1489
# 112212 turtles1492
# 112215 turtles1495
# 112218 turtles1498
# 112221 turtles1501
# 112224 turtles1504
# 112227 turtles1507
# 112230 turtles1510
# 112233 turtles1513
# 112236 turtles1516
# 112239 turtles1519
# 112242 turtles1522
# 112245 turtles1525
# 112248 turtles1528
# 112251 turtles1531
# 112254 turtles1534
# 112257 turtles1537
# 112260 turtles1540
# 112263 turtles1543
# 112266 turtles1546
# 112269 turtles1549
# 112272 turtles1552
# 112275 turtles1555
# 112278 turtles1558
# 112281 turtles1561
# 112284 turtles1564
# 112287 turtles1567
# 112290 turtles1570
# 112293 turtles1573
# 112296 turtles1576
# 112299 turtles1579
# 112302 turtles1582
# 112305 turtles1585
# 112308 turtles1588
# 112311 turtles1591
# 112314 turtles1594
# 112249 turtles1529
# 112252 turtles1532
# 112255 turtles1535
# 112258 turtles1538
# 112261 turtles1541
# 112264 turtles1544
# 112267 turtles1547
# 112270 turtles1550
# 112273 turtles1553
# 112276 turtles1556
# 112279 turtles1559
# 112282 turtles1562
# 112285 turtles1565
# 112288 turtles1568
# 112291 turtles1571
# 112294 turtles1574
# 112297 turtles1577
# 112300 turtles1580
# 112303 turtles1583
# 112306 turtles1586
# 112309 turtles1589
# 112312 turtles1592
# 112315 turtles1595
# 112318 turtles1598
# 112321 turtles1601
# 112324 turtles1604
# 112327 turtles1607
# 112330 turtles1610
# 112333 turtles1613
# 112336 turtles1616
# 112339 turtles1619
# 112342 turtles1622
# 112345 turtles1625
# 112348 turtles1628
# 112351 turtles1631
# 112354 turtles1634
# 112357 turtles1637
# 112360 turtles1640
# 112363 turtles1643
# 112366 turtles1646
# 112369 turtles1649
# 112374 turtles1654
# 112377 turtles1657
# 112380 turtles1660
# 112383 turtles1663
# 112386 turtles1666
# 112389 turtles1669
# 112392 turtles1672
# 112395 turtles1675
# 112398 turtles1678
# 112401 turtles1681
# 112404 turtles1684
# 112407 turtles1687
# 112410 turtles1690
# 112413 turtles1693
# 112416 turtles1696
# 112419 turtles1699
# 112422 turtles1702
# 112425 turtles1705
# 112428 turtles1708
# 112431 turtles1711
# 112434 turtles1714
# 112437 turtles1717
# 112440 turtles1720
# 112443 turtles1723
# 112446 turtles1726
# 112449 turtles1729
# 112452 turtles1732
# 112455 turtles1735
# 112458 turtles1738
# 112461 turtles1741
# 112464 turtles1744
# 112467 turtles1747
# 112470 turtles1750
# 112473 turtles1753
# 112476 turtles1756
# 112479 turtles1759
# 112482 turtles1762
# 112485 turtles1765
# 112488 turtles1768
# 112491 turtles1771
# 112494 turtles1774
# 112497 turtles1777
# 112500 turtles1780
# 112503 turtles1783
# 112506 turtles1786
# 112509 turtles1789
# 112512 turtles1792
# 112515 turtles1795
# 112518 turtles1798
# 112521 turtles1801
# 112524 turtles1804
# 112527 turtles1807
# 112530 turtles1810
# 112533 turtles1813
# 112536 turtles1816
# 112539 turtles1819
# 112542 turtles1822
# 112545 turtles1825
# 112548 turtles1828
# 112551 turtles1831
# 112554 turtles1834
# 112557 turtles1837
# 112560 turtles1840
# 112563 turtles1843
# 112566 turtles1846
# 112569 turtles1849
# 112572 turtles1852
# 112575 turtles1855
# 112578 turtles1858
# 112581 turtles1861
# 112584 turtles1864
# 112587 turtles1867
# 112590 turtles1870
# 112593 turtles1873
# 112596 turtles1876
# 112599 turtles1879
# 112602 turtles1882
# 112605 turtles1885
# 112608 turtles1888
# 112317 turtles1597
# 112320 turtles1600
# 112323 turtles1603
# 112326 turtles1606
# 112329 turtles1609
# 112332 turtles1612
# 112335 turtles1615
# 112338 turtles1618
# 112341 turtles1621
# 112344 turtles1624
# 112347 turtles1627
# 112350 turtles1630
# 112353 turtles1633
# 112356 turtles1636
# 112359 turtles1639
# 112362 turtles1642
# 112365 turtles1645
# 112368 turtles1648
# 112371 turtles1651
# 112372 turtles1652
# 112373 turtles1653
# 112376 turtles1656
# 112379 turtles1659
# 112382 turtles1662
# 112385 turtles1665
# 112388 turtles1668
# 112391 turtles1671
# 112394 turtles1674
# 112397 turtles1677
# 112400 turtles1680
# 112403 turtles1683
# 112406 turtles1686
# 112409 turtles1689
# 112412 turtles1692
# 112415 turtles1695
# 112418 turtles1698
# 112421 turtles1701
# 112424 turtles1704
# 112427 turtles1707
# 112430 turtles1710
# 112433 turtles1713
# 112436 turtles1716
# 112439 turtles1719
# 112442 turtles1722
# 112445 turtles1725
# 112448 turtles1728
# 112451 turtles1731
# 112454 turtles1734
# 112457 turtles1737
# 112460 turtles1740
# 112463 turtles1743
# 112466 turtles1746
# 112469 turtles1749
# 112472 turtles1752
# 112475 turtles1755
# 112478 turtles1758
# 112481 turtles1761
# 112484 turtles1764
# 112487 turtles1767
# 112490 turtles1770
# 112493 turtles1773
# 112496 turtles1776
# 112499 turtles1779
# 112502 turtles1782
# 112505 turtles1785
# 112508 turtles1788
# 112511 turtles1791
# 112514 turtles1794
# 112517 turtles1797
# 112520 turtles1800
# 112523 turtles1803
# 112526 turtles1806
# 112529 turtles1809
# 112532 turtles1812
# 112535 turtles1815
# 112538 turtles1818
# 112541 turtles1821
# 112544 turtles1824
# 112547 turtles1827
# 112550 turtles1830
# 112553 turtles1833
# 112556 turtles1836
# 112559 turtles1839
# 112562 turtles1842
# 112565 turtles1845
# 112568 turtles1848
# 112571 turtles1851
# 112574 turtles1854
# 112577 turtles1857
# 112580 turtles1860
# 112583 turtles1863
# 112586 turtles1866
# 112589 turtles1869
# 112592 turtles1872
# 112595 turtles1875
# 112598 turtles1878
# 112601 turtles1881
# 112604 turtles1884
# 112607 turtles1887
# 112610 turtles1890
# 112613 turtles1893
# 112616 turtles1896
# 112619 turtles1899
# 112622 turtles1902
# 112625 turtles1905
# 112628 turtles1908
# 112631 turtles1911
# 112634 turtles1914
# 112637 turtles1917
# 112640 turtles1920
# 112643 turtles1923
# 112646 turtles1926
# 112649 turtles1929
# 112652 turtles1932
# 112655 turtles1935
# 112658 turtles1938
# 112661 turtles1941
# 112664 turtles1944
# 112667 turtles1947
# 112670 turtles1950
# 112471 turtles1751
# 112474 turtles1754
# 112477 turtles1757
# 112480 turtles1760
# 112483 turtles1763
# 112486 turtles1766
# 112489 turtles1769
# 112492 turtles1772
# 112495 turtles1775
# 112498 turtles1778
# 112501 turtles1781
# 112504 turtles1784
# 112507 turtles1787
# 112510 turtles1790
# 112513 turtles1793
# 112516 turtles1796
# 112519 turtles1799
# 112522 turtles1802
# 112525 turtles1805
# 112528 turtles1808
# 112531 turtles1811
# 112534 turtles1814
# 112537 turtles1817
# 112540 turtles1820
# 112543 turtles1823
# 112546 turtles1826
# 112549 turtles1829
# 112552 turtles1832
# 112555 turtles1835
# 112558 turtles1838
# 112561 turtles1841
# 112564 turtles1844
# 112567 turtles1847
# 112570 turtles1850
# 112573 turtles1853
# 112576 turtles1856
# 112579 turtles1859
# 112582 turtles1862
# 112585 turtles1865
# 112588 turtles1868
# 112591 turtles1871
# 112594 turtles1874
# 112597 turtles1877
# 112600 turtles1880
# 112603 turtles1883
# 112606 turtles1886
# 112609 turtles1889
# 112612 turtles1892
# 112615 turtles1895
# 112618 turtles1898
# 112621 turtles1901
# 112624 turtles1904
# 112627 turtles1907
# 112630 turtles1910
# 112633 turtles1913
# 112636 turtles1916
# 112639 turtles1919
# 112642 turtles1922
# 112645 turtles1925
# 112648 turtles1928
# 112651 turtles1931
# 112654 turtles1934
# 112657 turtles1937
# 112660 turtles1940
# 112663 turtles1943
# 112666 turtles1946
# 112669 turtles1949
# 112672 turtles1952
# 112675 turtles1955
# 112678 turtles1958
# 112681 turtles1961
# 112684 turtles1964
# 112687 turtles1967
# 112690 turtles1970
# 112693 turtles1973
# 112696 turtles1976
# 112699 turtles1979
# 112702 turtles1982
# 112705 turtles1985
# 112708 turtles1988
# 112711 turtles1991
# 112714 turtles1994
# 112717 turtles1997
# 112720 turtles2000
# 112723 turtles2003
# 112726 turtles2006
# 112729 turtles2009
# 112732 turtles2012
# 112735 turtles2015
# 112738 turtles2018
# 112741 turtles2021
# 112744 turtles2024
# 112747 turtles2027
# 112750 turtles2030
# 112753 turtles2033
# 112756 turtles2036
# 112759 turtles2039
# 112762 turtles2042
# 112765 turtles2045
# 112768 turtles2048
# 112771 turtles2051
# 112774 turtles2054
# 112777 turtles2057
# 112780 turtles2060
# 112783 turtles2063
# 112786 turtles2066
# 112789 turtles2069
# 112792 turtles2072
# 112795 turtles2075
# 112798 turtles2078
# 112801 turtles2081
# 112804 turtles2084
# 112807 turtles2087
# 112810 turtles2090
# 112813 turtles2093
# 112816 turtles2096
# 112819 turtles2099
# 112611 turtles1891
# 112614 turtles1894
# 112617 turtles1897
# 112620 turtles1900
# 112623 turtles1903
# 112626 turtles1906
# 112629 turtles1909
# 112632 turtles1912
# 112635 turtles1915
# 112638 turtles1918
# 112641 turtles1921
# 112644 turtles1924
# 112647 turtles1927
# 112650 turtles1930
# 112653 turtles1933
# 112656 turtles1936
# 112659 turtles1939
# 112662 turtles1942
# 112665 turtles1945
# 112668 turtles1948
# 112671 turtles1951
# 112674 turtles1954
# 112677 turtles1957
# 112680 turtles1960
# 112683 turtles1963
# 112686 turtles1966
# 112689 turtles1969
# 112692 turtles1972
# 112695 turtles1975
# 112698 turtles1978
# 112701 turtles1981
# 112704 turtles1984
# 112707 turtles1987
# 112710 turtles1990
# 112713 turtles1993
# 112716 turtles1996
# 112719 turtles1999
# 112722 turtles2002
# 112725 turtles2005
# 112728 turtles2008
# 112731 turtles2011
# 112734 turtles2014
# 112737 turtles2017
# 112740 turtles2020
# 112743 turtles2023
# 112746 turtles2026
# 112749 turtles2029
# 112752 turtles2032
# 112755 turtles2035
# 112758 turtles2038
# 112761 turtles2041
# 112764 turtles2044
# 112767 turtles2047
# 112770 turtles2050
# 112773 turtles2053
# 112776 turtles2056
# 112779 turtles2059
# 112782 turtles2062
# 112785 turtles2065
# 112788 turtles2068
# 112791 turtles2071
# 112794 turtles2074
# 112797 turtles2077
# 112800 turtles2080
# 112803 turtles2083
# 112806 turtles2086
# 112809 turtles2089
# 112812 turtles2092
# 112815 turtles2095
# 112818 turtles2098
# 112673 turtles1953
# 112676 turtles1956
# 112679 turtles1959
# 112682 turtles1962
# 112685 turtles1965
# 112688 turtles1968
# 112691 turtles1971
# 112694 turtles1974
# 112697 turtles1977
# 112700 turtles1980
# 112703 turtles1983
# 112706 turtles1986
# 112709 turtles1989
# 112712 turtles1992
# 112715 turtles1995
# 112718 turtles1998
# 112721 turtles2001
# 112724 turtles2004
# 112727 turtles2007
# 112730 turtles2010
# 112733 turtles2013
# 112736 turtles2016
# 112739 turtles2019
# 112742 turtles2022
# 112745 turtles2025
# 112748 turtles2028
# 112751 turtles2031
# 112754 turtles2034
# 112757 turtles2037
# 112760 turtles2040
# 112763 turtles2043
# 112766 turtles2046
# 112769 turtles2049
# 112772 turtles2052
# 112775 turtles2055
# 112778 turtles2058
# 112781 turtles2061
# 112784 turtles2064
# 112787 turtles2067
# 112790 turtles2070
# 112793 turtles2073
# 112796 turtles2076
# 112799 turtles2079
# 112802 turtles2082
# 112805 turtles2085
# 112808 turtles2088
# 112811 turtles2091
# 112814 turtles2094
# 112817 turtles2097
# 134838 turtles2555
# 134839 turtles2556
# 134840 turtles2557
# 134841 turtles2558
# 134842 turtles2559
# 134843 turtles2560
# 134844 turtles2561
# 134845 turtles2562
# 134846 turtles2563
# 134847 turtles2564
# 134383 turtles2100
# 134388 turtles2105
# 134393 turtles2110
# 134398 turtles2115
# 134403 turtles2120
# 134408 turtles2125
# 134413 turtles2130
# 134418 turtles2135
# 134423 turtles2140
# 134428 turtles2145
# 134433 turtles2150
# 134438 turtles2155
# 134443 turtles2160
# 134448 turtles2165
# 134453 turtles2170
# 134458 turtles2175
# 134463 turtles2180
# 134468 turtles2185
# 134473 turtles2190
# 134478 turtles2195
# 134483 turtles2200
# 134488 turtles2205
# 134493 turtles2210
# 134498 turtles2215
# 134503 turtles2220
# 134508 turtles2225
# 134513 turtles2230
# 134518 turtles2235
# 134523 turtles2240
# 134528 turtles2245
# 134533 turtles2250
# 134538 turtles2255
# 134543 turtles2260
# 134548 turtles2265
# 134553 turtles2270
# 134558 turtles2275
# 134563 turtles2280
# 134568 turtles2285
# 134573 turtles2290
# 134578 turtles2295
# 134583 turtles2300
# 134588 turtles2305
# 134593 turtles2310
# 134598 turtles2315
# 134603 turtles2320
# 134608 turtles2325
# 134613 turtles2330
# 134618 turtles2335
# 134623 turtles2340
# 134628 turtles2345
# 134633 turtles2350
# 134638 turtles2355
# 134643 turtles2360
# 134648 turtles2365
# 134653 turtles2370
# 134658 turtles2375
# 134663 turtles2380
# 134668 turtles2385
# 134673 turtles2390
# 134678 turtles2395
# 134683 turtles2400
# 134688 turtles2405
# 134693 turtles2410
# 134698 turtles2415
# 134703 turtles2420
# 134708 turtles2425
# 134713 turtles2430
# 134718 turtles2435
# 134723 turtles2440
# 134728 turtles2445
# 134733 turtles2450
# 134738 turtles2455
# 134743 turtles2460
# 134748 turtles2465
# 134753 turtles2470
# 134758 turtles2475
# 134763 turtles2480
# 134768 turtles2485
# 134773 turtles2490
# 134778 turtles2495
# 134783 turtles2500
# 134788 turtles2505
# 134793 turtles2510
# 134798 turtles2515
# 134803 turtles2520
# 134808 turtles2525
# 134813 turtles2530
# 134818 turtles2535
# 134823 turtles2540
# 134828 turtles2545
# 134833 turtles2550
# 134386 turtles2103
# 134391 turtles2108
# 134396 turtles2113
# 134401 turtles2118
# 134406 turtles2123
# 134411 turtles2128
# 134416 turtles2133
# 134421 turtles2138
# 134426 turtles2143
# 134431 turtles2148
# 134436 turtles2153
# 134441 turtles2158
# 134446 turtles2163
# 134451 turtles2168
# 134456 turtles2173
# 134461 turtles2178
# 134466 turtles2183
# 134471 turtles2188
# 134476 turtles2193
# 134481 turtles2198
# 134486 turtles2203
# 134491 turtles2208
# 134496 turtles2213
# 134501 turtles2218
# 134506 turtles2223
# 134511 turtles2228
# 134516 turtles2233
# 134521 turtles2238
# 134526 turtles2243
# 134531 turtles2248
# 134536 turtles2253
# 134541 turtles2258
# 134546 turtles2263
# 134551 turtles2268
# 134556 turtles2273
# 134561 turtles2278
# 134566 turtles2283
# 134571 turtles2288
# 134576 turtles2293
# 134581 turtles2298
# 134586 turtles2303
# 134591 turtles2308
# 134596 turtles2313
# 134601 turtles2318
# 134606 turtles2323
# 134611 turtles2328
# 134616 turtles2333
# 134621 turtles2338
# 134626 turtles2343
# 134631 turtles2348
# 134636 turtles2353
# 134641 turtles2358
# 134646 turtles2363
# 134651 turtles2368
# 134656 turtles2373
# 134661 turtles2378
# 134666 turtles2383
# 134671 turtles2388
# 134676 turtles2393
# 134681 turtles2398
# 134686 turtles2403
# 134691 turtles2408
# 134696 turtles2413
# 134701 turtles2418
# 134706 turtles2423
# 134711 turtles2428
# 134716 turtles2433
# 134721 turtles2438
# 134726 turtles2443
# 134731 turtles2448
# 134736 turtles2453
# 134741 turtles2458
# 134746 turtles2463
# 134751 turtles2468
# 134756 turtles2473
# 134761 turtles2478
# 134766 turtles2483
# 134771 turtles2488
# 134776 turtles2493
# 134781 turtles2498
# 134786 turtles2503
# 134791 turtles2508
# 134796 turtles2513
# 134801 turtles2518
# 134806 turtles2523
# 134811 turtles2528
# 134816 turtles2533
# 134821 turtles2538
# 134826 turtles2543
# 134831 turtles2548
# 134836 turtles2553
# 134384 turtles2101
# 134389 turtles2106
# 134394 turtles2111
# 134399 turtles2116
# 134404 turtles2121
# 134409 turtles2126
# 134414 turtles2131
# 134419 turtles2136
# 134424 turtles2141
# 134429 turtles2146
# 134434 turtles2151
# 134439 turtles2156
# 134444 turtles2161
# 134449 turtles2166
# 134454 turtles2171
# 134459 turtles2176
# 134464 turtles2181
# 134469 turtles2186
# 134474 turtles2191
# 134479 turtles2196
# 134484 turtles2201
# 134489 turtles2206
# 134494 turtles2211
# 134499 turtles2216
# 134504 turtles2221
# 134509 turtles2226
# 134514 turtles2231
# 134519 turtles2236
# 134524 turtles2241
# 134529 turtles2246
# 134534 turtles2251
# 134539 turtles2256
# 134544 turtles2261
# 134549 turtles2266
# 134554 turtles2271
# 134559 turtles2276
# 134564 turtles2281
# 134569 turtles2286
# 134574 turtles2291
# 134579 turtles2296
# 134584 turtles2301
# 134589 turtles2306
# 134594 turtles2311
# 134599 turtles2316
# 134604 turtles2321
# 134609 turtles2326
# 134614 turtles2331
# 134619 turtles2336
# 134624 turtles2341
# 134629 turtles2346
# 134634 turtles2351
# 134639 turtles2356
# 134644 turtles2361
# 134649 turtles2366
# 134654 turtles2371
# 134659 turtles2376
# 134664 turtles2381
# 134669 turtles2386
# 134674 turtles2391
# 134679 turtles2396
# 134684 turtles2401
# 134689 turtles2406
# 134694 turtles2411
# 134699 turtles2416
# 134704 turtles2421
# 134709 turtles2426
# 134714 turtles2431
# 134719 turtles2436
# 134724 turtles2441
# 134729 turtles2446
# 134734 turtles2451
# 134739 turtles2456
# 134744 turtles2461
# 134749 turtles2466
# 134754 turtles2471
# 134759 turtles2476
# 134764 turtles2481
# 134769 turtles2486
# 134774 turtles2491
# 134779 turtles2496
# 134784 turtles2501
# 134789 turtles2506
# 134794 turtles2511
# 134799 turtles2516
# 134804 turtles2521
# 134809 turtles2526
# 134814 turtles2531
# 134819 turtles2536
# 134824 turtles2541
# 134829 turtles2546
# 134834 turtles2551
# 134387 turtles2104
# 134392 turtles2109
# 134397 turtles2114
# 134402 turtles2119
# 134407 turtles2124
# 134412 turtles2129
# 134417 turtles2134
# 134422 turtles2139
# 134427 turtles2144
# 134432 turtles2149
# 134437 turtles2154
# 134442 turtles2159
# 134447 turtles2164
# 134452 turtles2169
# 134457 turtles2174
# 134462 turtles2179
# 134467 turtles2184
# 134472 turtles2189
# 134477 turtles2194
# 134482 turtles2199
# 134487 turtles2204
# 134492 turtles2209
# 134497 turtles2214
# 134502 turtles2219
# 134507 turtles2224
# 134512 turtles2229
# 134517 turtles2234
# 134522 turtles2239
# 134527 turtles2244
# 134532 turtles2249
# 134537 turtles2254
# 134542 turtles2259
# 134547 turtles2264
# 134552 turtles2269
# 134557 turtles2274
# 134562 turtles2279
# 134567 turtles2284
# 134572 turtles2289
# 134577 turtles2294
# 134582 turtles2299
# 134587 turtles2304
# 134592 turtles2309
# 134597 turtles2314
# 134602 turtles2319
# 134607 turtles2324
# 134612 turtles2329
# 134617 turtles2334
# 134622 turtles2339
# 134627 turtles2344
# 134632 turtles2349
# 134637 turtles2354
# 134642 turtles2359
# 134647 turtles2364
# 134652 turtles2369
# 134657 turtles2374
# 134662 turtles2379
# 134667 turtles2384
# 134672 turtles2389
# 134677 turtles2394
# 134682 turtles2399
# 134687 turtles2404
# 134692 turtles2409
# 134697 turtles2414
# 134702 turtles2419
# 134707 turtles2424
# 134712 turtles2429
# 134717 turtles2434
# 134722 turtles2439
# 134727 turtles2444
# 134732 turtles2449
# 134737 turtles2454
# 134742 turtles2459
# 134747 turtles2464
# 134752 turtles2469
# 134757 turtles2474
# 134762 turtles2479
# 134767 turtles2484
# 134772 turtles2489
# 134777 turtles2494
# 134782 turtles2499
# 134787 turtles2504
# 134792 turtles2509
# 134797 turtles2514
# 134802 turtles2519
# 134807 turtles2524
# 134812 turtles2529
# 134817 turtles2534
# 134822 turtles2539
# 134827 turtles2544
# 134832 turtles2549
# 134837 turtles2554
# 134385 turtles2102
# 134390 turtles2107
# 134395 turtles2112
# 134400 turtles2117
# 134405 turtles2122
# 134410 turtles2127
# 134415 turtles2132
# 134420 turtles2137
# 134425 turtles2142
# 134430 turtles2147
# 134435 turtles2152
# 134440 turtles2157
# 134445 turtles2162
# 134450 turtles2167
# 134455 turtles2172
# 134460 turtles2177
# 134465 turtles2182
# 134470 turtles2187
# 134475 turtles2192
# 134480 turtles2197
# 134485 turtles2202
# 134490 turtles2207
# 134495 turtles2212
# 134500 turtles2217
# 134505 turtles2222
# 134510 turtles2227
# 134515 turtles2232
# 134520 turtles2237
# 134525 turtles2242
# 134530 turtles2247
# 134535 turtles2252
# 134540 turtles2257
# 134545 turtles2262
# 134550 turtles2267
# 134555 turtles2272
# 134560 turtles2277
# 134565 turtles2282
# 134570 turtles2287
# 134575 turtles2292
# 134580 turtles2297
# 134585 turtles2302
# 134590 turtles2307
# 134595 turtles2312
# 134600 turtles2317
# 134605 turtles2322
# 134610 turtles2327
# 134615 turtles2332
# 134620 turtles2337
# 134625 turtles2342
# 134630 turtles2347
# 134635 turtles2352
# 134640 turtles2357
# 134645 turtles2362
# 134650 turtles2367
# 134655 turtles2372
# 134660 turtles2377
# 134665 turtles2382
# 134670 turtles2387
# 134675 turtles2392
# 134680 turtles2397
# 134685 turtles2402
# 134690 turtles2407
# 134695 turtles2412
# 134700 turtles2417
# 134705 turtles2422
# 134710 turtles2427
# 134715 turtles2432
# 134720 turtles2437
# 134725 turtles2442
# 134730 turtles2447
# 134735 turtles2452
# 134740 turtles2457
# 134745 turtles2462
# 134750 turtles2467
# 134755 turtles2472
# 134760 turtles2477
# 134765 turtles2482
# 134770 turtles2487
# 134775 turtles2492
# 134780 turtles2497
# 134785 turtles2502
# 134790 turtles2507
# 134795 turtles2512
# 134800 turtles2517
# 134805 turtles2522
# 134810 turtles2527
# 134815 turtles2532
# 134820 turtles2537
# 134825 turtles2542
# 134830 turtles2547
# 134835 turtles2552
# 134848 turtles2565
# 134853 turtles2570
# 134858 turtles2575
# 134863 turtles2580
# 134868 turtles2585
# 134873 turtles2590
# 134878 turtles2595
# 134883 turtles2600
# 134888 turtles2605
# 134893 turtles2610
# 134898 turtles2615
# 134903 turtles2620
# 134908 turtles2625
# 134913 turtles2630
# 134918 turtles2635
# 134923 turtles2640
# 134928 turtles2645
# 134933 turtles2650
# 134938 turtles2655
# 134943 turtles2660
# 134948 turtles2665
# 134953 turtles2670
# 134958 turtles2675
# 134963 turtles2680
# 134968 turtles2685
# 134973 turtles2690
# 134978 turtles2695
# 134983 turtles2700
# 134988 turtles2705
# 134993 turtles2710
# 134998 turtles2715
# 135003 turtles2720
# 135008 turtles2725
# 135013 turtles2730
# 135018 turtles2735
# 135023 turtles2740
# 135028 turtles2745
# 135033 turtles2750
# 135038 turtles2755
# 135043 turtles2760
# 135048 turtles2765
# 135053 turtles2770
# 135058 turtles2775
# 135063 turtles2780
# 135068 turtles2785
# 135073 turtles2790
# 135078 turtles2795
# 135083 turtles2800
# 135088 turtles2805
# 135093 turtles2810
# 135098 turtles2815
# 135103 turtles2820
# 135108 turtles2825
# 135113 turtles2830
# 135118 turtles2835
# 135123 turtles2840
# 135128 turtles2845
# 135133 turtles2850
# 135138 turtles2855
# 135143 turtles2860
# 135148 turtles2865
# 135153 turtles2870
# 135158 turtles2875
# 135163 turtles2880
# 135168 turtles2885
# 135173 turtles2890
# 135178 turtles2895
# 135183 turtles2900
# 135188 turtles2905
# 135193 turtles2910
# 135198 turtles2915
# 135203 turtles2920
# 135208 turtles2925
# 135213 turtles2930
# 135218 turtles2935
# 135223 turtles2940
# 135228 turtles2945
# 135233 turtles2950
# 135238 turtles2955
# 135243 turtles2960
# 135248 turtles2965
# 135253 turtles2970
# 135258 turtles2975
# 135263 turtles2980
# 135268 turtles2985
# 135273 turtles2990
# 135278 turtles2995
# 135283 turtles3000
# 135288 turtles3005
# 135293 turtles3010
# 135298 turtles3015
# 135303 turtles3020
# 135308 turtles3025
# ...
# 169148 turtles3343
# 169153 turtles3348
# 169158 turtles3353
# 169163 turtles3358
# 169168 turtles3363
# 169173 turtles3368
# 169178 turtles3373
# 169183 turtles3378
# 169188 turtles3383
# 169193 turtles3388
# 169198 turtles3393
# 169203 turtles3398
# 169208 turtles3403
# 169213 turtles3408
# 169218 turtles3413
# 169223 turtles3418
# 169228 turtles3423
# 169233 turtles3428
# 169238 turtles3433
# 169243 turtles3438
# 169248 turtles3443
# 169253 turtles3448
# 169258 turtles3453
# 169263 turtles3458
# 169268 turtles3463
# 169273 turtles3468
# 169278 turtles3473
# 169283 turtles3478
# 169288 turtles3483
# 169293 turtles3488
# 169298 turtles3493
# 169303 turtles3498
# 169308 turtles3503
# 169313 turtles3508
# 169318 turtles3513
# 169323 turtles3518
# 169328 turtles3523
# 169333 turtles3528
# 169338 turtles3533
# 169343 turtles3538
# 169348 turtles3543
# 169353 turtles3548
# 169358 turtles3553
# 169363 turtles3558
# 169368 turtles3563
# 169373 turtles3568
# 169378 turtles3573
# 169383 turtles3578
# 169388 turtles3583
# 169393 turtles3588
# 169398 turtles3593
# 169403 turtles3598
# 169408 turtles3603
# 169413 turtles3608
# 169418 turtles3613
# 169423 turtles3618
# 169428 turtles3623
# 169433 turtles3628
# 169438 turtles3633
# 169443 turtles3638
# 169448 turtles3643
# 169453 turtles3648
# 169458 turtles3653
# 169463 turtles3658
# 168909 turtles3104
# 168914 turtles3109
# 168919 turtles3114
# 168924 turtles3119
# 168929 turtles3124
# 168934 turtles3129
# 168939 turtles3134
# 168944 turtles3139
# 168949 turtles3144
# 168954 turtles3149
# 168959 turtles3154
# 168964 turtles3159
# 168969 turtles3164
# 168974 turtles3169
# 168979 turtles3174
# 168984 turtles3179
# 168989 turtles3184
# 168994 turtles3189
# 168999 turtles3194
# 169004 turtles3199
# 169009 turtles3204
# 169014 turtles3209
# 169019 turtles3214
# 169024 turtles3219
# 169029 turtles3224
# 169034 turtles3229
# 169039 turtles3234
# 169044 turtles3239
# 169049 turtles3244
# 169054 turtles3249
# 169059 turtles3254
# 169064 turtles3259
# 169069 turtles3264
# 169074 turtles3269
# 169079 turtles3274
# 169084 turtles3279
# 169089 turtles3284
# 169094 turtles3289
# 169099 turtles3294
# 169104 turtles3299
# 169109 turtles3304
# 169114 turtles3309
# 169119 turtles3314
# 169124 turtles3319
# 169129 turtles3324
# 169134 turtles3329
# 169139 turtles3334
# 169144 turtles3339
# 169149 turtles3344
# 169154 turtles3349
# 169159 turtles3354
# 169164 turtles3359
# 169169 turtles3364
# 169174 turtles3369
# 169179 turtles3374
# 169184 turtles3379
# 169189 turtles3384
# 169194 turtles3389
# 169199 turtles3394
# 169204 turtles3399
# 169209 turtles3404
# 169214 turtles3409
# 169219 turtles3414
# 169224 turtles3419
# 169229 turtles3424
# 169234 turtles3429
# 169239 turtles3434
# 169244 turtles3439
# 169249 turtles3444
# 169254 turtles3449
# 169259 turtles3454
# 169264 turtles3459
# 169269 turtles3464
# 169274 turtles3469
# 169279 turtles3474
# 169284 turtles3479
# 169289 turtles3484
# 169294 turtles3489
# 169299 turtles3494
# 169304 turtles3499
# 169309 turtles3504
# 169314 turtles3509
# 169319 turtles3514
# 169324 turtles3519
# 169329 turtles3524
# 169334 turtles3529
# 169339 turtles3534
# 169344 turtles3539
# 169349 turtles3544
# 169354 turtles3549
# 169359 turtles3554
# 169364 turtles3559
# 169369 turtles3564
# 169374 turtles3569
# 169379 turtles3574
# 169384 turtles3579
# 169389 turtles3584
# 169394 turtles3589
# 169399 turtles3594
# 169404 turtles3599
# 169409 turtles3604
# 169414 turtles3609
# 169419 turtles3614
# 169424 turtles3619
# 169429 turtles3624
# 169434 turtles3629
# 169439 turtles3634
# 169444 turtles3639
# 169449 turtles3644
# 169454 turtles3649
# 169459 turtles3654
# 169464 turtles3659
# 169469 turtles3664
# 168905 turtles3100
# 168910 turtles3105
# 168915 turtles3110
# 168920 turtles3115
# 168925 turtles3120
# 168930 turtles3125
# 168935 turtles3130
# 168940 turtles3135
# 168945 turtles3140
# 168950 turtles3145
# 168955 turtles3150
# 168960 turtles3155
# 168965 turtles3160
# 168970 turtles3165
# 168975 turtles3170
# 168980 turtles3175
# 168985 turtles3180
# 168990 turtles3185
# 168995 turtles3190
# 169000 turtles3195
# 169005 turtles3200
# 169010 turtles3205
# 169015 turtles3210
# 169020 turtles3215
# 169025 turtles3220
# 169030 turtles3225
# 169035 turtles3230
# 169040 turtles3235
# 169045 turtles3240
# 169050 turtles3245
# 169055 turtles3250
# 169060 turtles3255
# 169065 turtles3260
# 169070 turtles3265
# 169075 turtles3270
# 169080 turtles3275
# 169085 turtles3280
# 169090 turtles3285
# 169095 turtles3290
# 169100 turtles3295
# 169105 turtles3300
# 169110 turtles3305
# 169115 turtles3310
# 169120 turtles3315
# 169125 turtles3320
# 169130 turtles3325
# 169135 turtles3330
# 169140 turtles3335
# 169145 turtles3340
# 169150 turtles3345
# 169155 turtles3350
# 169160 turtles3355
# 169165 turtles3360
# 169170 turtles3365
# 169175 turtles3370
# 169180 turtles3375
# 169185 turtles3380
# 169190 turtles3385
# 169195 turtles3390
# 169200 turtles3395
# 169205 turtles3400
# 169210 turtles3405
# 169215 turtles3410
# 169220 turtles3415
# 169225 turtles3420
# 169230 turtles3425
# 169235 turtles3430
# 169240 turtles3435
# 169245 turtles3440
# 169250 turtles3445
# 169255 turtles3450
# 169260 turtles3455
# 169265 turtles3460
# 169270 turtles3465
# 169275 turtles3470
# 169280 turtles3475
# 169285 turtles3480
# 169290 turtles3485
# 169295 turtles3490
# 169300 turtles3495
# 169305 turtles3500
# 169310 turtles3505
# 169315 turtles3510
# 169320 turtles3515
# 169325 turtles3520
# 169330 turtles3525
# 169335 turtles3530
# 169340 turtles3535
# 169345 turtles3540
# 169350 turtles3545
# 169355 turtles3550
# 169360 turtles3555
# 169365 turtles3560
# 169370 turtles3565
# 169375 turtles3570
# 169380 turtles3575
# 169385 turtles3580
# 169390 turtles3585
# 169395 turtles3590
# 169400 turtles3595
# 169405 turtles3600
# 169410 turtles3605
# 169415 turtles3610
# 169420 turtles3615
# 169425 turtles3620
# 169430 turtles3625
# 169435 turtles3630
# 169440 turtles3635
# 169445 turtles3640
# 169450 turtles3645
# 169455 turtles3650
# 169460 turtles3655
# 169465 turtles3660
# 169470 turtles3665
# 169475 turtles3670
# 169480 turtles3675
# 169485 turtles3680
# 169490 turtles3685
# 168916 turtles3111
# 168921 turtles3116
# 168926 turtles3121
# 168931 turtles3126
# 168936 turtles3131
# 168941 turtles3136
# 168946 turtles3141
# 168951 turtles3146
# 168956 turtles3151
# 168961 turtles3156
# 168966 turtles3161
# 168971 turtles3166
# 168976 turtles3171
# 168981 turtles3176
# 168986 turtles3181
# 168991 turtles3186
# 168996 turtles3191
# 169001 turtles3196
# 169006 turtles3201
# 169011 turtles3206
# 169016 turtles3211
# 169021 turtles3216
# 169026 turtles3221
# 169031 turtles3226
# 169036 turtles3231
# 169041 turtles3236
# 169046 turtles3241
# 169051 turtles3246
# 169056 turtles3251
# 169061 turtles3256
# 169066 turtles3261
# 169071 turtles3266
# 169076 turtles3271
# 169081 turtles3276
# 169086 turtles3281
# 169091 turtles3286
# 169096 turtles3291
# 169101 turtles3296
# 169106 turtles3301
# 169111 turtles3306
# 169116 turtles3311
# 169121 turtles3316
# 169126 turtles3321
# 169131 turtles3326
# 169136 turtles3331
# 169141 turtles3336
# 169146 turtles3341
# 169151 turtles3346
# 169156 turtles3351
# 169161 turtles3356
# 169166 turtles3361
# 169171 turtles3366
# 169176 turtles3371
# 169181 turtles3376
# 169186 turtles3381
# 169191 turtles3386
# 169196 turtles3391
# 169201 turtles3396
# 169206 turtles3401
# 169211 turtles3406
# 169216 turtles3411
# 169221 turtles3416
# 169226 turtles3421
# 169231 turtles3426
# 169236 turtles3431
# 169241 turtles3436
# 169246 turtles3441
# 169251 turtles3446
# 169256 turtles3451
# 169261 turtles3456
# 169266 turtles3461
# 169271 turtles3466
# 169276 turtles3471
# 169281 turtles3476
# 169286 turtles3481
# 169291 turtles3486
# 169296 turtles3491
# 169301 turtles3496
# 169306 turtles3501
# 169311 turtles3506
# 169316 turtles3511
# 169321 turtles3516
# 169326 turtles3521
# 169331 turtles3526
# 169336 turtles3531
# 169341 turtles3536
# 169346 turtles3541
# 169351 turtles3546
# 169356 turtles3551
# 169361 turtles3556
# 169366 turtles3561
# 169371 turtles3566
# 169376 turtles3571
# 169381 turtles3576
# 169386 turtles3581
# 169391 turtles3586
# 169396 turtles3591
# 169401 turtles3596
# 169406 turtles3601
# 169411 turtles3606
# 169416 turtles3611
# 169421 turtles3616
# 169426 turtles3621
# 169431 turtles3626
# 169436 turtles3631
# 169441 turtles3636
# 169446 turtles3641
# 169451 turtles3646
# 169456 turtles3651
# 169461 turtles3656
# 169466 turtles3661
# 169471 turtles3666
# 169476 turtles3671
# 169481 turtles3676
# 169486 turtles3681
# 169491 turtles3686
# 169496 turtles3691
# 169501 turtles3696
# 169506 turtles3701
# 169511 turtles3706
# 169447 turtles3642
# 169452 turtles3647
# 169457 turtles3652
# 169462 turtles3657
# 169467 turtles3662
# 169472 turtles3667
# 169477 turtles3672
# 169482 turtles3677
# 169487 turtles3682
# 169492 turtles3687
# 169497 turtles3692
# 169502 turtles3697
# 169507 turtles3702
# 169512 turtles3707
# 169517 turtles3712
# 169522 turtles3717
# 169527 turtles3722
# 169532 turtles3727
# 169537 turtles3732
# 169542 turtles3737
# 169547 turtles3742
# 169552 turtles3747
# 169557 turtles3752
# 169562 turtles3757
# 169567 turtles3762
# 169572 turtles3767
# 169577 turtles3772
# 169582 turtles3777
# 169587 turtles3782
# 169592 turtles3787
# 169597 turtles3792
# 169602 turtles3797
# 169607 turtles3802
# 169612 turtles3807
# 169617 turtles3812
# 169622 turtles3817
# 169627 turtles3822
# 169632 turtles3827
# 169637 turtles3832
# 169642 turtles3837
# 169647 turtles3842
# 169652 turtles3847
# 169657 turtles3852
# 169662 turtles3857
# 169667 turtles3862
# 169672 turtles3867
# 169677 turtles3872
# 169682 turtles3877
# 169687 turtles3882
# 169692 turtles3887
# 169697 turtles3892
# 169702 turtles3897
# 169707 turtles3902
# 169712 turtles3907
# 169717 turtles3912
# 169722 turtles3917
# 169727 turtles3922
# 169732 turtles3927
# 169737 turtles3932
# 169742 turtles3937
# 169747 turtles3942
# 169752 turtles3947
# 169757 turtles3952
# 169762 turtles3957
# 169767 turtles3962
# 169772 turtles3967
# 169777 turtles3972
# 169782 turtles3977
# 169787 turtles3982
# 169792 turtles3987
# 169797 turtles3992
# 169802 turtles3997
# 169807 turtles4002
# 169812 turtles4007
# 169817 turtles4012
# 169822 turtles4017
# 169827 turtles4022
# 169832 turtles4027
# 169837 turtles4032
# 169842 turtles4037
# 169847 turtles4042
# 169852 turtles4047
# 169857 turtles4052
# 169862 turtles4057
# 169867 turtles4062
# 169872 turtles4067
# 169877 turtles4072
# 169882 turtles4077
# 169887 turtles4082
# 169892 turtles4087
# 169897 turtles4092
# 169902 turtles4097
# 169468 turtles3663
# 169473 turtles3668
# 169478 turtles3673
# 169483 turtles3678
# 169488 turtles3683
# 169493 turtles3688
# 169498 turtles3693
# 169503 turtles3698
# 169508 turtles3703
# 169513 turtles3708
# 169518 turtles3713
# 169523 turtles3718
# 169528 turtles3723
# 169533 turtles3728
# 169538 turtles3733
# 169543 turtles3738
# 169548 turtles3743
# 169553 turtles3748
# 169558 turtles3753
# 169563 turtles3758
# 169568 turtles3763
# 169573 turtles3768
# 169578 turtles3773
# 169583 turtles3778
# 169588 turtles3783
# 169593 turtles3788
# 169598 turtles3793
# 169603 turtles3798
# 169608 turtles3803
# 169613 turtles3808
# 169618 turtles3813
# 169623 turtles3818
# 169628 turtles3823
# 169633 turtles3828
# 169638 turtles3833
# 169643 turtles3838
# 169648 turtles3843
# 169653 turtles3848
# 169658 turtles3853
# 169663 turtles3858
# 169668 turtles3863
# 169673 turtles3868
# 169678 turtles3873
# 169683 turtles3878
# 169688 turtles3883
# 169693 turtles3888
# 169698 turtles3893
# 169703 turtles3898
# 169708 turtles3903
# 169713 turtles3908
# 169718 turtles3913
# 169723 turtles3918
# 169728 turtles3923
# 169733 turtles3928
# 169738 turtles3933
# 169743 turtles3938
# 169748 turtles3943
# 169753 turtles3948
# 169758 turtles3953
# 169763 turtles3958
# 169768 turtles3963
# 169773 turtles3968
# 169778 turtles3973
# 169783 turtles3978
# 169788 turtles3983
# 169793 turtles3988
# 169798 turtles3993
# 169803 turtles3998
# 169808 turtles4003
# 169813 turtles4008
# 169818 turtles4013
# 169823 turtles4018
# 169828 turtles4023
# 169833 turtles4028
# 169838 turtles4033
# 169843 turtles4038
# 169848 turtles4043
# 169853 turtles4048
# 169858 turtles4053
# 169863 turtles4058
# 169868 turtles4063
# 169873 turtles4068
# 169878 turtles4073
# 169883 turtles4078
# 169888 turtles4083
# 169893 turtles4088
# 169898 turtles4093
# 169903 turtles4098
# 169474 turtles3669
# 169479 turtles3674
# 169484 turtles3679
# 169489 turtles3684
# 169494 turtles3689
# 169499 turtles3694
# 169504 turtles3699
# 169509 turtles3704
# 169514 turtles3709
# 169519 turtles3714
# 169524 turtles3719
# 169529 turtles3724
# 169534 turtles3729
# 169539 turtles3734
# 169544 turtles3739
# 169549 turtles3744
# 169554 turtles3749
# 169559 turtles3754
# 169564 turtles3759
# 169569 turtles3764
# 169574 turtles3769
# 169579 turtles3774
# 169584 turtles3779
# 169589 turtles3784
# 169594 turtles3789
# 169599 turtles3794
# 169604 turtles3799
# 169609 turtles3804
# 169614 turtles3809
# 169619 turtles3814
# 169624 turtles3819
# 169629 turtles3824
# 169634 turtles3829
# 169639 turtles3834
# 169644 turtles3839
# 169649 turtles3844
# 169654 turtles3849
# 169659 turtles3854
# 169664 turtles3859
# 169669 turtles3864
# 169674 turtles3869
# 169679 turtles3874
# 169684 turtles3879
# 169689 turtles3884
# 169694 turtles3889
# 169699 turtles3894
# 169704 turtles3899
# 169709 turtles3904
# 169714 turtles3909
# 169719 turtles3914
# 169724 turtles3919
# 169729 turtles3924
# 169734 turtles3929
# 169739 turtles3934
# 169744 turtles3939
# 169749 turtles3944
# 169754 turtles3949
# 169759 turtles3954
# 169764 turtles3959
# 169769 turtles3964
# 169774 turtles3969
# 169779 turtles3974
# 169784 turtles3979
# 169789 turtles3984
# 169794 turtles3989
# 169799 turtles3994
# 169804 turtles3999
# 169809 turtles4004
# 169814 turtles4009
# 169819 turtles4014
# 169824 turtles4019
# 169829 turtles4024
# 169834 turtles4029
# 169839 turtles4034
# 169844 turtles4039
# 169849 turtles4044
# 169854 turtles4049
# 169859 turtles4054
# 169864 turtles4059
# 169869 turtles4064
# 169874 turtles4069
# 169879 turtles4074
# 169884 turtles4079
# 169889 turtles4084
# 169894 turtles4089
# 169899 turtles4094
# 169904 turtles4099
# 169495 turtles3690
# 169500 turtles3695
# 169505 turtles3700
# 169510 turtles3705
# 169515 turtles3710
# 169520 turtles3715
# 169525 turtles3720
# 169530 turtles3725
# 169535 turtles3730
# 169540 turtles3735
# 169545 turtles3740
# 169550 turtles3745
# 169555 turtles3750
# 169560 turtles3755
# 169565 turtles3760
# 169570 turtles3765
# 169575 turtles3770
# 169580 turtles3775
# 169585 turtles3780
# 169590 turtles3785
# 169595 turtles3790
# 169600 turtles3795
# 169605 turtles3800
# 169610 turtles3805
# 169615 turtles3810
# 169620 turtles3815
# 169625 turtles3820
# 169630 turtles3825
# 169635 turtles3830
# 169640 turtles3835
# 169645 turtles3840
# 169650 turtles3845
# 169655 turtles3850
# 169660 turtles3855
# 169665 turtles3860
# 169670 turtles3865
# 169675 turtles3870
# 169680 turtles3875
# 169685 turtles3880
# 169690 turtles3885
# 169695 turtles3890
# 169700 turtles3895
# 169705 turtles3900
# 169710 turtles3905
# 169715 turtles3910
# 169720 turtles3915
# 169725 turtles3920
# 169730 turtles3925
# 169735 turtles3930
# 169740 turtles3935
# 169745 turtles3940
# 169750 turtles3945
# 169755 turtles3950
# 169760 turtles3955
# 169765 turtles3960
# 169770 turtles3965
# 169775 turtles3970
# 169780 turtles3975
# 169785 turtles3980
# 169790 turtles3985
# 169795 turtles3990
# 169800 turtles3995
# 169805 turtles4000
# 169810 turtles4005
# 169815 turtles4010
# 169820 turtles4015
# 169825 turtles4020
# 169830 turtles4025
# 169835 turtles4030
# 169840 turtles4035
# 169845 turtles4040
# 169850 turtles4045
# 169855 turtles4050
# 169860 turtles4055
# 169865 turtles4060
# 169870 turtles4065
# 169875 turtles4070
# 169880 turtles4075
# 169885 turtles4080
# 169890 turtles4085
# 169895 turtles4090
# 169900 turtles4095
# 169516 turtles3711
# 169521 turtles3716
# 169526 turtles3721
# 169531 turtles3726
# 169536 turtles3731
# 169541 turtles3736
# 169546 turtles3741
# 169551 turtles3746
# 169556 turtles3751
# 169561 turtles3756
# 169566 turtles3761
# 169571 turtles3766
# 169576 turtles3771
# 169581 turtles3776
# 169586 turtles3781
# 169591 turtles3786
# 169596 turtles3791
# 169601 turtles3796
# 169606 turtles3801
# 169611 turtles3806
# 169616 turtles3811
# 169621 turtles3816
# 169626 turtles3821
# 169631 turtles3826
# 169636 turtles3831
# 169641 turtles3836
# 169646 turtles3841
# 169651 turtles3846
# 169656 turtles3851
# 169661 turtles3856
# 169666 turtles3861
# 169671 turtles3866
# 169676 turtles3871
# 169681 turtles3876
# 169686 turtles3881
# 169691 turtles3886
# 169696 turtles3891
# 169701 turtles3896
# 169706 turtles3901
# 169711 turtles3906
# 169716 turtles3911
# 169721 turtles3916
# 169726 turtles3921
# 169731 turtles3926
# 169736 turtles3931
# 169741 turtles3936
# 169746 turtles3941
# 169751 turtles3946
# 169756 turtles3951
# 169761 turtles3956
# 169766 turtles3961
# 169771 turtles3966
# 169776 turtles3971
# 169781 turtles3976
# 169786 turtles3981
# 169791 turtles3986
# 169796 turtles3991
# 169801 turtles3996
# 169806 turtles4001
# 169811 turtles4006
# 169816 turtles4011
# 169821 turtles4016
# 169826 turtles4021
# 169831 turtles4026
# 169836 turtles4031
# 169841 turtles4036
# 169846 turtles4041
# 169851 turtles4046
# 169856 turtles4051
# 169861 turtles4056
# 169866 turtles4061
# 169871 turtles4066
# 169876 turtles4071
# 169881 turtles4076
# 169886 turtles4081
# 169891 turtles4086
# 169896 turtles4091
# 169901 turtles4096

# %%
(names[3101:])
# Out:
# ['turtles3101',
#  'turtles3106',
#  'turtles3102',
#  'turtles3107',
#  'turtles3112',
#  'turtles3117',
#  'turtles3122',
#  'turtles3127',
#  'turtles3132',
#  'turtles3137',
#  'turtles3142',
#  'turtles3147',
#  'turtles3152',
#  'turtles3157',
#  'turtles3162',
#  'turtles3167',
#  'turtles3172',
#  'turtles3177',
#  'turtles3182',
#  'turtles3187',
#  'turtles3192',
#  'turtles3197',
#  'turtles3202',
#  'turtles3207',
#  'turtles3212',
#  'turtles3217',
#  'turtles3222',
#  'turtles3227',
#  'turtles3232',
#  'turtles3237',
#  'turtles3242',
#  'turtles3247',
#  'turtles3252',
#  'turtles3257',
#  'turtles3262',
#  'turtles3267',
#  'turtles3272',
#  'turtles3277',
#  'turtles3282',
#  'turtles3287',
#  'turtles3292',
#  'turtles3297',
#  'turtles3302',
#  'turtles3307',
#  'turtles3312',
#  'turtles3317',
#  'turtles3322',
#  'turtles3327',
#  'turtles3332',
#  'turtles3337',
#  'turtles3342',
#  'turtles3347',
#  'turtles3352',
#  'turtles3357',
#  'turtles3362',
#  'turtles3367',
#  'turtles3372',
#  'turtles3377',
#  'turtles3382',
#  'turtles3387',
#  'turtles3392',
#  'turtles3397',
#  'turtles3402',
#  'turtles3407',
#  'turtles3412',
#  'turtles3417',
#  'turtles3422',
#  'turtles3427',
#  'turtles3432',
#  'turtles3437',
#  'turtles3442',
#  'turtles3447',
#  'turtles3452',
#  'turtles3457',
#  'turtles3462',
#  'turtles3467',
#  'turtles3472',
#  'turtles3477',
#  'turtles3482',
#  'turtles3487',
#  'turtles3492',
#  'turtles3497',
#  'turtles3502',
#  'turtles3507',
#  'turtles3512',
#  'turtles3517',
#  'turtles3522',
#  'turtles3527',
#  'turtles3532',
#  'turtles3537',
#  'turtles3542',
#  'turtles3547',
#  'turtles3552',
#  'turtles3557',
#  'turtles3562',
#  'turtles3567',
#  'turtles3572',
#  'turtles3577',
#  'turtles3582',
#  'turtles3587',
#  'turtles3592',
#  'turtles3597',
#  'turtles3602',
#  'turtles3607',
#  'turtles3612',
#  'turtles3617',
#  'turtles3622',
#  'turtles3627',
#  'turtles3632',
#  'turtles3637',
#  'turtles3103',
#  'turtles3108',
#  'turtles3113',
#  'turtles3118',
#  'turtles3123',
#  'turtles3128',
#  'turtles3133',
#  'turtles3138',
#  'turtles3143',
#  'turtles3148',
#  'turtles3153',
#  'turtles3158',
#  'turtles3163',
#  'turtles3168',
#  'turtles3173',
#  'turtles3178',
#  'turtles3183',
#  'turtles3188',
#  'turtles3193',
#  'turtles3198',
#  'turtles3203',
#  'turtles3208',
#  'turtles3213',
#  'turtles3218',
#  'turtles3223',
#  'turtles3228',
#  'turtles3233',
#  'turtles3238',
#  'turtles3243',
#  'turtles3248',
#  'turtles3253',
#  'turtles3258',
#  'turtles3263',
#  'turtles3268',
#  'turtles3273',
#  'turtles3278',
#  'turtles3283',
#  'turtles3288',
#  'turtles3293',
#  'turtles3298',
#  'turtles3303',
#  'turtles3308',
#  'turtles3313',
#  'turtles3318',
#  'turtles3323',
#  'turtles3328',
#  'turtles3333',
#  'turtles3338',
#  'turtles3343',
#  'turtles3348',
#  'turtles3353',
#  'turtles3358',
#  'turtles3363',
#  'turtles3368',
#  'turtles3373',
#  'turtles3378',
#  'turtles3383',
#  'turtles3388',
#  'turtles3393',
#  'turtles3398',
#  'turtles3403',
#  'turtles3408',
#  'turtles3413',
#  'turtles3418',
#  'turtles3423',
#  'turtles3428',
#  'turtles3433',
#  'turtles3438',
#  'turtles3443',
#  'turtles3448',
#  'turtles3453',
#  'turtles3458',
#  'turtles3463',
#  'turtles3468',
#  'turtles3473',
#  'turtles3478',
#  'turtles3483',
#  'turtles3488',
#  'turtles3493',
#  'turtles3498',
#  'turtles3503',
#  'turtles3508',
#  'turtles3513',
#  'turtles3518',
#  'turtles3523',
#  'turtles3528',
#  'turtles3533',
#  'turtles3538',
#  'turtles3543',
#  'turtles3548',
#  'turtles3553',
#  'turtles3558',
#  'turtles3563',
#  'turtles3568',
#  'turtles3573',
#  'turtles3578',
#  'turtles3583',
#  'turtles3588',
#  'turtles3593',
#  'turtles3598',
#  'turtles3603',
#  'turtles3608',
#  'turtles3613',
#  'turtles3618',
#  'turtles3623',
#  'turtles3628',
#  'turtles3633',
#  'turtles3638',
#  'turtles3643',
#  'turtles3648',
#  'turtles3653',
#  'turtles3658',
#  'turtles3104',
#  'turtles3109',
#  'turtles3114',
#  'turtles3119',
#  'turtles3124',
#  'turtles3129',
#  'turtles3134',
#  'turtles3139',
#  'turtles3144',
#  'turtles3149',
#  'turtles3154',
#  'turtles3159',
#  'turtles3164',
#  'turtles3169',
#  'turtles3174',
#  'turtles3179',
#  'turtles3184',
#  'turtles3189',
#  'turtles3194',
#  'turtles3199',
#  'turtles3204',
#  'turtles3209',
#  'turtles3214',
#  'turtles3219',
#  'turtles3224',
#  'turtles3229',
#  'turtles3234',
#  'turtles3239',
#  'turtles3244',
#  'turtles3249',
#  'turtles3254',
#  'turtles3259',
#  'turtles3264',
#  'turtles3269',
#  'turtles3274',
#  'turtles3279',
#  'turtles3284',
#  'turtles3289',
#  'turtles3294',
#  'turtles3299',
#  'turtles3304',
#  'turtles3309',
#  'turtles3314',
#  'turtles3319',
#  'turtles3324',
#  'turtles3329',
#  'turtles3334',
#  'turtles3339',
#  'turtles3344',
#  'turtles3349',
#  'turtles3354',
#  'turtles3359',
#  'turtles3364',
#  'turtles3369',
#  'turtles3374',
#  'turtles3379',
#  'turtles3384',
#  'turtles3389',
#  'turtles3394',
#  'turtles3399',
#  'turtles3404',
#  'turtles3409',
#  'turtles3414',
#  'turtles3419',
#  'turtles3424',
#  'turtles3429',
#  'turtles3434',
#  'turtles3439',
#  'turtles3444',
#  'turtles3449',
#  'turtles3454',
#  'turtles3459',
#  'turtles3464',
#  'turtles3469',
#  'turtles3474',
#  'turtles3479',
#  'turtles3484',
#  'turtles3489',
#  'turtles3494',
#  'turtles3499',
#  'turtles3504',
#  'turtles3509',
#  'turtles3514',
#  'turtles3519',
#  'turtles3524',
#  'turtles3529',
#  'turtles3534',
#  'turtles3539',
#  'turtles3544',
#  'turtles3549',
#  'turtles3554',
#  'turtles3559',
#  'turtles3564',
#  'turtles3569',
#  'turtles3574',
#  'turtles3579',
#  'turtles3584',
#  'turtles3589',
#  'turtles3594',
#  'turtles3599',
#  'turtles3604',
#  'turtles3609',
#  'turtles3614',
#  'turtles3619',
#  'turtles3624',
#  'turtles3629',
#  'turtles3634',
#  'turtles3639',
#  'turtles3644',
#  'turtles3649',
#  'turtles3654',
#  'turtles3659',
#  'turtles3664',
#  'turtles3100',
#  'turtles3105',
#  'turtles3110',
#  'turtles3115',
#  'turtles3120',
#  'turtles3125',
#  'turtles3130',
#  'turtles3135',
#  'turtles3140',
#  'turtles3145',
#  'turtles3150',
#  'turtles3155',
#  'turtles3160',
#  'turtles3165',
#  'turtles3170',
#  'turtles3175',
#  'turtles3180',
#  'turtles3185',
#  'turtles3190',
#  'turtles3195',
#  'turtles3200',
#  'turtles3205',
#  'turtles3210',
#  'turtles3215',
#  'turtles3220',
#  'turtles3225',
#  'turtles3230',
#  'turtles3235',
#  'turtles3240',
#  'turtles3245',
#  'turtles3250',
#  'turtles3255',
#  'turtles3260',
#  'turtles3265',
#  'turtles3270',
#  'turtles3275',
#  'turtles3280',
#  'turtles3285',
#  'turtles3290',
#  'turtles3295',
#  'turtles3300',
#  'turtles3305',
#  'turtles3310',
#  'turtles3315',
#  'turtles3320',
#  'turtles3325',
#  'turtles3330',
#  'turtles3335',
#  'turtles3340',
#  'turtles3345',
#  'turtles3350',
#  'turtles3355',
#  'turtles3360',
#  'turtles3365',
#  'turtles3370',
#  'turtles3375',
#  'turtles3380',
#  'turtles3385',
#  'turtles3390',
#  'turtles3395',
#  'turtles3400',
#  'turtles3405',
#  'turtles3410',
#  'turtles3415',
#  'turtles3420',
#  'turtles3425',
#  'turtles3430',
#  'turtles3435',
#  'turtles3440',
#  'turtles3445',
#  'turtles3450',
#  'turtles3455',
#  'turtles3460',
#  'turtles3465',
#  'turtles3470',
#  'turtles3475',
#  'turtles3480',
#  'turtles3485',
#  'turtles3490',
#  'turtles3495',
#  'turtles3500',
#  'turtles3505',
#  'turtles3510',
#  'turtles3515',
#  'turtles3520',
#  'turtles3525',
#  'turtles3530',
#  'turtles3535',
#  'turtles3540',
#  'turtles3545',
#  'turtles3550',
#  'turtles3555',
#  'turtles3560',
#  'turtles3565',
#  'turtles3570',
#  'turtles3575',
#  'turtles3580',
#  'turtles3585',
#  'turtles3590',
#  'turtles3595',
#  'turtles3600',
#  'turtles3605',
#  'turtles3610',
#  'turtles3615',
#  'turtles3620',
#  'turtles3625',
#  'turtles3630',
#  'turtles3635',
#  'turtles3640',
#  'turtles3645',
#  'turtles3650',
#  'turtles3655',
#  'turtles3660',
#  'turtles3665',
#  'turtles3670',
#  'turtles3675',
#  'turtles3680',
#  'turtles3685',
#  'turtles3111',
#  'turtles3116',
#  'turtles3121',
#  'turtles3126',
#  'turtles3131',
#  'turtles3136',
#  'turtles3141',
#  'turtles3146',
#  'turtles3151',
#  'turtles3156',
#  'turtles3161',
#  'turtles3166',
#  'turtles3171',
#  'turtles3176',
#  'turtles3181',
#  'turtles3186',
#  'turtles3191',
#  'turtles3196',
#  'turtles3201',
#  'turtles3206',
#  'turtles3211',
#  'turtles3216',
#  'turtles3221',
#  'turtles3226',
#  'turtles3231',
#  'turtles3236',
#  'turtles3241',
#  'turtles3246',
#  'turtles3251',
#  'turtles3256',
#  'turtles3261',
#  'turtles3266',
#  'turtles3271',
#  'turtles3276',
#  'turtles3281',
#  'turtles3286',
#  'turtles3291',
#  'turtles3296',
#  'turtles3301',
#  'turtles3306',
#  'turtles3311',
#  'turtles3316',
#  'turtles3321',
#  'turtles3326',
#  'turtles3331',
#  'turtles3336',
#  'turtles3341',
#  'turtles3346',
#  'turtles3351',
#  'turtles3356',
#  'turtles3361',
#  'turtles3366',
#  'turtles3371',
#  'turtles3376',
#  'turtles3381',
#  'turtles3386',
#  'turtles3391',
#  'turtles3396',
#  'turtles3401',
#  'turtles3406',
#  'turtles3411',
#  'turtles3416',
#  'turtles3421',
#  'turtles3426',
#  'turtles3431',
#  'turtles3436',
#  'turtles3441',
#  'turtles3446',
#  'turtles3451',
#  'turtles3456',
#  'turtles3461',
#  'turtles3466',
#  'turtles3471',
#  'turtles3476',
#  'turtles3481',
#  'turtles3486',
#  'turtles3491',
#  'turtles3496',
#  'turtles3501',
#  'turtles3506',
#  'turtles3511',
#  'turtles3516',
#  'turtles3521',
#  'turtles3526',
#  'turtles3531',
#  'turtles3536',
#  'turtles3541',
#  'turtles3546',
#  'turtles3551',
#  'turtles3556',
#  'turtles3561',
#  'turtles3566',
#  'turtles3571',
#  'turtles3576',
#  'turtles3581',
#  'turtles3586',
#  'turtles3591',
#  'turtles3596',
#  'turtles3601',
#  'turtles3606',
#  'turtles3611',
#  'turtles3616',
#  'turtles3621',
#  'turtles3626',
#  'turtles3631',
#  'turtles3636',
#  'turtles3641',
#  'turtles3646',
#  'turtles3651',
#  'turtles3656',
#  'turtles3661',
#  'turtles3666',
#  'turtles3671',
#  'turtles3676',
#  'turtles3681',
#  'turtles3686',
#  'turtles3691',
#  'turtles3696',
#  'turtles3701',
#  'turtles3706',
#  'turtles3642',
#  'turtles3647',
#  'turtles3652',
#  'turtles3657',
#  'turtles3662',
#  'turtles3667',
#  'turtles3672',
#  'turtles3677',
#  'turtles3682',
#  'turtles3687',
#  'turtles3692',
#  'turtles3697',
#  'turtles3702',
#  'turtles3707',
#  'turtles3712',
#  'turtles3717',
#  'turtles3722',
#  'turtles3727',
#  'turtles3732',
#  'turtles3737',
#  'turtles3742',
#  'turtles3747',
#  'turtles3752',
#  'turtles3757',
#  'turtles3762',
#  'turtles3767',
#  'turtles3772',
#  'turtles3777',
#  'turtles3782',
#  'turtles3787',
#  'turtles3792',
#  'turtles3797',
#  'turtles3802',
#  'turtles3807',
#  'turtles3812',
#  'turtles3817',
#  'turtles3822',
#  'turtles3827',
#  'turtles3832',
#  'turtles3837',
#  'turtles3842',
#  'turtles3847',
#  'turtles3852',
#  'turtles3857',
#  'turtles3862',
#  'turtles3867',
#  'turtles3872',
#  'turtles3877',
#  'turtles3882',
#  'turtles3887',
#  'turtles3892',
#  'turtles3897',
#  'turtles3902',
#  'turtles3907',
#  'turtles3912',
#  'turtles3917',
#  'turtles3922',
#  'turtles3927',
#  'turtles3932',
#  'turtles3937',
#  'turtles3942',
#  'turtles3947',
#  'turtles3952',
#  'turtles3957',
#  'turtles3962',
#  'turtles3967',
#  'turtles3972',
#  'turtles3977',
#  'turtles3982',
#  'turtles3987',
#  'turtles3992',
#  'turtles3997',
#  'turtles4002',
#  'turtles4007',
#  'turtles4012',
#  'turtles4017',
#  'turtles4022',
#  'turtles4027',
#  'turtles4032',
#  'turtles4037',
#  'turtles4042',
#  'turtles4047',
#  'turtles4052',
#  'turtles4057',
#  'turtles4062',
#  'turtles4067',
#  'turtles4072',
#  'turtles4077',
#  'turtles4082',
#  'turtles4087',
#  'turtles4092',
#  'turtles4097',
#  'turtles3663',
#  'turtles3668',
#  'turtles3673',
#  'turtles3678',
#  'turtles3683',
#  'turtles3688',
#  'turtles3693',
#  'turtles3698',
#  'turtles3703',
#  'turtles3708',
#  'turtles3713',
#  'turtles3718',
#  'turtles3723',
#  'turtles3728',
#  'turtles3733',
#  'turtles3738',
#  'turtles3743',
#  'turtles3748',
#  'turtles3753',
#  'turtles3758',
#  'turtles3763',
#  'turtles3768',
#  'turtles3773',
#  'turtles3778',
#  'turtles3783',
#  'turtles3788',
#  'turtles3793',
#  'turtles3798',
#  'turtles3803',
#  'turtles3808',
#  'turtles3813',
#  'turtles3818',
#  'turtles3823',
#  'turtles3828',
#  'turtles3833',
#  'turtles3838',
#  'turtles3843',
#  'turtles3848',
#  'turtles3853',
#  'turtles3858',
#  'turtles3863',
#  'turtles3868',
#  'turtles3873',
#  'turtles3878',
#  'turtles3883',
#  'turtles3888',
#  'turtles3893',
#  'turtles3898',
#  'turtles3903',
#  'turtles3908',
#  'turtles3913',
#  'turtles3918',
#  'turtles3923',
#  'turtles3928',
#  'turtles3933',
#  'turtles3938',
#  'turtles3943',
#  'turtles3948',
#  'turtles3953',
#  'turtles3958',
#  'turtles3963',
#  'turtles3968',
#  'turtles3973',
#  'turtles3978',
#  'turtles3983',
#  'turtles3988',
#  'turtles3993',
#  'turtles3998',
#  'turtles4003',
#  'turtles4008',
#  'turtles4013',
#  'turtles4018',
#  'turtles4023',
#  'turtles4028',
#  'turtles4033',
#  'turtles4038',
#  'turtles4043',
#  'turtles4048',
#  'turtles4053',
#  'turtles4058',
#  'turtles4063',
#  'turtles4068',
#  'turtles4073',
#  'turtles4078',
#  'turtles4083',
#  'turtles4088',
#  'turtles4093',
#  'turtles4098',
#  'turtles3669',
#  'turtles3674',
#  'turtles3679',
#  'turtles3684',
#  'turtles3689',
#  'turtles3694',
#  'turtles3699',
#  'turtles3704',
#  'turtles3709',
#  'turtles3714',
#  'turtles3719',
#  'turtles3724',
#  'turtles3729',
#  'turtles3734',
#  'turtles3739',
#  'turtles3744',
#  'turtles3749',
#  'turtles3754',
#  'turtles3759',
#  'turtles3764',
#  'turtles3769',
#  'turtles3774',
#  'turtles3779',
#  'turtles3784',
#  'turtles3789',
#  'turtles3794',
#  'turtles3799',
#  'turtles3804',
#  'turtles3809',
#  'turtles3814',
#  'turtles3819',
#  'turtles3824',
#  'turtles3829',
#  'turtles3834',
#  'turtles3839',
#  'turtles3844',
#  'turtles3849',
#  'turtles3854',
#  'turtles3859',
#  'turtles3864',
#  'turtles3869',
#  'turtles3874',
#  'turtles3879',
#  'turtles3884',
#  'turtles3889',
#  'turtles3894',
#  'turtles3899',
#  'turtles3904',
#  'turtles3909',
#  'turtles3914',
#  'turtles3919',
#  'turtles3924',
#  'turtles3929',
#  'turtles3934',
#  'turtles3939',
#  'turtles3944',
#  'turtles3949',
#  'turtles3954',
#  'turtles3959',
#  'turtles3964',
#  'turtles3969',
#  'turtles3974',
#  'turtles3979',
#  'turtles3984',
#  'turtles3989',
#  'turtles3994',
#  'turtles3999',
#  'turtles4004',
#  'turtles4009',
#  'turtles4014',
#  'turtles4019',
#  'turtles4024',
#  'turtles4029',
#  'turtles4034',
#  'turtles4039',
#  'turtles4044',
#  'turtles4049',
#  'turtles4054',
#  'turtles4059',
#  'turtles4064',
#  'turtles4069',
#  'turtles4074',
#  'turtles4079',
#  'turtles4084',
#  'turtles4089',
#  'turtles4094',
#  'turtles4099',
#  'turtles3690',
#  'turtles3695',
#  'turtles3700',
#  'turtles3705',
#  'turtles3710',
#  'turtles3715',
#  'turtles3720',
#  'turtles3725',
#  'turtles3730',
#  'turtles3735',
#  'turtles3740',
#  'turtles3745',
#  'turtles3750',
#  'turtles3755',
#  'turtles3760',
#  'turtles3765',
#  'turtles3770',
#  'turtles3775',
#  'turtles3780',
#  'turtles3785',
#  'turtles3790',
#  'turtles3795',
#  'turtles3800',
#  'turtles3805',
#  'turtles3810',
#  'turtles3815',
#  'turtles3820',
#  'turtles3825',
#  'turtles3830',
#  'turtles3835',
#  'turtles3840',
#  'turtles3845',
#  'turtles3850',
#  'turtles3855',
#  'turtles3860',
#  'turtles3865',
#  'turtles3870',
#  'turtles3875',
#  'turtles3880',
#  'turtles3885',
#  'turtles3890',
#  'turtles3895',
#  'turtles3900',
#  'turtles3905',
#  'turtles3910',
#  'turtles3915',
#  'turtles3920',
#  'turtles3925',
#  'turtles3930',
#  'turtles3935',
#  'turtles3940',
#  'turtles3945',
#  'turtles3950',
#  'turtles3955',
#  'turtles3960',
#  'turtles3965',
#  'turtles3970',
#  'turtles3975',
#  'turtles3980',
#  'turtles3985',
#  'turtles3990',
#  'turtles3995',
#  'turtles4000',
#  'turtles4005',
#  'turtles4010',
#  'turtles4015',
#  'turtles4020',
#  'turtles4025',
#  'turtles4030',
#  'turtles4035',
#  'turtles4040',
#  'turtles4045',
#  'turtles4050',
#  'turtles4055',
#  'turtles4060',
#  'turtles4065',
#  'turtles4070',
#  'turtles4075',
#  'turtles4080',
#  'turtles4085',
#  'turtles4090',
#  'turtles4095',
#  'turtles3711',
#  'turtles3716',
#  'turtles3721',
#  'turtles3726',
#  'turtles3731',
#  'turtles3736',
#  'turtles3741',
#  'turtles3746',
#  'turtles3751',
#  'turtles3756',
#  'turtles3761',
#  'turtles3766',
#  'turtles3771',
#  'turtles3776',
#  'turtles3781',
#  'turtles3786',
#  'turtles3791',
#  'turtles3796',
#  'turtles3801',
#  'turtles3806',
#  'turtles3811',
#  'turtles3816',
#  'turtles3821',
#  'turtles3826',
#  'turtles3831',
#  'turtles3836',
#  'turtles3841',
#  'turtles3846',
#  'turtles3851',
#  'turtles3856',
#  'turtles3861',
#  'turtles3866',
#  'turtles3871',
#  'turtles3876',
#  'turtles3881',
#  'turtles3886',
#  'turtles3891',
#  'turtles3896',
#  'turtles3901',
#  'turtles3906',
#  'turtles3911',
#  'turtles3916',
#  'turtles3921',
#  'turtles3926',
#  'turtles3931',
#  'turtles3936',
#  'turtles3941',
#  'turtles3946',
#  'turtles3951',
#  'turtles3956',
#  'turtles3961',
#  'turtles3966',
#  'turtles3971',
#  'turtles3976',
#  'turtles3981',
#  'turtles3986',
#  'turtles3991',
#  'turtles3996',
#  'turtles4001',
#  'turtles4006',
#  'turtles4011',
#  'turtles4016',
#  'turtles4021',
#  'turtles4026',
#  'turtles4031',
#  'turtles4036',
#  'turtles4041',
#  'turtles4046',
#  'turtles4051',
#  'turtles4056',
#  'turtles4061',
#  'turtles4066',
#  'turtles4071',
#  'turtles4076',
#  'turtles4081',
#  'turtles4086',
#  'turtles4091',
#  'turtles4096']

# %% [markdown]
# ## 4 - Fonction de génération des requêtes

# %%
# Fonction pour générer toutes les requêtes d'un utilisateur 
def all_requests_1user(user_name,max_requetes,max_jours,threshold_city,threshold_language) : 
    # initialisation dataframe pour stocker la liste des requêtes + définir le nombre de requêtes faites : 
    df_user = pd.DataFrame()
    nb_requetes = random.randint(1,max_requetes)

    # Enregistrement du user_name sur toutes les lignes du df
    df_user["avatar_name"] = [user_name]*nb_requetes
    
    # Attribution d'une date 
    #--Choix des bornes 
    dates = np.sort(random.choices(list(range(max_jours)), k = nb_requetes))[::-1]
    df_user["date"] = dates
        
    # Attribution de la ville 
    city_user = random.choice(city) 
    prob = np.random.uniform(0,1,nb_requetes)
    vect_city = pd.Series([""]*nb_requetes)
    
    vect_city[prob >= threshold_city] = city_user
    vect_city[prob < threshold_city] = random.choice(city) 
    df_user["city"] = vect_city
    
    # Attribution de la langue : 
    # 1. une langue pour l'utilisateur :
    language_user = random.choice(language) 
    vect_language = pd.Series([language_user]*nb_requetes)
    
    # 2. remplacer cette langue par une langue similaire ? 
    if language_user in dic_similar_language : 
        prob = np.random.uniform(0,1,nb_requetes)
        ind = np.where(prob<=threshold_language)[0]
        vect_language[ind] = random.choice(dic_similar_language[language_user])
    
    # 3. remplacer cette langue par la langue du pays dans lequel l'utilisateur se rend ? 
    prob = np.random.uniform(0,1,nb_requetes)
    ind = np.where(prob<=threshold_language)[0]
    vect_language[ind] = dic_language_country[vect_city[ind]]
    df_user["language"] = vect_language
    
    # Attribution du mobile 
    df_user["mobile"] = random.choices([0,1],k=nb_requetes)
    return df_user

#Test
#df1 = all_requests_1user("turtles0",max_requetes,max_jours,threshold_city,threshold_language)

# %%
# Fonction pour créer un df pour stocker toutes les requêtes de tous les  utilisateurs 
def all_requests_all_users(nb_users,names,max_requetes,max_jours,threshold_city,threshold_language) : 
    df = pd.DataFrame(columns=np.r_[["avatar_name"],request_var])
    for i in range(nb_users) :
        print(i)
        # génération d'un df par user 
        df_1user = all_requests_1user(names[i],max_requetes,max_jours,threshold_city,threshold_language)
        # concaténation de tous les dataframes en un seul
        df = pd.concat([df,df_1user],ignore_index=True)
    return df 

#Test 
#df = all_requests_all_users(nb_users,names,max_requetes,max_jours,threshold_city,threshold_language)

# %%
#Sauvegarde des toutes nos prochaines requêtes 
# A NE PAS RUN
#df = all_requests_all_users(1000,names[3101:],max_requetes,max_jours,threshold_city,threshold_language) 
df.to_csv('data/stock_requetes/data_requests5.csv', index=False)

# %%
df = pd.read_csv('data/stock_requetes/data_requests5.csv')

# %%
len(np.unique(df["avatar_name"]))
# Out:
# 1000

# %% [markdown]
# ## 5 - Fonctions pour la mise en forme des données

# %%
# Transformer les requêtes (dictionnaire) en df 
def request_to_df(dic_request):
    # dataframe contenant le résultat de la requête : 
    df_prices = pd.DataFrame.from_dict(dic_request['prices'])

    # dataframe contenant les infos de la requête (que l'on dupplique pour avoir le même nombre de ligne) :
    df_1request = pd.DataFrame.from_dict([dic_request['request']])
    df_1request = pd.DataFrame(np.repeat(df_1request.values, len(df_prices.index), axis=0),columns=df_1request.columns)
    cols = list(df_1request.columns)
    cols = [cols[-1]] + cols[:-1]
    df_1request = df_1request[cols]

    # dataframe final pour un avatar ayant fait une requête : 
    df_1avatar = pd.concat([df_1request,df_prices],axis=1)
    
    return df_1avatar

#Test
#df_1avatar = request_to_df(test)

# 2. fonction pour concaténer les dataframes de plusieurs requêtes : 
def request_to_final_df(list_df) : 
    return pd.concat(list_df,axis=0,ignore_index=True)

#Test
#df_2avatar = request_to_final_df([df_1avatar,df_1avatar])

# 3. fonction pour transformer notre dataframe avec la liste des requêtes à faire en dict :

def request_to_dict(csv_file,ind_request) :
    # get the list of request we want to do : 
    data = pd.read_csv(csv_file)
    data2 = copy.deepcopy(data.iloc[ind_request])
    # associate avatar name to each request and order the columns : 
    # data2["avatar_name"] = names 
    cols = list(data2.columns)
    cols = [cols[-1]] + cols[:-1]
    data2 = data2[cols]
    # convert df to dict : 
    dic = data2.to_dict('records')
    return dic

#Test
#dic = request_to_dict('stock_requetes/data_requests1.csv',range(0,10))

# %% [markdown]
# ## Requêtes

# %% [markdown]
# Pour connaître le nombre de requêtes restantes, il faut taper dans une barre de recherche :
# `http://51.91.251.0:3000/remaining-requests/82a030f2-958a-4824-8ee0-85cde6f5668c`

# %%
user_id = '82a030f2-958a-4824-8ee0-85cde6f5668c'

# %%
#REPRENDRE le 26/11/2022 dès 15h05 :) 
#data_requests3 : reprendre à partir de 390 si temps 
start = 500
end = 1000

# Création du dictionnaire pour les requêtes
dictio = request_to_dict('data/stock_requetes/data_requests5.csv',range(start,end))
stock_json = []
stock_df = []
for params in dictio : 
    print(params)
    """r2 = requests.get(path(f"pricing/{user_id}"), params=params)
    stock_json.append(r2.json())
    stock_df.append(request_to_df(r2.json()))"""
# Out:
# {'mobile': 0, 'avatar_name': 'turtles3346', 'language': 'czech', 'city': 'madrid', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles3351', 'language': 'croatian', 'city': 'vilnius', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles3356', 'language': 'danish', 'city': 'rome', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles3361', 'language': 'french', 'city': 'rome', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles3366', 'language': 'french', 'city': 'vienna', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles3371', 'language': 'hungarian', 'city': 'sofia', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles3376', 'language': 'finnish', 'city': 'sofia', 'date': 24}
# {'mobile': 1, 'avatar_name': 'turtles3381', 'language': 'lithuanian', 'city': 'vienna', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles3386', 'language': 'slovakian', 'city': 'rome', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles3391', 'language': 'italian', 'city': 'amsterdam', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles3396', 'language': 'slovene', 'city': 'valletta', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles3401', 'language': 'estonian', 'city': 'vienna', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles3406', 'language': 'polish', 'city': 'paris', 'date': 10}
# {'mobile': 0, 'avatar_name': 'turtles3411', 'language': 'dutch', 'city': 'vilnius', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles3416', 'language': 'irish', 'city': 'amsterdam', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles3421', 'language': 'belgian', 'city': 'vilnius', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles3426', 'language': 'greek', 'city': 'madrid', 'date': 3}
# {'mobile': 0, 'avatar_name': 'turtles3431', 'language': 'polish', 'city': 'madrid', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles3436', 'language': 'bulgarian', 'city': 'sofia', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles3441', 'language': 'austrian', 'city': 'paris', 'date': 17}
# {'mobile': 0, 'avatar_name': 'turtles3446', 'language': 'austrian', 'city': 'sofia', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles3451', 'language': 'czech', 'city': 'madrid', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles3456', 'language': 'cypriot', 'city': 'vilnius', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles3461', 'language': 'lithuanian', 'city': 'madrid', 'date': 1}
# {'mobile': 0, 'avatar_name': 'turtles3466', 'language': 'italian', 'city': 'paris', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles3471', 'language': 'dutch', 'city': 'vilnius', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles3476', 'language': 'dutch', 'city': 'copenhagen', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles3481', 'language': 'estonian', 'city': 'copenhagen', 'date': 0}
# {'mobile': 1, 'avatar_name': 'turtles3486', 'language': 'latvian', 'city': 'copenhagen', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles3491', 'language': 'swedish', 'city': 'copenhagen', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles3496', 'language': 'latvian', 'city': 'copenhagen', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles3501', 'language': 'german', 'city': 'madrid', 'date': 38}
# {'mobile': 0, 'avatar_name': 'turtles3506', 'language': 'bulgarian', 'city': 'vilnius', 'date': 2}
# {'mobile': 1, 'avatar_name': 'turtles3511', 'language': 'belgian', 'city': 'copenhagen', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles3516', 'language': 'finnish', 'city': 'paris', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles3521', 'language': 'french', 'city': 'valletta', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles3526', 'language': 'slovene', 'city': 'paris', 'date': 17}
# {'mobile': 0, 'avatar_name': 'turtles3531', 'language': 'maltese', 'city': 'vienna', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles3536', 'language': 'estonian', 'city': 'sofia', 'date': 1}
# {'mobile': 0, 'avatar_name': 'turtles3541', 'language': 'bulgarian', 'city': 'sofia', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles3546', 'language': 'irish', 'city': 'amsterdam', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles3551', 'language': 'cypriot', 'city': 'madrid', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles3556', 'language': 'latvian', 'city': 'madrid', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles3561', 'language': 'italian', 'city': 'valletta', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles3566', 'language': 'lithuanian', 'city': 'valletta', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles3571', 'language': 'finnish', 'city': 'vilnius', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles3576', 'language': 'maltese', 'city': 'valletta', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles3581', 'language': 'portuguese', 'city': 'vilnius', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles3586', 'language': 'portuguese', 'city': 'amsterdam', 'date': 2}
# {'mobile': 1, 'avatar_name': 'turtles3591', 'language': 'irish', 'city': 'copenhagen', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles3596', 'language': 'hungarian', 'city': 'madrid', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles3601', 'language': 'french', 'city': 'valletta', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles3606', 'language': 'irish', 'city': 'sofia', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles3611', 'language': 'slovene', 'city': 'amsterdam', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles3616', 'language': 'estonian', 'city': 'madrid', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles3621', 'language': 'estonian', 'city': 'copenhagen', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles3626', 'language': 'spanish', 'city': 'amsterdam', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles3631', 'language': 'swedish', 'city': 'vienna', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles3636', 'language': 'danish', 'city': 'madrid', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles3641', 'language': 'austrian', 'city': 'paris', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles3646', 'language': 'croatian', 'city': 'sofia', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles3651', 'language': 'czech', 'city': 'vilnius', 'date': 13}
# {'mobile': 1, 'avatar_name': 'turtles3656', 'language': 'polish', 'city': 'vienna', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles3661', 'language': 'lithuanian', 'city': 'madrid', 'date': 7}
# {'mobile': 1, 'avatar_name': 'turtles3666', 'language': 'danish', 'city': 'valletta', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles3671', 'language': 'romanian', 'city': 'copenhagen', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles3676', 'language': 'croatian', 'city': 'vienna', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles3681', 'language': 'italian', 'city': 'valletta', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles3686', 'language': 'polish', 'city': 'amsterdam', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles3691', 'language': 'belgian', 'city': 'valletta', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles3696', 'language': 'maltese', 'city': 'amsterdam', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles3701', 'language': 'belgian', 'city': 'valletta', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles3706', 'language': 'cypriot', 'city': 'copenhagen', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles3642', 'language': 'luxembourgish', 'city': 'paris', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles3647', 'language': 'cypriot', 'city': 'paris', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles3652', 'language': 'portuguese', 'city': 'copenhagen', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles3657', 'language': 'polish', 'city': 'rome', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles3662', 'language': 'bulgarian', 'city': 'paris', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles3667', 'language': 'french', 'city': 'paris', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles3672', 'language': 'italian', 'city': 'vilnius', 'date': 13}
# {'mobile': 1, 'avatar_name': 'turtles3677', 'language': 'bulgarian', 'city': 'copenhagen', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles3682', 'language': 'spanish', 'city': 'sofia', 'date': 11}
# {'mobile': 0, 'avatar_name': 'turtles3687', 'language': 'greek', 'city': 'madrid', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles3692', 'language': 'greek', 'city': 'paris', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles3697', 'language': 'luxembourgish', 'city': 'sofia', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles3702', 'language': 'german', 'city': 'rome', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles3707', 'language': 'portuguese', 'city': 'copenhagen', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles3712', 'language': 'swedish', 'city': 'sofia', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles3717', 'language': 'austrian', 'city': 'paris', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles3722', 'language': 'spanish', 'city': 'copenhagen', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles3727', 'language': 'czech', 'city': 'madrid', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles3732', 'language': 'dutch', 'city': 'amsterdam', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles3737', 'language': 'latvian', 'city': 'valletta', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles3742', 'language': 'cypriot', 'city': 'vilnius', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles3747', 'language': 'portuguese', 'city': 'sofia', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3752', 'language': 'lithuanian', 'city': 'valletta', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles3757', 'language': 'slovene', 'city': 'madrid', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles3762', 'language': 'dutch', 'city': 'vilnius', 'date': 11}
# {'mobile': 0, 'avatar_name': 'turtles3767', 'language': 'dutch', 'city': 'sofia', 'date': 7}
# {'mobile': 1, 'avatar_name': 'turtles3772', 'language': 'greek', 'city': 'valletta', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles3777', 'language': 'french', 'city': 'vilnius', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3782', 'language': 'dutch', 'city': 'amsterdam', 'date': 10}
# {'mobile': 0, 'avatar_name': 'turtles3787', 'language': 'danish', 'city': 'rome', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles3792', 'language': 'swedish', 'city': 'valletta', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles3797', 'language': 'dutch', 'city': 'copenhagen', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles3802', 'language': 'dutch', 'city': 'vienna', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles3807', 'language': 'lithuanian', 'city': 'vilnius', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles3812', 'language': 'czech', 'city': 'madrid', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles3817', 'language': 'slovene', 'city': 'copenhagen', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles3822', 'language': 'lithuanian', 'city': 'sofia', 'date': 22}
# {'mobile': 0, 'avatar_name': 'turtles3827', 'language': 'lithuanian', 'city': 'paris', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles3832', 'language': 'polish', 'city': 'rome', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles3837', 'language': 'polish', 'city': 'copenhagen', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles3842', 'language': 'spanish', 'city': 'madrid', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles3847', 'language': 'italian', 'city': 'madrid', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles3852', 'language': 'italian', 'city': 'vilnius', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles3857', 'language': 'german', 'city': 'paris', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles3862', 'language': 'french', 'city': 'rome', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3867', 'language': 'austrian', 'city': 'vienna', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles3872', 'language': 'lithuanian', 'city': 'paris', 'date': 25}
# {'mobile': 0, 'avatar_name': 'turtles3877', 'language': 'bulgarian', 'city': 'sofia', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles3882', 'language': 'estonian', 'city': 'paris', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles3887', 'language': 'bulgarian', 'city': 'vienna', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles3892', 'language': 'danish', 'city': 'valletta', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles3897', 'language': 'dutch', 'city': 'sofia', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles3902', 'language': 'french', 'city': 'rome', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles3907', 'language': 'italian', 'city': 'sofia', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles3912', 'language': 'slovene', 'city': 'paris', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles3917', 'language': 'estonian', 'city': 'paris', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles3922', 'language': 'estonian', 'city': 'vienna', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles3927', 'language': 'french', 'city': 'valletta', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles3932', 'language': 'czech', 'city': 'valletta', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles3937', 'language': 'german', 'city': 'paris', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles3942', 'language': 'cypriot', 'city': 'vilnius', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles3947', 'language': 'portuguese', 'city': 'copenhagen', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles3952', 'language': 'swedish', 'city': 'copenhagen', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles3957', 'language': 'slovakian', 'city': 'paris', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles3962', 'language': 'portuguese', 'city': 'madrid', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles3967', 'language': 'slovene', 'city': 'rome', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles3972', 'language': 'romanian', 'city': 'madrid', 'date': 1}
# {'mobile': 0, 'avatar_name': 'turtles3977', 'language': 'lithuanian', 'city': 'madrid', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3982', 'language': 'estonian', 'city': 'madrid', 'date': 42}
# {'mobile': 1, 'avatar_name': 'turtles3987', 'language': 'czech', 'city': 'sofia', 'date': 17}
# {'mobile': 0, 'avatar_name': 'turtles3992', 'language': 'bulgarian', 'city': 'copenhagen', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles3997', 'language': 'portuguese', 'city': 'copenhagen', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles4002', 'language': 'french', 'city': 'paris', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles4007', 'language': 'maltese', 'city': 'valletta', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles4012', 'language': 'hungarian', 'city': 'paris', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles4017', 'language': 'luxembourgish', 'city': 'paris', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles4022', 'language': 'italian', 'city': 'amsterdam', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles4027', 'language': 'hungarian', 'city': 'copenhagen', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles4032', 'language': 'czech', 'city': 'vilnius', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles4037', 'language': 'german', 'city': 'vilnius', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles4042', 'language': 'hungarian', 'city': 'sofia', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles4047', 'language': 'swedish', 'city': 'copenhagen', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles4052', 'language': 'polish', 'city': 'vienna', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles4057', 'language': 'finnish', 'city': 'copenhagen', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles4062', 'language': 'lithuanian', 'city': 'madrid', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles4067', 'language': 'danish', 'city': 'copenhagen', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles4072', 'language': 'slovene', 'city': 'madrid', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles4077', 'language': 'slovene', 'city': 'sofia', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles4082', 'language': 'swedish', 'city': 'vienna', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles4087', 'language': 'estonian', 'city': 'rome', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles4092', 'language': 'belgian', 'city': 'valletta', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles4097', 'language': 'spanish', 'city': 'paris', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles3663', 'language': 'latvian', 'city': 'valletta', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles3668', 'language': 'danish', 'city': 'rome', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles3673', 'language': 'greek', 'city': 'sofia', 'date': 24}
# {'mobile': 1, 'avatar_name': 'turtles3678', 'language': 'irish', 'city': 'madrid', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles3683', 'language': 'czech', 'city': 'copenhagen', 'date': 25}
# {'mobile': 0, 'avatar_name': 'turtles3688', 'language': 'bulgarian', 'city': 'sofia', 'date': 13}
# {'mobile': 1, 'avatar_name': 'turtles3693', 'language': 'french', 'city': 'paris', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles3698', 'language': 'finnish', 'city': 'paris', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles3703', 'language': 'belgian', 'city': 'paris', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles3708', 'language': 'cypriot', 'city': 'sofia', 'date': 38}
# {'mobile': 0, 'avatar_name': 'turtles3713', 'language': 'danish', 'city': 'amsterdam', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles3718', 'language': 'dutch', 'city': 'vilnius', 'date': 12}
# {'mobile': 1, 'avatar_name': 'turtles3723', 'language': 'spanish', 'city': 'vilnius', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles3728', 'language': 'maltese', 'city': 'valletta', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles3733', 'language': 'swedish', 'city': 'paris', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles3738', 'language': 'cypriot', 'city': 'copenhagen', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles3743', 'language': 'slovene', 'city': 'amsterdam', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles3748', 'language': 'italian', 'city': 'rome', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles3753', 'language': 'swedish', 'city': 'copenhagen', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles3758', 'language': 'maltese', 'city': 'paris', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles3763', 'language': 'french', 'city': 'vilnius', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles3768', 'language': 'spanish', 'city': 'copenhagen', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles3773', 'language': 'maltese', 'city': 'rome', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles3778', 'language': 'german', 'city': 'rome', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles3783', 'language': 'portuguese', 'city': 'paris', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles3788', 'language': 'hungarian', 'city': 'vilnius', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles3793', 'language': 'bulgarian', 'city': 'sofia', 'date': 13}
# {'mobile': 1, 'avatar_name': 'turtles3798', 'language': 'bulgarian', 'city': 'sofia', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles3803', 'language': 'maltese', 'city': 'valletta', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles3808', 'language': 'swedish', 'city': 'valletta', 'date': 22}
# {'mobile': 0, 'avatar_name': 'turtles3813', 'language': 'maltese', 'city': 'madrid', 'date': 0}
# {'mobile': 1, 'avatar_name': 'turtles3818', 'language': 'hungarian', 'city': 'rome', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles3823', 'language': 'irish', 'city': 'vilnius', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles3828', 'language': 'spanish', 'city': 'valletta', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles3833', 'language': 'finnish', 'city': 'sofia', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3838', 'language': 'hungarian', 'city': 'amsterdam', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles3843', 'language': 'estonian', 'city': 'copenhagen', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles3848', 'language': 'slovene', 'city': 'copenhagen', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles3853', 'language': 'finnish', 'city': 'valletta', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles3858', 'language': 'lithuanian', 'city': 'rome', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles3863', 'language': 'czech', 'city': 'sofia', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles3868', 'language': 'french', 'city': 'madrid', 'date': 13}
# {'mobile': 1, 'avatar_name': 'turtles3873', 'language': 'swedish', 'city': 'valletta', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles3878', 'language': 'danish', 'city': 'vilnius', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles3883', 'language': 'greek', 'city': 'madrid', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles3888', 'language': 'italian', 'city': 'copenhagen', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles3893', 'language': 'luxembourgish', 'city': 'copenhagen', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles3898', 'language': 'dutch', 'city': 'amsterdam', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles3903', 'language': 'latvian', 'city': 'paris', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles3908', 'language': 'cypriot', 'city': 'madrid', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles3913', 'language': 'maltese', 'city': 'paris', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles3918', 'language': 'spanish', 'city': 'vilnius', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles3923', 'language': 'slovakian', 'city': 'vilnius', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles3928', 'language': 'czech', 'city': 'madrid', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles3933', 'language': 'finnish', 'city': 'paris', 'date': 26}
# {'mobile': 1, 'avatar_name': 'turtles3938', 'language': 'finnish', 'city': 'madrid', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles3943', 'language': 'german', 'city': 'paris', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles3948', 'language': 'hungarian', 'city': 'madrid', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles3953', 'language': 'latvian', 'city': 'paris', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles3958', 'language': 'belgian', 'city': 'vilnius', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles3963', 'language': 'cypriot', 'city': 'valletta', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles3968', 'language': 'maltese', 'city': 'vienna', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles3973', 'language': 'greek', 'city': 'sofia', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles3978', 'language': 'irish', 'city': 'vilnius', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles3983', 'language': 'greek', 'city': 'copenhagen', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles3988', 'language': 'slovene', 'city': 'copenhagen', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles3993', 'language': 'italian', 'city': 'copenhagen', 'date': 11}
# {'mobile': 0, 'avatar_name': 'turtles3998', 'language': 'french', 'city': 'madrid', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles4003', 'language': 'czech', 'city': 'vilnius', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles4008', 'language': 'czech', 'city': 'madrid', 'date': 12}
# {'mobile': 1, 'avatar_name': 'turtles4013', 'language': 'dutch', 'city': 'amsterdam', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles4018', 'language': 'bulgarian', 'city': 'copenhagen', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles4023', 'language': 'latvian', 'city': 'rome', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles4028', 'language': 'greek', 'city': 'rome', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles4033', 'language': 'hungarian', 'city': 'paris', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles4038', 'language': 'estonian', 'city': 'valletta', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles4043', 'language': 'maltese', 'city': 'paris', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles4048', 'language': 'greek', 'city': 'amsterdam', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles4053', 'language': 'austrian', 'city': 'vienna', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles4058', 'language': 'portuguese', 'city': 'vilnius', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles4063', 'language': 'german', 'city': 'paris', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles4068', 'language': 'luxembourgish', 'city': 'vienna', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles4073', 'language': 'french', 'city': 'paris', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles4078', 'language': 'luxembourgish', 'city': 'vienna', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles4083', 'language': 'irish', 'city': 'madrid', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles4088', 'language': 'irish', 'city': 'vilnius', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles4093', 'language': 'czech', 'city': 'valletta', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles4098', 'language': 'lithuanian', 'city': 'amsterdam', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles3669', 'language': 'finnish', 'city': 'sofia', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles3674', 'language': 'italian', 'city': 'sofia', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles3679', 'language': 'danish', 'city': 'rome', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles3684', 'language': 'irish', 'city': 'vienna', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles3689', 'language': 'romanian', 'city': 'madrid', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles3694', 'language': 'maltese', 'city': 'vilnius', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles3699', 'language': 'latvian', 'city': 'vienna', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles3704', 'language': 'hungarian', 'city': 'amsterdam', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles3709', 'language': 'finnish', 'city': 'madrid', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles3714', 'language': 'latvian', 'city': 'vienna', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3719', 'language': 'austrian', 'city': 'vienna', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3724', 'language': 'czech', 'city': 'vienna', 'date': 16}
# {'mobile': 1, 'avatar_name': 'turtles3729', 'language': 'estonian', 'city': 'paris', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles3734', 'language': 'danish', 'city': 'rome', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles3739', 'language': 'slovene', 'city': 'amsterdam', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles3744', 'language': 'irish', 'city': 'madrid', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles3749', 'language': 'maltese', 'city': 'amsterdam', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3754', 'language': 'latvian', 'city': 'valletta', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles3759', 'language': 'slovakian', 'city': 'vienna', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles3764', 'language': 'austrian', 'city': 'rome', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3769', 'language': 'danish', 'city': 'vilnius', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles3774', 'language': 'french', 'city': 'sofia', 'date': 11}
# {'mobile': 0, 'avatar_name': 'turtles3779', 'language': 'danish', 'city': 'valletta', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles3784', 'language': 'swedish', 'city': 'sofia', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles3789', 'language': 'greek', 'city': 'vilnius', 'date': 3}
# {'mobile': 0, 'avatar_name': 'turtles3794', 'language': 'spanish', 'city': 'vilnius', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles3799', 'language': 'danish', 'city': 'copenhagen', 'date': 25}
# {'mobile': 0, 'avatar_name': 'turtles3804', 'language': 'bulgarian', 'city': 'vienna', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles3809', 'language': 'irish', 'city': 'amsterdam', 'date': 15}
# {'mobile': 0, 'avatar_name': 'turtles3814', 'language': 'dutch', 'city': 'paris', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles3819', 'language': 'french', 'city': 'rome', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles3824', 'language': 'finnish', 'city': 'madrid', 'date': 7}
# {'mobile': 1, 'avatar_name': 'turtles3829', 'language': 'lithuanian', 'city': 'vilnius', 'date': 10}
# {'mobile': 0, 'avatar_name': 'turtles3834', 'language': 'spanish', 'city': 'madrid', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles3839', 'language': 'estonian', 'city': 'amsterdam', 'date': 31}
# {'mobile': 1, 'avatar_name': 'turtles3844', 'language': 'german', 'city': 'vienna', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles3849', 'language': 'estonian', 'city': 'amsterdam', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles3854', 'language': 'swedish', 'city': 'valletta', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles3859', 'language': 'cypriot', 'city': 'rome', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles3864', 'language': 'czech', 'city': 'copenhagen', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles3869', 'language': 'dutch', 'city': 'sofia', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3874', 'language': 'lithuanian', 'city': 'valletta', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3879', 'language': 'portuguese', 'city': 'valletta', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles3884', 'language': 'portuguese', 'city': 'copenhagen', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles3889', 'language': 'dutch', 'city': 'sofia', 'date': 19}
# {'mobile': 0, 'avatar_name': 'turtles3894', 'language': 'belgian', 'city': 'sofia', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles3899', 'language': 'cypriot', 'city': 'paris', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles3904', 'language': 'slovakian', 'city': 'valletta', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles3909', 'language': 'croatian', 'city': 'sofia', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles3914', 'language': 'french', 'city': 'amsterdam', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles3919', 'language': 'austrian', 'city': 'valletta', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles3924', 'language': 'croatian', 'city': 'madrid', 'date': 43}
# {'mobile': 0, 'avatar_name': 'turtles3929', 'language': 'romanian', 'city': 'vienna', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles3934', 'language': 'italian', 'city': 'vilnius', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles3939', 'language': 'estonian', 'city': 'copenhagen', 'date': 21}
# {'mobile': 1, 'avatar_name': 'turtles3944', 'language': 'czech', 'city': 'vienna', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles3949', 'language': 'croatian', 'city': 'valletta', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles3954', 'language': 'slovene', 'city': 'valletta', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles3959', 'language': 'portuguese', 'city': 'copenhagen', 'date': 21}
# {'mobile': 1, 'avatar_name': 'turtles3964', 'language': 'romanian', 'city': 'paris', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles3969', 'language': 'dutch', 'city': 'copenhagen', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles3974', 'language': 'austrian', 'city': 'valletta', 'date': 31}
# {'mobile': 0, 'avatar_name': 'turtles3979', 'language': 'danish', 'city': 'vienna', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles3984', 'language': 'latvian', 'city': 'vilnius', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles3989', 'language': 'belgian', 'city': 'madrid', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3994', 'language': 'spanish', 'city': 'vienna', 'date': 15}
# {'mobile': 0, 'avatar_name': 'turtles3999', 'language': 'romanian', 'city': 'sofia', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles4004', 'language': 'austrian', 'city': 'vienna', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles4009', 'language': 'danish', 'city': 'vienna', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles4014', 'language': 'hungarian', 'city': 'paris', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles4019', 'language': 'italian', 'city': 'vilnius', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles4024', 'language': 'czech', 'city': 'vienna', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles4029', 'language': 'german', 'city': 'vilnius', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles4034', 'language': 'portuguese', 'city': 'copenhagen', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles4039', 'language': 'cypriot', 'city': 'valletta', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles4044', 'language': 'croatian', 'city': 'valletta', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles4049', 'language': 'portuguese', 'city': 'valletta', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles4054', 'language': 'greek', 'city': 'paris', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles4059', 'language': 'luxembourgish', 'city': 'rome', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles4064', 'language': 'hungarian', 'city': 'rome', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles4069', 'language': 'austrian', 'city': 'sofia', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles4074', 'language': 'slovakian', 'city': 'vienna', 'date': 15}
# {'mobile': 0, 'avatar_name': 'turtles4079', 'language': 'romanian', 'city': 'copenhagen', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles4084', 'language': 'latvian', 'city': 'rome', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles4089', 'language': 'lithuanian', 'city': 'rome', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles4094', 'language': 'portuguese', 'city': 'valletta', 'date': 5}
# {'mobile': 0, 'avatar_name': 'turtles4099', 'language': 'czech', 'city': 'valletta', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3690', 'language': 'czech', 'city': 'vienna', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles3695', 'language': 'french', 'city': 'paris', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles3700', 'language': 'swedish', 'city': 'paris', 'date': 38}
# {'mobile': 0, 'avatar_name': 'turtles3705', 'language': 'french', 'city': 'valletta', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles3710', 'language': 'croatian', 'city': 'madrid', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3715', 'language': 'danish', 'city': 'amsterdam', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3720', 'language': 'italian', 'city': 'vilnius', 'date': 10}
# {'mobile': 0, 'avatar_name': 'turtles3725', 'language': 'romanian', 'city': 'paris', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles3730', 'language': 'estonian', 'city': 'sofia', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles3735', 'language': 'maltese', 'city': 'sofia', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles3740', 'language': 'greek', 'city': 'rome', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3745', 'language': 'french', 'city': 'paris', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles3750', 'language': 'dutch', 'city': 'copenhagen', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles3755', 'language': 'maltese', 'city': 'valletta', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles3760', 'language': 'slovene', 'city': 'vilnius', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles3765', 'language': 'luxembourgish', 'city': 'vilnius', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3770', 'language': 'belgian', 'city': 'amsterdam', 'date': 5}
# {'mobile': 0, 'avatar_name': 'turtles3775', 'language': 'polish', 'city': 'paris', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles3780', 'language': 'lithuanian', 'city': 'copenhagen', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles3785', 'language': 'cypriot', 'city': 'madrid', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3790', 'language': 'portuguese', 'city': 'paris', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles3795', 'language': 'german', 'city': 'amsterdam', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles3800', 'language': 'portuguese', 'city': 'copenhagen', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles3805', 'language': 'italian', 'city': 'amsterdam', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles3810', 'language': 'slovakian', 'city': 'madrid', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles3815', 'language': 'lithuanian', 'city': 'copenhagen', 'date': 19}
# {'mobile': 0, 'avatar_name': 'turtles3820', 'language': 'swedish', 'city': 'paris', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles3825', 'language': 'croatian', 'city': 'paris', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles3830', 'language': 'belgian', 'city': 'madrid', 'date': 15}
# {'mobile': 0, 'avatar_name': 'turtles3835', 'language': 'maltese', 'city': 'rome', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles3840', 'language': 'hungarian', 'city': 'madrid', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles3845', 'language': 'irish', 'city': 'amsterdam', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles3850', 'language': 'spanish', 'city': 'rome', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles3855', 'language': 'slovene', 'city': 'amsterdam', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles3860', 'language': 'latvian', 'city': 'madrid', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles3865', 'language': 'croatian', 'city': 'sofia', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles3870', 'language': 'cypriot', 'city': 'rome', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles3875', 'language': 'irish', 'city': 'madrid', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles3880', 'language': 'dutch', 'city': 'vilnius', 'date': 10}
# {'mobile': 0, 'avatar_name': 'turtles3885', 'language': 'french', 'city': 'amsterdam', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles3890', 'language': 'estonian', 'city': 'amsterdam', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles3895', 'language': 'spanish', 'city': 'rome', 'date': 42}
# {'mobile': 1, 'avatar_name': 'turtles3900', 'language': 'maltese', 'city': 'madrid', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles3905', 'language': 'lithuanian', 'city': 'valletta', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles3910', 'language': 'lithuanian', 'city': 'copenhagen', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles3915', 'language': 'estonian', 'city': 'vilnius', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles3920', 'language': 'czech', 'city': 'vienna', 'date': 1}
# {'mobile': 0, 'avatar_name': 'turtles3925', 'language': 'czech', 'city': 'rome', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles3930', 'language': 'austrian', 'city': 'rome', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles3935', 'language': 'portuguese', 'city': 'paris', 'date': 25}
# {'mobile': 0, 'avatar_name': 'turtles3940', 'language': 'portuguese', 'city': 'amsterdam', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles3945', 'language': 'irish', 'city': 'madrid', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles3950', 'language': 'slovakian', 'city': 'copenhagen', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3955', 'language': 'cypriot', 'city': 'madrid', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles3960', 'language': 'finnish', 'city': 'paris', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles3965', 'language': 'hungarian', 'city': 'rome', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles3970', 'language': 'maltese', 'city': 'amsterdam', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles3975', 'language': 'hungarian', 'city': 'madrid', 'date': 17}
# {'mobile': 0, 'avatar_name': 'turtles3980', 'language': 'polish', 'city': 'vienna', 'date': 43}
# {'mobile': 0, 'avatar_name': 'turtles3985', 'language': 'slovakian', 'city': 'copenhagen', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles3990', 'language': 'luxembourgish', 'city': 'sofia', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles3995', 'language': 'latvian', 'city': 'rome', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles4000', 'language': 'irish', 'city': 'rome', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles4005', 'language': 'swedish', 'city': 'sofia', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles4010', 'language': 'belgian', 'city': 'madrid', 'date': 10}
# {'mobile': 0, 'avatar_name': 'turtles4015', 'language': 'slovakian', 'city': 'vilnius', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles4020', 'language': 'finnish', 'city': 'copenhagen', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles4025', 'language': 'polish', 'city': 'copenhagen', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles4030', 'language': 'austrian', 'city': 'copenhagen', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles4035', 'language': 'greek', 'city': 'paris', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles4040', 'language': 'maltese', 'city': 'vilnius', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles4045', 'language': 'italian', 'city': 'copenhagen', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles4050', 'language': 'estonian', 'city': 'vilnius', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles4055', 'language': 'slovakian', 'city': 'paris', 'date': 25}
# {'mobile': 1, 'avatar_name': 'turtles4060', 'language': 'swedish', 'city': 'amsterdam', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles4065', 'language': 'irish', 'city': 'vienna', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles4070', 'language': 'irish', 'city': 'madrid', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles4075', 'language': 'belgian', 'city': 'amsterdam', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles4080', 'language': 'greek', 'city': 'vilnius', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles4085', 'language': 'cypriot', 'city': 'vienna', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles4090', 'language': 'belgian', 'city': 'sofia', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles4095', 'language': 'dutch', 'city': 'rome', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles3711', 'language': 'italian', 'city': 'amsterdam', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles3716', 'language': 'bulgarian', 'city': 'copenhagen', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles3721', 'language': 'portuguese', 'city': 'madrid', 'date': 15}
# {'mobile': 0, 'avatar_name': 'turtles3726', 'language': 'portuguese', 'city': 'copenhagen', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles3731', 'language': 'spanish', 'city': 'sofia', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles3736', 'language': 'dutch', 'city': 'vilnius', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles3741', 'language': 'bulgarian', 'city': 'sofia', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles3746', 'language': 'romanian', 'city': 'amsterdam', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles3751', 'language': 'polish', 'city': 'paris', 'date': 3}
# {'mobile': 0, 'avatar_name': 'turtles3756', 'language': 'estonian', 'city': 'amsterdam', 'date': 3}
# {'mobile': 0, 'avatar_name': 'turtles3761', 'language': 'luxembourgish', 'city': 'rome', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles3766', 'language': 'slovakian', 'city': 'rome', 'date': 5}
# {'mobile': 0, 'avatar_name': 'turtles3771', 'language': 'bulgarian', 'city': 'sofia', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles3776', 'language': 'latvian', 'city': 'copenhagen', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles3781', 'language': 'romanian', 'city': 'sofia', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles3786', 'language': 'romanian', 'city': 'vienna', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles3791', 'language': 'french', 'city': 'sofia', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles3796', 'language': 'slovakian', 'city': 'rome', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles3801', 'language': 'french', 'city': 'copenhagen', 'date': 26}
# {'mobile': 1, 'avatar_name': 'turtles3806', 'language': 'swedish', 'city': 'paris', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles3811', 'language': 'italian', 'city': 'vienna', 'date': 3}
# {'mobile': 0, 'avatar_name': 'turtles3816', 'language': 'spanish', 'city': 'valletta', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles3821', 'language': 'austrian', 'city': 'vienna', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles3826', 'language': 'finnish', 'city': 'valletta', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles3831', 'language': 'polish', 'city': 'sofia', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles3836', 'language': 'danish', 'city': 'sofia', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles3841', 'language': 'estonian', 'city': 'valletta', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles3846', 'language': 'french', 'city': 'copenhagen', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles3851', 'language': 'luxembourgish', 'city': 'rome', 'date': 21}
# {'mobile': 1, 'avatar_name': 'turtles3856', 'language': 'austrian', 'city': 'amsterdam', 'date': 26}
# {'mobile': 1, 'avatar_name': 'turtles3861', 'language': 'italian', 'city': 'sofia', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles3866', 'language': 'italian', 'city': 'vilnius', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles3871', 'language': 'romanian', 'city': 'vienna', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles3876', 'language': 'maltese', 'city': 'vilnius', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles3881', 'language': 'finnish', 'city': 'amsterdam', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles3886', 'language': 'belgian', 'city': 'amsterdam', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles3891', 'language': 'croatian', 'city': 'rome', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles3896', 'language': 'lithuanian', 'city': 'paris', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles3901', 'language': 'slovene', 'city': 'copenhagen', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles3906', 'language': 'french', 'city': 'paris', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles3911', 'language': 'bulgarian', 'city': 'vilnius', 'date': 5}
# {'mobile': 0, 'avatar_name': 'turtles3916', 'language': 'german', 'city': 'copenhagen', 'date': 0}
# {'mobile': 1, 'avatar_name': 'turtles3921', 'language': 'polish', 'city': 'paris', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles3926', 'language': 'croatian', 'city': 'rome', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles3931', 'language': 'lithuanian', 'city': 'copenhagen', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles3936', 'language': 'lithuanian', 'city': 'paris', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles3941', 'language': 'french', 'city': 'paris', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles3946', 'language': 'french', 'city': 'amsterdam', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles3951', 'language': 'spanish', 'city': 'copenhagen', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles3956', 'language': 'cypriot', 'city': 'madrid', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles3961', 'language': 'danish', 'city': 'copenhagen', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles3966', 'language': 'czech', 'city': 'valletta', 'date': 19}
# {'mobile': 0, 'avatar_name': 'turtles3971', 'language': 'bulgarian', 'city': 'paris', 'date': 11}
# {'mobile': 0, 'avatar_name': 'turtles3976', 'language': 'german', 'city': 'valletta', 'date': 19}
# {'mobile': 0, 'avatar_name': 'turtles3981', 'language': 'lithuanian', 'city': 'rome', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles3986', 'language': 'lithuanian', 'city': 'amsterdam', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles3991', 'language': 'slovakian', 'city': 'vilnius', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles3996', 'language': 'german', 'city': 'amsterdam', 'date': 42}
# {'mobile': 1, 'avatar_name': 'turtles4001', 'language': 'austrian', 'city': 'copenhagen', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles4006', 'language': 'greek', 'city': 'paris', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles4011', 'language': 'cypriot', 'city': 'amsterdam', 'date': 31}
# {'mobile': 0, 'avatar_name': 'turtles4016', 'language': 'polish', 'city': 'copenhagen', 'date': 5}
# {'mobile': 0, 'avatar_name': 'turtles4021', 'language': 'german', 'city': 'rome', 'date': 31}
# {'mobile': 1, 'avatar_name': 'turtles4026', 'language': 'maltese', 'city': 'amsterdam', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles4031', 'language': 'austrian', 'city': 'rome', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles4036', 'language': 'danish', 'city': 'rome', 'date': 31}
# {'mobile': 1, 'avatar_name': 'turtles4041', 'language': 'belgian', 'city': 'valletta', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles4046', 'language': 'estonian', 'city': 'sofia', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles4051', 'language': 'estonian', 'city': 'sofia', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles4056', 'language': 'czech', 'city': 'valletta', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles4061', 'language': 'hungarian', 'city': 'vilnius', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles4066', 'language': 'belgian', 'city': 'amsterdam', 'date': 25}
# {'mobile': 1, 'avatar_name': 'turtles4071', 'language': 'romanian', 'city': 'vienna', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles4076', 'language': 'cypriot', 'city': 'rome', 'date': 42}
# {'mobile': 1, 'avatar_name': 'turtles4081', 'language': 'maltese', 'city': 'valletta', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles4086', 'language': 'dutch', 'city': 'amsterdam', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles4091', 'language': 'dutch', 'city': 'paris', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles4096', 'language': 'luxembourgish', 'city': 'rome', 'date': 9}

# %%
stock_df_final = request_to_final_df(stock_df)
stock_df_final.to_csv('data/results_requests/result26.csv', index=False)

# %%
#r2.json()
