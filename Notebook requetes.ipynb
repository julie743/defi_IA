# %% [markdown]
# # Notebook défi IA - Préparation des données

# %%
#Librairies 
import itertools
import pandas as pd 
import random
import requests
import numpy as np
import copy
import json

# %%
#Requêtes 
import urllib.parse

domain = "51.91.251.0"
port = 3000
host = f"http://{domain}:{port}"
path = lambda x: urllib.parse.urljoin(host, x)

# %% [markdown]
# ## 1 - Labels et valeurs

# %%
# les paramètres du jeu de données : 
request_var = ["language","city","date","mobile"]
city = ["amsterdam","copenhagen","madrid","paris","rome","sofia","valletta","vienna","vilnius"]
date = list(range(0,45))
language = ["austrian", "belgian", "bulgarian", "croatian", "cypriot", "czech", "danish", "dutch", "estonian", "finnish", "french",
"german", "greek", "hungarian", "irish", "italian", "latvian", "lithuanian", "luxembourgish", "maltese", "polish", "portuguese", 
            "romanian", "slovakian", "slovene", "spanish", "swedish"]
mobile = [0,1]

dic_language_country = pd.Series({"amsterdam":"dutch",
                                   "copenhagen":"danish",
                                   "madrid":"spanish",
                                   "paris" : "french",
                                   "rome": "italian",
                                   "sofia": "bulgarian",
                                   "valletta": "maltese",
                                   "vienna" : "austrian",
                                   "vilnius" : "lithuanian"})

dic_similar_language = {"french" : ["belgian"],
                       "belgian" : ["french"], 
                       "german" : ["austrian","luxembourgish"],
                       "austrian" : ["german","luxembourgish"],
                       "luxembourgish" : ["german","austrian"]}

# %% [markdown]
# ## 2 - Paramètres

# %%
# les paramètres des fonctions pour générer les requêtes : 
nb_users = 1400
max_requetes = 4 
max_jours = 44
threshold_city = 0.02
threshold_language = 0.02

# %% [markdown]
# ## 3 - Création des avatars

# %%
#Création des avatars 
user_id = '82a030f2-958a-4824-8ee0-85cde6f5668c'

for i in range(700,nb_users) :
    name = "turtles" + str(i)
    r = requests.post(path(f'avatars/{user_id}/{name}'))

# %%
#Vérification création des avatars 
r = requests.get(path(f"avatars/{user_id}"))  
names = []

for avatar in r.json():
    print(avatar['id'], avatar['name'])
    names.append(avatar['name'])
# Out:
# 3530 first_avatar
# 3531 turtles1
# 3532 turtles2
# 4527 turtles0
# 4528 turtles3
# 4529 turtles4
# 4530 turtles5
# 4531 turtles6
# 4532 turtles7
# 4533 turtles8
# 4534 turtles9
# 29408 turtles46
# 29409 turtles47
# 29410 turtles48
# 29411 turtles49
# 29412 turtles50
# 29413 turtles51
# 29414 turtles52
# 29415 turtles53
# 29416 turtles54
# 29417 turtles55
# 29419 turtles56
# 29420 turtles57
# 29421 turtles58
# 29422 turtles59
# 29372 turtles10
# 29373 turtles11
# 29374 turtles12
# 29375 turtles13
# 29376 turtles14
# 29377 turtles15
# 29378 turtles16
# 29379 turtles17
# 29380 turtles18
# 29381 turtles19
# 29382 turtles20
# 29383 turtles21
# 29384 turtles22
# 29385 turtles23
# 29386 turtles24
# 29387 turtles25
# 29388 turtles26
# 29389 turtles27
# 29390 turtles28
# 29391 turtles29
# 29392 turtles30
# 29393 turtles31
# 29394 turtles32
# 29395 turtles33
# 29396 turtles34
# 29397 turtles35
# 29398 turtles36
# 29399 turtles37
# 29400 turtles38
# 29401 turtles39
# 29402 turtles40
# 29403 turtles41
# 29404 turtles42
# 29405 turtles43
# 29406 turtles44
# 29407 turtles45
# 29441 turtles77
# 29442 turtles78
# 29443 turtles79
# 29444 turtles80
# 29445 turtles81
# 29446 turtles82
# 29447 turtles83
# 29448 turtles84
# 29449 turtles85
# 29450 turtles86
# 29451 turtles87
# 29452 turtles88
# 29453 turtles89
# 29454 turtles90
# 29423 turtles60
# 29424 turtles61
# 29425 turtles62
# 29426 turtles63
# 29427 turtles64
# 29428 turtles65
# 29429 turtles66
# 29431 turtles67
# 29432 turtles68
# 29433 turtles69
# 29434 turtles70
# 29435 turtles71
# 29436 turtles72
# 29437 turtles73
# 29438 turtles74
# 29439 turtles75
# 29440 turtles76
# 29456 turtles92
# 29457 turtles93
# 29458 turtles94
# 29459 turtles95
# 29460 turtles96
# 29461 turtles97
# 29475 turtles111
# 29476 turtles112
# 29477 turtles113
# 29478 turtles114
# 29479 turtles115
# 29480 turtles116
# 29487 turtles123
# 29488 turtles124
# 29489 turtles125
# 29490 turtles126
# 29491 turtles127
# 29492 turtles128
# 29493 turtles129
# 29515 turtles151
# 29516 turtles152
# 29517 turtles153
# 29518 turtles154
# 29519 turtles155
# 29520 turtles156
# 29521 turtles157
# 29522 turtles158
# 29523 turtles159
# 29524 turtles160
# 29525 turtles161
# 29526 turtles162
# 29527 turtles163
# 29528 turtles164
# 29529 turtles165
# 29531 turtles166
# 29532 turtles167
# 29533 turtles168
# 29545 turtles180
# 29546 turtles181
# 29547 turtles182
# 29557 turtles192
# 29558 turtles193
# 29559 turtles194
# 29560 turtles195
# 29561 turtles196
# 29562 turtles197
# 29563 turtles198
# 29564 turtles199
# 29572 turtles207
# 29574 turtles209
# 29575 turtles210
# 29576 turtles211
# 29577 turtles212
# 29578 turtles213
# 29579 turtles214
# 29580 turtles215
# 29581 turtles216
# 29582 turtles217
# 29583 turtles218
# 29584 turtles219
# 29585 turtles220
# 29586 turtles221
# 29588 turtles223
# 29597 turtles232
# 29598 turtles233
# 29600 turtles235
# 29601 turtles236
# 29604 turtles239
# 29605 turtles240
# 29606 turtles241
# 29607 turtles242
# 29608 turtles243
# 29609 turtles244
# 29610 turtles245
# 29611 turtles246
# 29612 turtles247
# 29639 turtles273
# 29640 turtles274
# 29641 turtles275
# 29642 turtles276
# 29643 turtles277
# 29644 turtles278
# 29645 turtles279
# 29646 turtles280
# 29647 turtles281
# 29648 turtles282
# 29649 turtles283
# 29650 turtles284
# 29651 turtles285
# 29652 turtles286
# 29653 turtles287
# 29654 turtles288
# 29655 turtles289
# 29656 turtles290
# 29657 turtles291
# 29662 turtles296
# 29664 turtles298
# 29665 turtles299
# 29666 turtles300
# 29671 turtles305
# 29672 turtles306
# 29455 turtles91
# 29462 turtles98
# 29463 turtles99
# 29464 turtles100
# 29465 turtles101
# 29466 turtles102
# 29467 turtles103
# 29468 turtles104
# 29469 turtles105
# 29470 turtles106
# 29471 turtles107
# 29472 turtles108
# 29473 turtles109
# 29474 turtles110
# 29481 turtles117
# 29482 turtles118
# 29483 turtles119
# 29484 turtles120
# 29485 turtles121
# 29486 turtles122
# 29494 turtles130
# 29495 turtles131
# 29496 turtles132
# 29497 turtles133
# 29498 turtles134
# 29499 turtles135
# 29500 turtles136
# 29501 turtles137
# 29502 turtles138
# 29503 turtles139
# 29504 turtles140
# 29505 turtles141
# 29506 turtles142
# 29507 turtles143
# 29508 turtles144
# 29509 turtles145
# 29510 turtles146
# 29511 turtles147
# 29512 turtles148
# 29513 turtles149
# 29514 turtles150
# 29534 turtles169
# 29535 turtles170
# 29536 turtles171
# 29537 turtles172
# 29538 turtles173
# 29539 turtles174
# 29540 turtles175
# 29541 turtles176
# 29542 turtles177
# 29543 turtles178
# 29544 turtles179
# 29548 turtles183
# 29549 turtles184
# 29550 turtles185
# 29551 turtles186
# 29552 turtles187
# 29553 turtles188
# 29554 turtles189
# 29555 turtles190
# 29556 turtles191
# 29565 turtles200
# 29566 turtles201
# 29567 turtles202
# 29568 turtles203
# 29569 turtles204
# 29570 turtles205
# 29571 turtles206
# 29573 turtles208
# 29587 turtles222
# 29589 turtles224
# 29590 turtles225
# 29591 turtles226
# 29592 turtles227
# 29593 turtles228
# 29594 turtles229
# 29595 turtles230
# 29596 turtles231
# 29599 turtles234
# 29602 turtles237
# 29603 turtles238
# 29613 turtles248
# 29614 turtles249
# 29615 turtles250
# 29616 turtles251
# 29617 turtles252
# 29618 turtles253
# 29619 turtles254
# 29620 turtles255
# 29621 turtles256
# 29622 turtles257
# 29623 turtles258
# 29624 turtles259
# 29625 turtles260
# 29626 turtles261
# 29627 turtles262
# 29628 turtles263
# 29629 turtles264
# 29630 turtles265
# 29631 turtles266
# 29632 turtles267
# 29633 turtles268
# 29634 turtles269
# 29635 turtles270
# 29637 turtles271
# 29638 turtles272
# 29658 turtles292
# 29659 turtles293
# 29660 turtles294
# 29661 turtles295
# 29663 turtles297
# 29667 turtles301
# 29668 turtles302
# 29669 turtles303
# 29670 turtles304
# 29699 turtles333
# 29700 turtles334
# 29701 turtles335
# 29702 turtles336
# 29673 turtles307
# 29674 turtles308
# 29675 turtles309
# 29676 turtles310
# 29677 turtles311
# 29678 turtles312
# 29679 turtles313
# 29680 turtles314
# 29681 turtles315
# 29682 turtles316
# 29683 turtles317
# 29684 turtles318
# 29685 turtles319
# 29686 turtles320
# 29687 turtles321
# 29688 turtles322
# 29689 turtles323
# 29690 turtles324
# 29691 turtles325
# 29692 turtles326
# 29693 turtles327
# 29694 turtles328
# 29695 turtles329
# 29696 turtles330
# 29697 turtles331
# 29698 turtles332
# 29704 turtles338
# 29705 turtles339
# 29706 turtles340
# 29707 turtles341
# 29708 turtles342
# 29709 turtles343
# 29711 turtles345
# 29712 turtles346
# 29713 turtles347
# 29714 turtles348
# 29715 turtles349
# 29716 turtles350
# 29717 turtles351
# 29718 turtles352
# 29719 turtles353
# 29720 turtles354
# 29721 turtles355
# 29722 turtles356
# 29723 turtles357
# 29726 turtles360
# 29727 turtles361
# 29728 turtles362
# 29729 turtles363
# 29732 turtles366
# 29745 turtles379
# 29746 turtles380
# 29747 turtles381
# 29749 turtles382
# 29750 turtles383
# 29751 turtles384
# 29752 turtles385
# 29753 turtles386
# 29754 turtles387
# 29755 turtles388
# 29756 turtles389
# 29757 turtles390
# 29758 turtles391
# 29759 turtles392
# 29760 turtles393
# 29768 turtles401
# 29770 turtles403
# 29771 turtles404
# 29772 turtles405
# 29773 turtles406
# 29774 turtles407
# 29776 turtles409
# 29784 turtles417
# 29800 turtles433
# 29801 turtles434
# 29802 turtles435
# 29805 turtles438
# 29806 turtles439
# 29808 turtles441
# 29812 turtles445
# 29822 turtles455
# 29826 turtles459
# 29827 turtles460
# 29833 turtles466
# 29834 turtles467
# 29839 turtles472
# 29840 turtles473
# 29843 turtles476
# 29844 turtles477
# 29847 turtles480
# 29850 turtles483
# 29851 turtles484
# 29858 turtles490
# 29861 turtles493
# 29863 turtles495
# 29864 turtles496
# 29868 turtles500
# 29870 turtles502
# 29873 turtles505
# 29879 turtles511
# 29880 turtles512
# 29882 turtles514
# 29883 turtles515
# 29884 turtles516
# 29885 turtles517
# 29888 turtles520
# 29893 turtles525
# 29897 turtles529
# 29902 turtles534
# 29903 turtles535
# 29906 turtles538
# 29907 turtles539
# 29912 turtles544
# 29916 turtles548
# 29920 turtles552
# 29924 turtles556
# 29925 turtles557
# 29926 turtles558
# 29930 turtles562
# 29703 turtles337
# 29710 turtles344
# 29724 turtles358
# 29725 turtles359
# 29730 turtles364
# 29731 turtles365
# 29733 turtles367
# 29734 turtles368
# 29735 turtles369
# 29736 turtles370
# 29737 turtles371
# 29738 turtles372
# 29739 turtles373
# 29740 turtles374
# 29741 turtles375
# 29742 turtles376
# 29743 turtles377
# 29744 turtles378
# 29761 turtles394
# 29762 turtles395
# 29763 turtles396
# 29764 turtles397
# 29765 turtles398
# 29766 turtles399
# 29767 turtles400
# 29769 turtles402
# 29775 turtles408
# 29777 turtles410
# 29778 turtles411
# 29779 turtles412
# 29780 turtles413
# 29781 turtles414
# 29782 turtles415
# 29783 turtles416
# 29785 turtles418
# 29786 turtles419
# 29787 turtles420
# 29788 turtles421
# 29789 turtles422
# 29790 turtles423
# 29791 turtles424
# 29792 turtles425
# 29793 turtles426
# 29794 turtles427
# 29795 turtles428
# 29796 turtles429
# 29797 turtles430
# 29798 turtles431
# 29799 turtles432
# 29803 turtles436
# 29804 turtles437
# 29807 turtles440
# 29809 turtles442
# 29810 turtles443
# 29811 turtles444
# 29813 turtles446
# 29814 turtles447
# 29815 turtles448
# 29816 turtles449
# 29817 turtles450
# 29818 turtles451
# 29819 turtles452
# 29820 turtles453
# 29821 turtles454
# 29823 turtles456
# 29824 turtles457
# 29825 turtles458
# 29828 turtles461
# 29829 turtles462
# 29830 turtles463
# 29831 turtles464
# 29832 turtles465
# 29835 turtles468
# 29836 turtles469
# 29837 turtles470
# 29838 turtles471
# 29841 turtles474
# 29842 turtles475
# 29845 turtles478
# 29846 turtles479
# 29848 turtles481
# 29849 turtles482
# 29852 turtles485
# 29853 turtles486
# 29854 turtles487
# 29855 turtles488
# 29856 turtles489
# 29859 turtles491
# 29860 turtles492
# 29862 turtles494
# 29865 turtles497
# 29866 turtles498
# 29867 turtles499
# 29869 turtles501
# 29871 turtles503
# 29872 turtles504
# 29874 turtles506
# 29875 turtles507
# 29876 turtles508
# 29877 turtles509
# 29878 turtles510
# 29881 turtles513
# 29886 turtles518
# 29887 turtles519
# 29889 turtles521
# 29890 turtles522
# 29891 turtles523
# 29892 turtles524
# 29894 turtles526
# 29895 turtles527
# 29896 turtles528
# 29898 turtles530
# 29899 turtles531
# 29900 turtles532
# 29901 turtles533
# 29904 turtles536
# 29905 turtles537
# 29908 turtles540
# 29909 turtles541
# 29910 turtles542
# 29913 turtles545
# 29914 turtles546
# 29917 turtles549
# 29918 turtles550
# 29921 turtles553
# 29922 turtles554
# 29927 turtles559
# 29931 turtles563
# 29936 turtles568
# 29937 turtles569
# 29940 turtles572
# 29942 turtles574
# 29946 turtles578
# 29950 turtles582
# 29954 turtles586
# 29956 turtles588
# 29960 turtles592
# 29964 turtles596
# 29968 turtles600
# 29973 turtles605
# 29974 turtles606
# 29977 turtles609
# 29978 turtles610
# 29981 turtles613
# 29982 turtles614
# 29985 turtles617
# 29986 turtles618
# 29990 turtles622
# 29994 turtles626
# 29999 turtles631
# 30001 turtles633
# 30005 turtles637
# 30009 turtles641
# 30014 turtles646
# 30015 turtles647
# 30018 turtles650
# 30019 turtles651
# 30025 turtles657
# 30026 turtles658
# 30029 turtles661
# 30030 turtles662
# 30033 turtles665
# 30034 turtles666
# 30037 turtles669
# 30038 turtles670
# 30044 turtles676
# 30045 turtles677
# 30048 turtles680
# 30049 turtles681
# 30052 turtles684
# 30053 turtles685
# 30056 turtles688
# 30058 turtles690
# 30062 turtles694
# 30066 turtles698
# 29911 turtles543
# 29915 turtles547
# 29919 turtles551
# 29923 turtles555
# 29928 turtles560
# 29929 turtles561
# 29932 turtles564
# 29933 turtles565
# 29938 turtles570
# 29941 turtles573
# 29945 turtles577
# 29949 turtles581
# 29953 turtles585
# 29955 turtles587
# 29958 turtles590
# 29959 turtles591
# 29962 turtles594
# 29963 turtles595
# 29966 turtles598
# 29967 turtles599
# 29972 turtles604
# 29976 turtles608
# 29980 turtles612
# 29983 turtles615
# 29988 turtles620
# 29989 turtles621
# 29992 turtles624
# 29993 turtles625
# 29998 turtles630
# 30002 turtles634
# 30006 turtles638
# 30010 turtles642
# 30012 turtles644
# 30016 turtles648
# 30020 turtles652
# 30022 turtles654
# 30024 turtles656
# 30028 turtles660
# 30032 turtles664
# 30036 turtles668
# 30040 turtles672
# 30042 turtles674
# 30046 turtles678
# 30050 turtles682
# 30055 turtles687
# 30059 turtles691
# 30060 turtles692
# 30063 turtles695
# 30064 turtles696
# 30067 turtles699
# 29934 turtles566
# 29935 turtles567
# 29939 turtles571
# 29943 turtles575
# 29944 turtles576
# 29947 turtles579
# 29948 turtles580
# 29951 turtles583
# 29952 turtles584
# 29957 turtles589
# 29961 turtles593
# 29965 turtles597
# 29969 turtles601
# 29970 turtles602
# 29971 turtles603
# 29975 turtles607
# 29979 turtles611
# 29984 turtles616
# 29987 turtles619
# 29991 turtles623
# 29995 turtles627
# 29996 turtles628
# 29997 turtles629
# 30000 turtles632
# 30003 turtles635
# 30004 turtles636
# 30007 turtles639
# 30008 turtles640
# 30011 turtles643
# 30013 turtles645
# 30017 turtles649
# 30021 turtles653
# 30023 turtles655
# 30027 turtles659
# 30031 turtles663
# 30035 turtles667
# 30039 turtles671
# 30041 turtles673
# 30043 turtles675
# 30047 turtles679
# 30051 turtles683
# 30054 turtles686
# 30057 turtles689
# 30061 turtles693
# 30065 turtles697
# 68466 turtles700
# 68467 turtles701
# 68468 turtles702
# 68469 turtles703
# 68470 turtles704
# 68471 turtles705
# 68472 turtles706
# 68473 turtles707
# 68474 turtles708
# 68475 turtles709
# 68476 turtles710
# 68477 turtles711
# 68478 turtles712
# 68479 turtles713
# 68480 turtles714
# 68481 turtles715
# 68482 turtles716
# 68483 turtles717
# 68484 turtles718
# 68485 turtles719
# 68486 turtles720
# 68487 turtles721
# 68488 turtles722
# 68489 turtles723
# 68490 turtles724
# 68491 turtles725
# 68492 turtles726
# 68493 turtles727
# 68494 turtles728
# 68495 turtles729
# 68496 turtles730
# 68497 turtles731
# 68498 turtles732
# 68499 turtles733
# 68500 turtles734
# 68501 turtles735
# 68502 turtles736
# 68503 turtles737
# 68504 turtles738
# 68505 turtles739
# 68506 turtles740
# 68507 turtles741
# 68508 turtles742
# 68509 turtles743
# 68510 turtles744
# 68511 turtles745
# 68512 turtles746
# 68513 turtles747
# 68514 turtles748
# 68515 turtles749
# 68516 turtles750
# 68517 turtles751
# 68518 turtles752
# 68519 turtles753
# 68520 turtles754
# 68521 turtles755
# 68522 turtles756
# 68523 turtles757
# 68524 turtles758
# 68525 turtles759
# 68526 turtles760
# 68527 turtles761
# 68528 turtles762
# 68529 turtles763
# 68530 turtles764
# 68531 turtles765
# 68532 turtles766
# 68533 turtles767
# 68534 turtles768
# 68535 turtles769
# 68536 turtles770
# 68537 turtles771
# 68538 turtles772
# 68539 turtles773
# 68540 turtles774
# 68541 turtles775
# 68542 turtles776
# 68543 turtles777
# 68544 turtles778
# 68545 turtles779
# 68546 turtles780
# 68547 turtles781
# 68548 turtles782
# 68549 turtles783
# 68550 turtles784
# 68551 turtles785
# 68552 turtles786
# 68553 turtles787
# 68554 turtles788
# 68555 turtles789
# 68556 turtles790
# 68557 turtles791
# 68558 turtles792
# 68559 turtles793
# 68560 turtles794
# 68561 turtles795
# 68562 turtles796
# 68563 turtles797
# 68564 turtles798
# 68565 turtles799
# 68566 turtles800
# 68567 turtles801
# 68568 turtles802
# 68569 turtles803
# 68570 turtles804
# 68571 turtles805
# 68572 turtles806
# 68573 turtles807
# 68574 turtles808
# 68575 turtles809
# 68576 turtles810
# 68577 turtles811
# 68578 turtles812
# 68579 turtles813
# 68580 turtles814
# 68581 turtles815
# 68582 turtles816
# 68583 turtles817
# 68584 turtles818
# 68585 turtles819
# 68586 turtles820
# 68587 turtles821
# 68588 turtles822
# 68589 turtles823
# 68590 turtles824
# 68591 turtles825
# 68592 turtles826
# 68593 turtles827
# 68594 turtles828
# 68595 turtles829
# 68596 turtles830
# 68597 turtles831
# 68598 turtles832
# 68599 turtles833
# 68600 turtles834
# 68601 turtles835
# 68602 turtles836
# 68603 turtles837
# 68604 turtles838
# 68605 turtles839
# 68606 turtles840
# 68607 turtles841
# 68608 turtles842
# 68609 turtles843
# 68610 turtles844
# 68611 turtles845
# 68612 turtles846
# 68613 turtles847
# 68614 turtles848
# 68615 turtles849
# 68616 turtles850
# 68617 turtles851
# 68618 turtles852
# 68619 turtles853
# 68620 turtles854
# 68621 turtles855
# 68622 turtles856
# 68623 turtles857
# 68624 turtles858
# 68625 turtles859
# 68626 turtles860
# 68627 turtles861
# 68628 turtles862
# 68629 turtles863
# 68630 turtles864
# 68631 turtles865
# 68632 turtles866
# 68633 turtles867
# 68634 turtles868
# 68635 turtles869
# 68636 turtles870
# 68637 turtles871
# 68638 turtles872
# 68639 turtles873
# 68640 turtles874
# 68641 turtles875
# 68642 turtles876
# 68643 turtles877
# 68644 turtles878
# 68645 turtles879
# 68646 turtles880
# 68647 turtles881
# 68648 turtles882
# 68649 turtles883
# 68650 turtles884
# 68651 turtles885
# 68652 turtles886
# 68653 turtles887
# 68654 turtles888
# 68655 turtles889
# 68656 turtles890
# 68657 turtles891
# 68658 turtles892
# 68659 turtles893
# 68660 turtles894
# 68661 turtles895
# 68662 turtles896
# 68663 turtles897
# 68664 turtles898
# 68665 turtles899
# 68666 turtles900
# 68667 turtles901
# 68668 turtles902
# 68669 turtles903
# 68670 turtles904
# 68671 turtles905
# 68672 turtles906
# 68673 turtles907
# 68674 turtles908
# 68675 turtles909
# 68676 turtles910
# 68677 turtles911
# 68678 turtles912
# 68679 turtles913
# 68680 turtles914
# 68681 turtles915
# 68682 turtles916
# 68683 turtles917
# 68684 turtles918
# 68685 turtles919
# 68686 turtles920
# 68687 turtles921
# 68688 turtles922
# 68689 turtles923
# 68690 turtles924
# 68691 turtles925
# 68692 turtles926
# 68693 turtles927
# 68694 turtles928
# 68695 turtles929
# 68696 turtles930
# 68697 turtles931
# 68698 turtles932
# 68699 turtles933
# 68700 turtles934
# 68701 turtles935
# 68702 turtles936
# 68703 turtles937
# 68704 turtles938
# 68705 turtles939
# 68706 turtles940
# 68707 turtles941
# 68708 turtles942
# 68709 turtles943
# 68710 turtles944
# 68711 turtles945
# 68712 turtles946
# 68713 turtles947
# 68714 turtles948
# 68715 turtles949
# 68716 turtles950
# 68717 turtles951
# 68718 turtles952
# 68719 turtles953
# 68720 turtles954
# 68721 turtles955
# 68722 turtles956
# 68723 turtles957
# 68724 turtles958
# 68725 turtles959
# 68726 turtles960
# 68727 turtles961
# 68728 turtles962
# 68729 turtles963
# 68730 turtles964
# 68731 turtles965
# 68732 turtles966
# 68733 turtles967
# 68734 turtles968
# 68735 turtles969
# 68736 turtles970
# 68737 turtles971
# 68738 turtles972
# 68739 turtles973
# 68740 turtles974
# 68741 turtles975
# 68742 turtles976
# 68743 turtles977
# 68744 turtles978
# 68745 turtles979
# 68746 turtles980
# 68747 turtles981
# 68748 turtles982
# 68749 turtles983
# 68750 turtles984
# 68751 turtles985
# 68752 turtles986
# 68753 turtles987
# 68754 turtles988
# 68755 turtles989
# 68756 turtles990
# 68757 turtles991
# 68758 turtles992
# 68759 turtles993
# 68760 turtles994
# 68761 turtles995
# 68762 turtles996
# 68763 turtles997
# 68764 turtles998
# 68765 turtles999
# 68766 turtles1000
# 68767 turtles1001
# 68768 turtles1002
# 68769 turtles1003
# 68770 turtles1004
# 68771 turtles1005
# 68772 turtles1006
# 68773 turtles1007
# 68774 turtles1008
# 68775 turtles1009
# 68776 turtles1010
# 68777 turtles1011
# 68778 turtles1012
# 68779 turtles1013
# 68780 turtles1014
# 68781 turtles1015
# 68782 turtles1016
# 68783 turtles1017
# 68784 turtles1018
# 68785 turtles1019
# 68786 turtles1020
# 68787 turtles1021
# 68788 turtles1022
# 68789 turtles1023
# 68790 turtles1024
# 68791 turtles1025
# 68792 turtles1026
# 68793 turtles1027
# 68794 turtles1028
# 68795 turtles1029
# 68796 turtles1030
# 68797 turtles1031
# 68798 turtles1032
# 68799 turtles1033
# 68800 turtles1034
# 68801 turtles1035
# 68802 turtles1036
# 68803 turtles1037
# 68804 turtles1038
# 68805 turtles1039
# 68806 turtles1040
# 68807 turtles1041
# 68808 turtles1042
# 68809 turtles1043
# 68810 turtles1044
# 68811 turtles1045
# 68812 turtles1046
# 68813 turtles1047
# 68814 turtles1048
# 68815 turtles1049
# 68816 turtles1050
# 68817 turtles1051
# 68818 turtles1052
# 68819 turtles1053
# 68820 turtles1054
# 68821 turtles1055
# 68822 turtles1056
# 68823 turtles1057
# 68824 turtles1058
# 68825 turtles1059
# 68826 turtles1060
# 68827 turtles1061
# 68828 turtles1062
# 68829 turtles1063
# 68830 turtles1064
# 68831 turtles1065
# 68832 turtles1066
# 68833 turtles1067
# 68834 turtles1068
# 68835 turtles1069
# 68836 turtles1070
# 68837 turtles1071
# 68838 turtles1072
# 68839 turtles1073
# 68840 turtles1074
# 68841 turtles1075
# 68842 turtles1076
# 68843 turtles1077
# 68844 turtles1078
# 68845 turtles1079
# 68846 turtles1080
# 68847 turtles1081
# 68848 turtles1082
# 68849 turtles1083
# 68850 turtles1084
# 68851 turtles1085
# 68852 turtles1086
# 68853 turtles1087
# 68854 turtles1088
# 68855 turtles1089
# 68856 turtles1090
# 68857 turtles1091
# 68858 turtles1092
# 68859 turtles1093
# 68860 turtles1094
# 68861 turtles1095
# 68862 turtles1096
# 68863 turtles1097
# 68864 turtles1098
# 68865 turtles1099
# 68866 turtles1100
# 68867 turtles1101
# 68868 turtles1102
# 68869 turtles1103
# 68870 turtles1104
# 68871 turtles1105
# 68872 turtles1106
# 68873 turtles1107
# 68874 turtles1108
# 68875 turtles1109
# 68876 turtles1110
# 68877 turtles1111
# 68878 turtles1112
# 68879 turtles1113
# 68880 turtles1114
# 68881 turtles1115
# 68882 turtles1116
# 68883 turtles1117
# 68884 turtles1118
# 68885 turtles1119
# 68886 turtles1120
# 68887 turtles1121
# 68888 turtles1122
# 68889 turtles1123
# 68890 turtles1124
# 68891 turtles1125
# 68892 turtles1126
# 68893 turtles1127
# 68894 turtles1128
# 68895 turtles1129
# 68896 turtles1130
# 68897 turtles1131
# 68898 turtles1132
# 68899 turtles1133
# 68900 turtles1134
# 68901 turtles1135
# 68902 turtles1136
# 68903 turtles1137
# 68904 turtles1138
# 68905 turtles1139
# 68906 turtles1140
# 68907 turtles1141
# 68908 turtles1142
# 68909 turtles1143
# 68910 turtles1144
# 68911 turtles1145
# 68912 turtles1146
# 68913 turtles1147
# 68914 turtles1148
# 68915 turtles1149
# 68916 turtles1150
# 68917 turtles1151
# 68918 turtles1152
# 68919 turtles1153
# 68920 turtles1154
# 68921 turtles1155
# 68922 turtles1156
# 68923 turtles1157
# 68924 turtles1158
# 68925 turtles1159
# 68926 turtles1160
# 68927 turtles1161
# 68928 turtles1162
# 68929 turtles1163
# 68930 turtles1164
# 68931 turtles1165
# 68932 turtles1166
# 68933 turtles1167
# 68934 turtles1168
# 68935 turtles1169
# 68936 turtles1170
# 68937 turtles1171
# 68938 turtles1172
# 68939 turtles1173
# 68940 turtles1174
# 68941 turtles1175
# 68942 turtles1176
# 68943 turtles1177
# 68944 turtles1178
# 68945 turtles1179
# 68946 turtles1180
# 68947 turtles1181
# 68948 turtles1182
# 68949 turtles1183
# 68950 turtles1184
# 68951 turtles1185
# 68952 turtles1186
# 68953 turtles1187
# 68954 turtles1188
# 68955 turtles1189
# 68956 turtles1190
# 68957 turtles1191
# 68958 turtles1192
# 68959 turtles1193
# 68960 turtles1194
# 68961 turtles1195
# 68962 turtles1196
# 68963 turtles1197
# 68964 turtles1198
# 68965 turtles1199
# 68966 turtles1200
# 68967 turtles1201
# 68968 turtles1202
# 68969 turtles1203
# 68970 turtles1204
# 68971 turtles1205
# 68972 turtles1206
# 68973 turtles1207
# 68974 turtles1208
# 68975 turtles1209
# 68976 turtles1210
# 68977 turtles1211
# 68978 turtles1212
# 68979 turtles1213
# 68980 turtles1214
# 68981 turtles1215
# 68982 turtles1216
# 68983 turtles1217
# 68984 turtles1218
# 68985 turtles1219
# 68986 turtles1220
# 68987 turtles1221
# 68988 turtles1222
# 68989 turtles1223
# 68990 turtles1224
# 68991 turtles1225
# 68992 turtles1226
# 68993 turtles1227
# 68994 turtles1228
# 68995 turtles1229
# 68996 turtles1230
# 68997 turtles1231
# 68998 turtles1232
# 68999 turtles1233
# 69000 turtles1234
# 69001 turtles1235
# 69002 turtles1236
# 69003 turtles1237
# 69004 turtles1238
# 69005 turtles1239
# 69006 turtles1240
# 69007 turtles1241
# 69008 turtles1242
# 69009 turtles1243
# 69010 turtles1244
# 69011 turtles1245
# 69012 turtles1246
# 69013 turtles1247
# 69014 turtles1248
# 69015 turtles1249
# 69016 turtles1250
# 69017 turtles1251
# 69018 turtles1252
# 69019 turtles1253
# 69020 turtles1254
# 69021 turtles1255
# 69022 turtles1256
# 69023 turtles1257
# 69024 turtles1258
# 69025 turtles1259
# 69026 turtles1260
# 69027 turtles1261
# 69028 turtles1262
# 69029 turtles1263
# 69030 turtles1264
# 69031 turtles1265
# 69032 turtles1266
# 69033 turtles1267
# 69034 turtles1268
# 69035 turtles1269
# 69036 turtles1270
# 69037 turtles1271
# 69038 turtles1272
# 69039 turtles1273
# 69040 turtles1274
# 69041 turtles1275
# 69042 turtles1276
# 69043 turtles1277
# 69044 turtles1278
# 69045 turtles1279
# 69046 turtles1280
# 69047 turtles1281
# 69048 turtles1282
# 69049 turtles1283
# 69050 turtles1284
# 69051 turtles1285
# 69052 turtles1286
# 69053 turtles1287
# 69054 turtles1288
# 69055 turtles1289
# 69056 turtles1290
# 69057 turtles1291
# 69058 turtles1292
# 69059 turtles1293
# 69060 turtles1294
# 69061 turtles1295
# 69062 turtles1296
# 69063 turtles1297
# 69064 turtles1298
# 69065 turtles1299
# 69066 turtles1300
# 69067 turtles1301
# 69068 turtles1302
# 69069 turtles1303
# 69070 turtles1304
# 69071 turtles1305
# 69072 turtles1306
# 69073 turtles1307
# 69074 turtles1308
# 69075 turtles1309
# 69076 turtles1310
# 69077 turtles1311
# 69078 turtles1312
# 69079 turtles1313
# 69080 turtles1314
# 69081 turtles1315
# 69082 turtles1316
# 69083 turtles1317
# 69084 turtles1318
# 69085 turtles1319
# 69086 turtles1320
# 69087 turtles1321
# 69088 turtles1322
# 69089 turtles1323
# 69090 turtles1324
# 69091 turtles1325
# 69092 turtles1326
# 69093 turtles1327
# 69094 turtles1328
# 69095 turtles1329
# 69096 turtles1330
# 69097 turtles1331
# 69098 turtles1332
# 69099 turtles1333
# 69100 turtles1334
# 69101 turtles1335
# 69102 turtles1336
# 69103 turtles1337
# 69104 turtles1338
# 69105 turtles1339
# 69106 turtles1340
# 69107 turtles1341
# 69108 turtles1342
# 69109 turtles1343
# 69110 turtles1344
# 69111 turtles1345
# 69112 turtles1346
# 69113 turtles1347
# 69114 turtles1348
# 69115 turtles1349
# 69116 turtles1350
# 69117 turtles1351
# 69118 turtles1352
# 69119 turtles1353
# 69120 turtles1354
# 69121 turtles1355
# 69122 turtles1356
# 69123 turtles1357
# 69124 turtles1358
# 69125 turtles1359
# 69126 turtles1360
# 69127 turtles1361
# 69128 turtles1362
# 69129 turtles1363
# 69130 turtles1364
# 69131 turtles1365
# 69132 turtles1366
# 69133 turtles1367
# 69134 turtles1368
# 69135 turtles1369
# 69136 turtles1370
# 69137 turtles1371
# 69138 turtles1372
# 69139 turtles1373
# 69140 turtles1374
# 69141 turtles1375
# 69142 turtles1376
# 69143 turtles1377
# 69144 turtles1378
# 69145 turtles1379
# 69146 turtles1380
# 69147 turtles1381
# 69148 turtles1382
# 69149 turtles1383
# 69150 turtles1384
# 69151 turtles1385
# 69152 turtles1386
# 69153 turtles1387
# 69154 turtles1388
# 69155 turtles1389
# 69156 turtles1390
# 69157 turtles1391
# 69158 turtles1392
# 69159 turtles1393
# 69160 turtles1394
# 69161 turtles1395
# 69162 turtles1396
# 69163 turtles1397
# 69164 turtles1398
# 69165 turtles1399

# %% [markdown]
# ## 4 - Fonction de génération des requêtes

# %%
# Fonction pour générer toutes les requêtes d'un utilisateur 
def all_requests_1user(user_name,max_requetes,max_jours,threshold_city,threshold_language) : 
    # initialisation dataframe pour stocker la liste des requêtes + définir le nombre de requêtes faites : 
    df_user = pd.DataFrame()
    nb_requetes = random.randint(1,max_requetes)

    # Enregistrement du user_name sur toutes les lignes du df
    df_user["avatar_name"] = [user_name]*nb_requetes
    
    # Attribution d'une date 
    #--Choix des bornes 
    dates = np.sort(random.choices(list(range(max_jours)), k = nb_requetes))[::-1]
    df_user["date"] = dates
        
    # Attribution de la ville 
    city_user = random.choice(city) 
    prob = np.random.uniform(0,1,nb_requetes)
    vect_city = pd.Series([""]*nb_requetes)
    
    vect_city[prob >= threshold_city] = city_user
    vect_city[prob < threshold_city] = random.choice(city) 
    df_user["city"] = vect_city
    
    # Attribution de la langue : 
    # 1. une langue pour l'utilisateur :
    language_user = random.choice(language) 
    vect_language = pd.Series([language_user]*nb_requetes)
    
    # 2. remplacer cette langue par une langue similaire ? 
    if language_user in dic_similar_language : 
        prob = np.random.uniform(0,1,nb_requetes)
        ind = np.where(prob<=threshold_language)[0]
        vect_language[ind] = random.choice(dic_similar_language[language_user])
    
    # 3. remplacer cette langue par la langue du pays dans lequel l'utilisateur se rend ? 
    prob = np.random.uniform(0,1,nb_requetes)
    ind = np.where(prob<=threshold_language)[0]
    vect_language[ind] = dic_language_country[vect_city[ind]]
    df_user["language"] = vect_language
    
    # Attribution du mobile 
    df_user["mobile"] = random.choices([0,1],k=nb_requetes)
    return df_user

#Test
#df1 = all_requests_1user("turtles0",max_requetes,max_jours,threshold_city,threshold_language)

# %%
# Fonction pour créer un df pour stocker toutes les requêtes de tous les  utilisateurs 
def all_requests_all_users(nb_users,names,max_requetes,max_jours,threshold_city,threshold_language) : 
    df = pd.DataFrame(columns=np.r_[["avatar_name"],request_var])
    for i in range(nb_users) :
        # génération d'un df par user 
        df_1user = all_requests_1user(names[i],max_requetes,max_jours,threshold_city,threshold_language)
        # concaténation de tous les dataframes en un seul
        df = pd.concat([df,df_1user],ignore_index=True)
    return df 

#Test 
#df = all_requests_all_users(nb_users,names,max_requetes,max_jours,threshold_city,threshold_language)

# %%
#Sauvegarde des toutes nos prochaines requêtes 
# A NE PAS RUN
"""df = all_requests_all_users(700,names[701:],max_requetes,max_jours,threshold_city,threshold_language) 
df.to_csv('stock_requetes/data_requests2.csv', index=False)"""
# Out:
# "df = all_requests_all_users(700,names[701:],max_requetes,max_jours,threshold_city,threshold_language) \ndf.to_csv('stock_requetes/data_requests2.csv', index=False)"

# %%
df = pd.read_csv('stock_requetes/data_requests2.csv')

# %%
len(np.unique(df["avatar_name"]))
# Out:
# 700

# %% [markdown]
# ## 5 - Fonctions pour la mise en forme des données

# %%
# Transformer les requêtes (dictionnaire) en df 
def request_to_df(dic_request):
    # dataframe contenant le résultat de la requête : 
    df_prices = pd.DataFrame.from_dict(dic_request['prices'])

    # dataframe contenant les infos de la requête (que l'on dupplique pour avoir le même nombre de ligne) :
    df_1request = pd.DataFrame.from_dict([dic_request['request']])
    df_1request = pd.DataFrame(np.repeat(df_1request.values, len(df_prices.index), axis=0),columns=df_1request.columns)
    cols = list(df_1request.columns)
    cols = [cols[-1]] + cols[:-1]
    df_1request = df_1request[cols]

    # dataframe final pour un avatar ayant fait une requête : 
    df_1avatar = pd.concat([df_1request,df_prices],axis=1)
    
    return df_1avatar

#Test
#df_1avatar = request_to_df(test)

# 2. fonction pour concaténer les dataframes de plusieurs requêtes : 
def request_to_final_df(list_df) : 
    return pd.concat(list_df,axis=0,ignore_index=True)

#Test
#df_2avatar = request_to_final_df([df_1avatar,df_1avatar])

# 3. fonction pour transformer notre dataframe avec la liste des requêtes à faire en dict :

def request_to_dict(csv_file,ind_request) :
    # get the list of request we want to do : 
    data = pd.read_csv(csv_file)
    data2 = copy.deepcopy(data.iloc[ind_request])
    # associate avatar name to each request and order the columns : 
    # data2["avatar_name"] = names 
    cols = list(data2.columns)
    cols = [cols[-1]] + cols[:-1]
    data2 = data2[cols]
    # convert df to dict : 
    dic = data2.to_dict('records')
    return dic

#Test
#dic = request_to_dict('stock_requetes/data_requests1.csv',range(0,10))

# %% [markdown]
# ## Requêtes

# %% [markdown]
# Pour connaître le nombre de requêtes restantes, il faut taper dans une barre de recherche :
# `http://51.91.251.0:3000/remaining-requests/82a030f2-958a-4824-8ee0-85cde6f5668c`

# %%
user_id = '82a030f2-958a-4824-8ee0-85cde6f5668c'

# %%
#REPRENDRE le 29/10/2022 dès 14h30 :) 
start = 1223
end = 1500

# Création du dictionnaire pour les requêtes
dictio = request_to_dict('stock_requetes/data_requests2.csv',range(start,end))
stock_json = []
stock_df = []
for params in dictio :  
    print(params)
    """r2 = requests.get(path(f"pricing/{user_id}"), params=params)
    stock_json.append(r2.json())
    stock_df.append(request_to_df(r2.json()))"""
# Out:
# {'mobile': 1, 'avatar_name': 'turtles973', 'language': 'portuguese', 'city': 'valletta', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles973', 'language': 'portuguese', 'city': 'valletta', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles974', 'language': 'slovene', 'city': 'valletta', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles974', 'language': 'slovene', 'city': 'valletta', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles975', 'language': 'austrian', 'city': 'vienna', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles975', 'language': 'austrian', 'city': 'vienna', 'date': 24}
# {'mobile': 1, 'avatar_name': 'turtles975', 'language': 'austrian', 'city': 'vienna', 'date': 16}
# {'mobile': 1, 'avatar_name': 'turtles975', 'language': 'austrian', 'city': 'vienna', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles976', 'language': 'greek', 'city': 'madrid', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles976', 'language': 'greek', 'city': 'madrid', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles976', 'language': 'greek', 'city': 'madrid', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles977', 'language': 'lithuanian', 'city': 'rome', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles977', 'language': 'lithuanian', 'city': 'rome', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles977', 'language': 'lithuanian', 'city': 'rome', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles977', 'language': 'lithuanian', 'city': 'rome', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles978', 'language': 'dutch', 'city': 'paris', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles978', 'language': 'dutch', 'city': 'paris', 'date': 12}
# {'mobile': 1, 'avatar_name': 'turtles979', 'language': 'italian', 'city': 'vienna', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles979', 'language': 'italian', 'city': 'vienna', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles980', 'language': 'estonian', 'city': 'madrid', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles980', 'language': 'estonian', 'city': 'madrid', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles981', 'language': 'irish', 'city': 'vilnius', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles982', 'language': 'italian', 'city': 'valletta', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles982', 'language': 'italian', 'city': 'valletta', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles983', 'language': 'greek', 'city': 'paris', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles984', 'language': 'german', 'city': 'sofia', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles984', 'language': 'german', 'city': 'sofia', 'date': 18}
# {'mobile': 1, 'avatar_name': 'turtles985', 'language': 'finnish', 'city': 'madrid', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles986', 'language': 'hungarian', 'city': 'vilnius', 'date': 25}
# {'mobile': 1, 'avatar_name': 'turtles986', 'language': 'hungarian', 'city': 'vilnius', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles987', 'language': 'maltese', 'city': 'valletta', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles987', 'language': 'maltese', 'city': 'valletta', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles987', 'language': 'maltese', 'city': 'valletta', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles987', 'language': 'maltese', 'city': 'valletta', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles988', 'language': 'bulgarian', 'city': 'sofia', 'date': 25}
# {'mobile': 1, 'avatar_name': 'turtles988', 'language': 'bulgarian', 'city': 'sofia', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles988', 'language': 'bulgarian', 'city': 'sofia', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles989', 'language': 'irish', 'city': 'sofia', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles989', 'language': 'irish', 'city': 'sofia', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles990', 'language': 'estonian', 'city': 'madrid', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles990', 'language': 'estonian', 'city': 'madrid', 'date': 22}
# {'mobile': 0, 'avatar_name': 'turtles990', 'language': 'estonian', 'city': 'madrid', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles991', 'language': 'croatian', 'city': 'madrid', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles991', 'language': 'spanish', 'city': 'madrid', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles991', 'language': 'croatian', 'city': 'madrid', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles991', 'language': 'croatian', 'city': 'madrid', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles992', 'language': 'hungarian', 'city': 'vienna', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles992', 'language': 'hungarian', 'city': 'vienna', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles992', 'language': 'hungarian', 'city': 'vienna', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles993', 'language': 'irish', 'city': 'madrid', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles994', 'language': 'cypriot', 'city': 'vilnius', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles994', 'language': 'cypriot', 'city': 'vilnius', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles994', 'language': 'cypriot', 'city': 'vilnius', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles994', 'language': 'cypriot', 'city': 'vilnius', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles995', 'language': 'greek', 'city': 'vienna', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles996', 'language': 'belgian', 'city': 'copenhagen', 'date': 38}
# {'mobile': 0, 'avatar_name': 'turtles997', 'language': 'maltese', 'city': 'amsterdam', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles997', 'language': 'maltese', 'city': 'amsterdam', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles997', 'language': 'maltese', 'city': 'amsterdam', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles998', 'language': 'romanian', 'city': 'sofia', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles998', 'language': 'romanian', 'city': 'sofia', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles998', 'language': 'romanian', 'city': 'sofia', 'date': 13}
# {'mobile': 1, 'avatar_name': 'turtles999', 'language': 'slovakian', 'city': 'madrid', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles999', 'language': 'slovakian', 'city': 'madrid', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles999', 'language': 'slovakian', 'city': 'madrid', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles1000', 'language': 'slovene', 'city': 'copenhagen', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles1000', 'language': 'slovene', 'city': 'copenhagen', 'date': 21}
# {'mobile': 1, 'avatar_name': 'turtles1000', 'language': 'slovene', 'city': 'copenhagen', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles1001', 'language': 'luxembourgish', 'city': 'paris', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles1001', 'language': 'luxembourgish', 'city': 'paris', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles1001', 'language': 'luxembourgish', 'city': 'paris', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles1002', 'language': 'czech', 'city': 'paris', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles1002', 'language': 'czech', 'city': 'paris', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles1002', 'language': 'czech', 'city': 'paris', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles1002', 'language': 'czech', 'city': 'paris', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles1003', 'language': 'austrian', 'city': 'amsterdam', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles1004', 'language': 'maltese', 'city': 'copenhagen', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles1004', 'language': 'maltese', 'city': 'copenhagen', 'date': 26}
# {'mobile': 1, 'avatar_name': 'turtles1004', 'language': 'maltese', 'city': 'copenhagen', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles1005', 'language': 'lithuanian', 'city': 'copenhagen', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles1006', 'language': 'finnish', 'city': 'vienna', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles1006', 'language': 'finnish', 'city': 'vienna', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles1006', 'language': 'finnish', 'city': 'vienna', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles1007', 'language': 'hungarian', 'city': 'paris', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles1007', 'language': 'hungarian', 'city': 'paris', 'date': 25}
# {'mobile': 1, 'avatar_name': 'turtles1007', 'language': 'hungarian', 'city': 'paris', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles1007', 'language': 'hungarian', 'city': 'paris', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles1008', 'language': 'finnish', 'city': 'sofia', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles1008', 'language': 'finnish', 'city': 'sofia', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles1008', 'language': 'finnish', 'city': 'sofia', 'date': 24}
# {'mobile': 1, 'avatar_name': 'turtles1009', 'language': 'latvian', 'city': 'sofia', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles1009', 'language': 'latvian', 'city': 'sofia', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles1009', 'language': 'latvian', 'city': 'sofia', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles1010', 'language': 'irish', 'city': 'vienna', 'date': 5}
# {'mobile': 0, 'avatar_name': 'turtles1011', 'language': 'estonian', 'city': 'valletta', 'date': 42}
# {'mobile': 1, 'avatar_name': 'turtles1011', 'language': 'estonian', 'city': 'valletta', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles1011', 'language': 'maltese', 'city': 'valletta', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles1011', 'language': 'estonian', 'city': 'valletta', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles1012', 'language': 'italian', 'city': 'copenhagen', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles1013', 'language': 'estonian', 'city': 'rome', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles1014', 'language': 'czech', 'city': 'copenhagen', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles1014', 'language': 'czech', 'city': 'copenhagen', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles1014', 'language': 'czech', 'city': 'copenhagen', 'date': 7}
# {'mobile': 1, 'avatar_name': 'turtles1015', 'language': 'belgian', 'city': 'valletta', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles1015', 'language': 'belgian', 'city': 'valletta', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles1016', 'language': 'french', 'city': 'vienna', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles1017', 'language': 'czech', 'city': 'sofia', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles1017', 'language': 'czech', 'city': 'sofia', 'date': 25}
# {'mobile': 1, 'avatar_name': 'turtles1017', 'language': 'czech', 'city': 'sofia', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles1018', 'language': 'bulgarian', 'city': 'amsterdam', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles1018', 'language': 'bulgarian', 'city': 'amsterdam', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles1018', 'language': 'bulgarian', 'city': 'amsterdam', 'date': 3}
# {'mobile': 0, 'avatar_name': 'turtles1018', 'language': 'bulgarian', 'city': 'amsterdam', 'date': 1}
# {'mobile': 0, 'avatar_name': 'turtles1019', 'language': 'spanish', 'city': 'amsterdam', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles1019', 'language': 'spanish', 'city': 'amsterdam', 'date': 21}
# {'mobile': 1, 'avatar_name': 'turtles1020', 'language': 'cypriot', 'city': 'sofia', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles1020', 'language': 'cypriot', 'city': 'sofia', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles1021', 'language': 'belgian', 'city': 'rome', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles1021', 'language': 'belgian', 'city': 'rome', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles1021', 'language': 'belgian', 'city': 'rome', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles1021', 'language': 'belgian', 'city': 'paris', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles1022', 'language': 'polish', 'city': 'vilnius', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles1023', 'language': 'cypriot', 'city': 'valletta', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles1023', 'language': 'cypriot', 'city': 'valletta', 'date': 17}
# {'mobile': 0, 'avatar_name': 'turtles1023', 'language': 'cypriot', 'city': 'valletta', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles1024', 'language': 'spanish', 'city': 'vienna', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles1024', 'language': 'spanish', 'city': 'vienna', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles1024', 'language': 'spanish', 'city': 'vienna', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles1025', 'language': 'austrian', 'city': 'sofia', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles1025', 'language': 'austrian', 'city': 'sofia', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles1026', 'language': 'luxembourgish', 'city': 'sofia', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles1027', 'language': 'slovene', 'city': 'vilnius', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles1027', 'language': 'slovene', 'city': 'madrid', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles1027', 'language': 'slovene', 'city': 'vilnius', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles1027', 'language': 'slovene', 'city': 'vilnius', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles1028', 'language': 'greek', 'city': 'paris', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles1028', 'language': 'greek', 'city': 'copenhagen', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles1028', 'language': 'greek', 'city': 'copenhagen', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles1029', 'language': 'slovakian', 'city': 'vienna', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles1030', 'language': 'bulgarian', 'city': 'amsterdam', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles1030', 'language': 'bulgarian', 'city': 'amsterdam', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles1031', 'language': 'hungarian', 'city': 'sofia', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles1031', 'language': 'hungarian', 'city': 'sofia', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles1031', 'language': 'hungarian', 'city': 'sofia', 'date': 7}
# {'mobile': 1, 'avatar_name': 'turtles1032', 'language': 'austrian', 'city': 'rome', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles1032', 'language': 'austrian', 'city': 'rome', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles1033', 'language': 'belgian', 'city': 'madrid', 'date': 17}
# {'mobile': 0, 'avatar_name': 'turtles1034', 'language': 'slovene', 'city': 'rome', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles1034', 'language': 'slovene', 'city': 'rome', 'date': 10}
# {'mobile': 0, 'avatar_name': 'turtles1034', 'language': 'slovene', 'city': 'rome', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles1035', 'language': 'spanish', 'city': 'paris', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles1036', 'language': 'finnish', 'city': 'copenhagen', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles1037', 'language': 'german', 'city': 'copenhagen', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles1037', 'language': 'german', 'city': 'copenhagen', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles1038', 'language': 'slovene', 'city': 'paris', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles1038', 'language': 'slovene', 'city': 'paris', 'date': 0}
# {'mobile': 1, 'avatar_name': 'turtles1038', 'language': 'slovene', 'city': 'paris', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles1039', 'language': 'irish', 'city': 'amsterdam', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles1039', 'language': 'irish', 'city': 'amsterdam', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles1039', 'language': 'irish', 'city': 'amsterdam', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles1040', 'language': 'greek', 'city': 'vienna', 'date': 31}
# {'mobile': 0, 'avatar_name': 'turtles1041', 'language': 'portuguese', 'city': 'rome', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles1042', 'language': 'greek', 'city': 'amsterdam', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles1042', 'language': 'greek', 'city': 'amsterdam', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles1042', 'language': 'greek', 'city': 'amsterdam', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles1042', 'language': 'dutch', 'city': 'amsterdam', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles1043', 'language': 'danish', 'city': 'paris', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles1043', 'language': 'danish', 'city': 'paris', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles1044', 'language': 'croatian', 'city': 'valletta', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles1044', 'language': 'croatian', 'city': 'valletta', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles1045', 'language': 'french', 'city': 'vienna', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles1045', 'language': 'belgian', 'city': 'amsterdam', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles1046', 'language': 'croatian', 'city': 'amsterdam', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles1047', 'language': 'dutch', 'city': 'madrid', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles1047', 'language': 'dutch', 'city': 'madrid', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles1047', 'language': 'dutch', 'city': 'madrid', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles1048', 'language': 'cypriot', 'city': 'rome', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles1048', 'language': 'cypriot', 'city': 'rome', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles1048', 'language': 'cypriot', 'city': 'rome', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles1049', 'language': 'maltese', 'city': 'valletta', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles1049', 'language': 'maltese', 'city': 'valletta', 'date': 7}
# {'mobile': 1, 'avatar_name': 'turtles1049', 'language': 'maltese', 'city': 'valletta', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles1050', 'language': 'slovene', 'city': 'madrid', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles1050', 'language': 'slovene', 'city': 'madrid', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles1050', 'language': 'slovene', 'city': 'madrid', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles1050', 'language': 'slovene', 'city': 'madrid', 'date': 3}
# {'mobile': 0, 'avatar_name': 'turtles1051', 'language': 'portuguese', 'city': 'sofia', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles1051', 'language': 'portuguese', 'city': 'sofia', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles1051', 'language': 'portuguese', 'city': 'sofia', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles1052', 'language': 'latvian', 'city': 'valletta', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles1052', 'language': 'latvian', 'city': 'valletta', 'date': 21}
# {'mobile': 1, 'avatar_name': 'turtles1052', 'language': 'latvian', 'city': 'valletta', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles1052', 'language': 'latvian', 'city': 'valletta', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles1053', 'language': 'austrian', 'city': 'amsterdam', 'date': 25}
# {'mobile': 0, 'avatar_name': 'turtles1053', 'language': 'austrian', 'city': 'amsterdam', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles1054', 'language': 'danish', 'city': 'sofia', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles1054', 'language': 'danish', 'city': 'sofia', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles1054', 'language': 'danish', 'city': 'sofia', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles1054', 'language': 'danish', 'city': 'sofia', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles1055', 'language': 'irish', 'city': 'madrid', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles1055', 'language': 'irish', 'city': 'madrid', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles1055', 'language': 'irish', 'city': 'madrid', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles1055', 'language': 'irish', 'city': 'madrid', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles1056', 'language': 'polish', 'city': 'vilnius', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles1057', 'language': 'bulgarian', 'city': 'vilnius', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles1057', 'language': 'bulgarian', 'city': 'vilnius', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles1058', 'language': 'danish', 'city': 'copenhagen', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles1058', 'language': 'luxembourgish', 'city': 'copenhagen', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles1058', 'language': 'luxembourgish', 'city': 'copenhagen', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles1059', 'language': 'estonian', 'city': 'madrid', 'date': 15}
# {'mobile': 0, 'avatar_name': 'turtles1059', 'language': 'estonian', 'city': 'madrid', 'date': 11}
# {'mobile': 0, 'avatar_name': 'turtles1059', 'language': 'estonian', 'city': 'madrid', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles1060', 'language': 'maltese', 'city': 'rome', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles1060', 'language': 'maltese', 'city': 'rome', 'date': 25}
# {'mobile': 1, 'avatar_name': 'turtles1060', 'language': 'maltese', 'city': 'rome', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles1060', 'language': 'maltese', 'city': 'rome', 'date': 21}
# {'mobile': 1, 'avatar_name': 'turtles1061', 'language': 'finnish', 'city': 'amsterdam', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles1061', 'language': 'finnish', 'city': 'amsterdam', 'date': 19}
# {'mobile': 0, 'avatar_name': 'turtles1062', 'language': 'dutch', 'city': 'rome', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles1062', 'language': 'dutch', 'city': 'rome', 'date': 24}
# {'mobile': 1, 'avatar_name': 'turtles1062', 'language': 'dutch', 'city': 'rome', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles1062', 'language': 'dutch', 'city': 'rome', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles1063', 'language': 'romanian', 'city': 'vienna', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles1063', 'language': 'romanian', 'city': 'vienna', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles1064', 'language': 'hungarian', 'city': 'vienna', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles1064', 'language': 'hungarian', 'city': 'vienna', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles1064', 'language': 'hungarian', 'city': 'vienna', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles1065', 'language': 'cypriot', 'city': 'paris', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles1065', 'language': 'cypriot', 'city': 'paris', 'date': 21}
# {'mobile': 1, 'avatar_name': 'turtles1065', 'language': 'cypriot', 'city': 'paris', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles1065', 'language': 'cypriot', 'city': 'paris', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles1066', 'language': 'estonian', 'city': 'madrid', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles1066', 'language': 'estonian', 'city': 'madrid', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles1066', 'language': 'estonian', 'city': 'madrid', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles1067', 'language': 'estonian', 'city': 'amsterdam', 'date': 42}
# {'mobile': 1, 'avatar_name': 'turtles1067', 'language': 'estonian', 'city': 'amsterdam', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles1067', 'language': 'estonian', 'city': 'amsterdam', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles1067', 'language': 'estonian', 'city': 'amsterdam', 'date': 5}
# {'mobile': 0, 'avatar_name': 'turtles1068', 'language': 'belgian', 'city': 'copenhagen', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles1068', 'language': 'belgian', 'city': 'copenhagen', 'date': 17}
# {'mobile': 0, 'avatar_name': 'turtles1069', 'language': 'slovakian', 'city': 'paris', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles1069', 'language': 'slovakian', 'city': 'madrid', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles1070', 'language': 'latvian', 'city': 'paris', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles1071', 'language': 'hungarian', 'city': 'vilnius', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles1071', 'language': 'hungarian', 'city': 'vilnius', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles1071', 'language': 'hungarian', 'city': 'vilnius', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles1072', 'language': 'dutch', 'city': 'amsterdam', 'date': 43}
# {'mobile': 0, 'avatar_name': 'turtles1072', 'language': 'finnish', 'city': 'amsterdam', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles1072', 'language': 'finnish', 'city': 'amsterdam', 'date': 25}
# {'mobile': 0, 'avatar_name': 'turtles1072', 'language': 'finnish', 'city': 'amsterdam', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles1073', 'language': 'french', 'city': 'amsterdam', 'date': 3}
# {'mobile': 0, 'avatar_name': 'turtles1074', 'language': 'croatian', 'city': 'vilnius', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles1074', 'language': 'croatian', 'city': 'vilnius', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles1074', 'language': 'croatian', 'city': 'vilnius', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles1074', 'language': 'croatian', 'city': 'vilnius', 'date': 0}
# {'mobile': 1, 'avatar_name': 'turtles1075', 'language': 'lithuanian', 'city': 'sofia', 'date': 7}
# {'mobile': 1, 'avatar_name': 'turtles1075', 'language': 'lithuanian', 'city': 'sofia', 'date': 1}
# {'mobile': 0, 'avatar_name': 'turtles1075', 'language': 'lithuanian', 'city': 'sofia', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles1076', 'language': 'german', 'city': 'paris', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles1077', 'language': 'portuguese', 'city': 'madrid', 'date': 13}
# {'mobile': 1, 'avatar_name': 'turtles1078', 'language': 'swedish', 'city': 'rome', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles1078', 'language': 'swedish', 'city': 'rome', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles1078', 'language': 'swedish', 'city': 'rome', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles1079', 'language': 'bulgarian', 'city': 'madrid', 'date': 42}
# {'mobile': 1, 'avatar_name': 'turtles1079', 'language': 'bulgarian', 'city': 'madrid', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles1079', 'language': 'bulgarian', 'city': 'madrid', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles1080', 'language': 'czech', 'city': 'rome', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles1080', 'language': 'czech', 'city': 'rome', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles1080', 'language': 'czech', 'city': 'vienna', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles1080', 'language': 'czech', 'city': 'rome', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles1081', 'language': 'slovene', 'city': 'vilnius', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles1081', 'language': 'slovene', 'city': 'vilnius', 'date': 12}
# {'mobile': 1, 'avatar_name': 'turtles1081', 'language': 'slovene', 'city': 'vilnius', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles1081', 'language': 'slovene', 'city': 'vilnius', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles1082', 'language': 'irish', 'city': 'amsterdam', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles1082', 'language': 'irish', 'city': 'madrid', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles1082', 'language': 'irish', 'city': 'amsterdam', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles1082', 'language': 'irish', 'city': 'madrid', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles1083', 'language': 'portuguese', 'city': 'madrid', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles1084', 'language': 'belgian', 'city': 'vienna', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles1084', 'language': 'belgian', 'city': 'vienna', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles1084', 'language': 'belgian', 'city': 'vienna', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles1085', 'language': 'maltese', 'city': 'paris', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles1085', 'language': 'maltese', 'city': 'paris', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles1085', 'language': 'maltese', 'city': 'paris', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles1085', 'language': 'maltese', 'city': 'paris', 'date': 31}
# {'mobile': 0, 'avatar_name': 'turtles1086', 'language': 'belgian', 'city': 'amsterdam', 'date': 22}
# {'mobile': 0, 'avatar_name': 'turtles1086', 'language': 'belgian', 'city': 'amsterdam', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles1086', 'language': 'belgian', 'city': 'amsterdam', 'date': 12}
# {'mobile': 1, 'avatar_name': 'turtles1087', 'language': 'french', 'city': 'vienna', 'date': 31}
# {'mobile': 0, 'avatar_name': 'turtles1087', 'language': 'french', 'city': 'vienna', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles1088', 'language': 'hungarian', 'city': 'vilnius', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles1088', 'language': 'hungarian', 'city': 'vilnius', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles1088', 'language': 'hungarian', 'city': 'vilnius', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles1089', 'language': 'romanian', 'city': 'copenhagen', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles1089', 'language': 'romanian', 'city': 'copenhagen', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles1090', 'language': 'latvian', 'city': 'madrid', 'date': 42}
# {'mobile': 1, 'avatar_name': 'turtles1090', 'language': 'latvian', 'city': 'madrid', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles1090', 'language': 'latvian', 'city': 'madrid', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles1091', 'language': 'finnish', 'city': 'valletta', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles1091', 'language': 'finnish', 'city': 'valletta', 'date': 7}
# {'mobile': 0, 'avatar_name': 'turtles1092', 'language': 'dutch', 'city': 'copenhagen', 'date': 36}
# {'mobile': 1, 'avatar_name': 'turtles1092', 'language': 'dutch', 'city': 'copenhagen', 'date': 25}
# {'mobile': 0, 'avatar_name': 'turtles1092', 'language': 'dutch', 'city': 'copenhagen', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles1093', 'language': 'romanian', 'city': 'vilnius', 'date': 40}
# {'mobile': 0, 'avatar_name': 'turtles1093', 'language': 'romanian', 'city': 'vilnius', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles1093', 'language': 'lithuanian', 'city': 'vilnius', 'date': 12}
# {'mobile': 1, 'avatar_name': 'turtles1093', 'language': 'romanian', 'city': 'vilnius', 'date': 2}
# {'mobile': 1, 'avatar_name': 'turtles1094', 'language': 'danish', 'city': 'copenhagen', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles1094', 'language': 'danish', 'city': 'copenhagen', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles1095', 'language': 'slovene', 'city': 'vilnius', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles1095', 'language': 'slovene', 'city': 'vilnius', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles1095', 'language': 'slovene', 'city': 'vilnius', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles1095', 'language': 'slovene', 'city': 'vilnius', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles1096', 'language': 'dutch', 'city': 'paris', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles1096', 'language': 'dutch', 'city': 'paris', 'date': 26}
# {'mobile': 1, 'avatar_name': 'turtles1096', 'language': 'dutch', 'city': 'paris', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles1096', 'language': 'dutch', 'city': 'paris', 'date': 5}
# {'mobile': 0, 'avatar_name': 'turtles1097', 'language': 'polish', 'city': 'paris', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles1098', 'language': 'slovene', 'city': 'amsterdam', 'date': 29}
# {'mobile': 1, 'avatar_name': 'turtles1098', 'language': 'slovene', 'city': 'amsterdam', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles1098', 'language': 'slovene', 'city': 'amsterdam', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles1099', 'language': 'spanish', 'city': 'vienna', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles1099', 'language': 'spanish', 'city': 'vienna', 'date': 38}
# {'mobile': 0, 'avatar_name': 'turtles1099', 'language': 'spanish', 'city': 'vienna', 'date': 17}
# {'mobile': 0, 'avatar_name': 'turtles1099', 'language': 'spanish', 'city': 'vienna', 'date': 10}
# {'mobile': 0, 'avatar_name': 'turtles1100', 'language': 'spanish', 'city': 'valletta', 'date': 26}
# {'mobile': 1, 'avatar_name': 'turtles1100', 'language': 'spanish', 'city': 'valletta', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles1101', 'language': 'luxembourgish', 'city': 'sofia', 'date': 41}
# {'mobile': 0, 'avatar_name': 'turtles1101', 'language': 'luxembourgish', 'city': 'sofia', 'date': 40}
# {'mobile': 1, 'avatar_name': 'turtles1101', 'language': 'luxembourgish', 'city': 'sofia', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles1101', 'language': 'luxembourgish', 'city': 'sofia', 'date': 4}
# {'mobile': 0, 'avatar_name': 'turtles1102', 'language': 'hungarian', 'city': 'copenhagen', 'date': 43}
# {'mobile': 0, 'avatar_name': 'turtles1102', 'language': 'hungarian', 'city': 'copenhagen', 'date': 37}
# {'mobile': 1, 'avatar_name': 'turtles1102', 'language': 'hungarian', 'city': 'copenhagen', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles1103', 'language': 'swedish', 'city': 'madrid', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles1103', 'language': 'swedish', 'city': 'madrid', 'date': 39}
# {'mobile': 1, 'avatar_name': 'turtles1103', 'language': 'swedish', 'city': 'madrid', 'date': 25}
# {'mobile': 1, 'avatar_name': 'turtles1103', 'language': 'swedish', 'city': 'madrid', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles1104', 'language': 'polish', 'city': 'paris', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles1104', 'language': 'polish', 'city': 'paris', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles1105', 'language': 'polish', 'city': 'sofia', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles1105', 'language': 'polish', 'city': 'sofia', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles1105', 'language': 'polish', 'city': 'sofia', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles1105', 'language': 'polish', 'city': 'sofia', 'date': 13}
# {'mobile': 1, 'avatar_name': 'turtles1106', 'language': 'german', 'city': 'amsterdam', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles1106', 'language': 'dutch', 'city': 'amsterdam', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles1107', 'language': 'slovene', 'city': 'sofia', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles1107', 'language': 'slovene', 'city': 'sofia', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles1107', 'language': 'slovene', 'city': 'sofia', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles1108', 'language': 'slovene', 'city': 'amsterdam', 'date': 24}
# {'mobile': 0, 'avatar_name': 'turtles1109', 'language': 'bulgarian', 'city': 'copenhagen', 'date': 17}
# {'mobile': 0, 'avatar_name': 'turtles1110', 'language': 'slovene', 'city': 'vilnius', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles1111', 'language': 'danish', 'city': 'rome', 'date': 38}
# {'mobile': 0, 'avatar_name': 'turtles1111', 'language': 'danish', 'city': 'rome', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles1112', 'language': 'danish', 'city': 'vienna', 'date': 26}
# {'mobile': 1, 'avatar_name': 'turtles1113', 'language': 'swedish', 'city': 'vienna', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles1113', 'language': 'swedish', 'city': 'vienna', 'date': 13}
# {'mobile': 1, 'avatar_name': 'turtles1114', 'language': 'lithuanian', 'city': 'rome', 'date': 26}
# {'mobile': 1, 'avatar_name': 'turtles1114', 'language': 'lithuanian', 'city': 'paris', 'date': 25}
# {'mobile': 1, 'avatar_name': 'turtles1114', 'language': 'lithuanian', 'city': 'rome', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles1114', 'language': 'lithuanian', 'city': 'rome', 'date': 15}
# {'mobile': 0, 'avatar_name': 'turtles1115', 'language': 'slovene', 'city': 'rome', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles1115', 'language': 'slovene', 'city': 'rome', 'date': 30}
# {'mobile': 0, 'avatar_name': 'turtles1115', 'language': 'slovene', 'city': 'rome', 'date': 24}
# {'mobile': 1, 'avatar_name': 'turtles1116', 'language': 'swedish', 'city': 'madrid', 'date': 7}
# {'mobile': 1, 'avatar_name': 'turtles1116', 'language': 'swedish', 'city': 'madrid', 'date': 5}
# {'mobile': 0, 'avatar_name': 'turtles1116', 'language': 'swedish', 'city': 'madrid', 'date': 1}
# {'mobile': 0, 'avatar_name': 'turtles1117', 'language': 'danish', 'city': 'paris', 'date': 42}
# {'mobile': 1, 'avatar_name': 'turtles1117', 'language': 'danish', 'city': 'paris', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles1117', 'language': 'danish', 'city': 'paris', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles1117', 'language': 'danish', 'city': 'paris', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles1118', 'language': 'finnish', 'city': 'rome', 'date': 16}
# {'mobile': 1, 'avatar_name': 'turtles1118', 'language': 'finnish', 'city': 'rome', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles1118', 'language': 'finnish', 'city': 'rome', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles1118', 'language': 'finnish', 'city': 'rome', 'date': 1}
# {'mobile': 0, 'avatar_name': 'turtles1119', 'language': 'belgian', 'city': 'valletta', 'date': 29}
# {'mobile': 0, 'avatar_name': 'turtles1119', 'language': 'belgian', 'city': 'valletta', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles1119', 'language': 'belgian', 'city': 'valletta', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles1120', 'language': 'irish', 'city': 'vienna', 'date': 43}
# {'mobile': 0, 'avatar_name': 'turtles1120', 'language': 'irish', 'city': 'vienna', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles1121', 'language': 'german', 'city': 'rome', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles1122', 'language': 'polish', 'city': 'sofia', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles1122', 'language': 'polish', 'city': 'sofia', 'date': 7}
# {'mobile': 1, 'avatar_name': 'turtles1122', 'language': 'polish', 'city': 'sofia', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles1123', 'language': 'estonian', 'city': 'valletta', 'date': 38}
# {'mobile': 0, 'avatar_name': 'turtles1123', 'language': 'estonian', 'city': 'valletta', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles1123', 'language': 'maltese', 'city': 'valletta', 'date': 16}
# {'mobile': 1, 'avatar_name': 'turtles1123', 'language': 'estonian', 'city': 'valletta', 'date': 11}
# {'mobile': 0, 'avatar_name': 'turtles1124', 'language': 'german', 'city': 'vilnius', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles1124', 'language': 'austrian', 'city': 'vilnius', 'date': 27}
# {'mobile': 0, 'avatar_name': 'turtles1124', 'language': 'german', 'city': 'vilnius', 'date': 24}
# {'mobile': 1, 'avatar_name': 'turtles1125', 'language': 'luxembourgish', 'city': 'copenhagen', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles1126', 'language': 'czech', 'city': 'vienna', 'date': 36}
# {'mobile': 0, 'avatar_name': 'turtles1126', 'language': 'czech', 'city': 'vienna', 'date': 27}
# {'mobile': 1, 'avatar_name': 'turtles1126', 'language': 'czech', 'city': 'vienna', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles1126', 'language': 'czech', 'city': 'vienna', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles1127', 'language': 'slovene', 'city': 'rome', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles1128', 'language': 'spanish', 'city': 'paris', 'date': 42}
# {'mobile': 0, 'avatar_name': 'turtles1128', 'language': 'spanish', 'city': 'paris', 'date': 32}
# {'mobile': 1, 'avatar_name': 'turtles1128', 'language': 'spanish', 'city': 'paris', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles1128', 'language': 'spanish', 'city': 'paris', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles1129', 'language': 'estonian', 'city': 'sofia', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles1129', 'language': 'estonian', 'city': 'sofia', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles1129', 'language': 'estonian', 'city': 'sofia', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles1130', 'language': 'czech', 'city': 'copenhagen', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles1130', 'language': 'czech', 'city': 'copenhagen', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles1131', 'language': 'maltese', 'city': 'vilnius', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles1131', 'language': 'maltese', 'city': 'vilnius', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles1131', 'language': 'maltese', 'city': 'vilnius', 'date': 0}
# {'mobile': 1, 'avatar_name': 'turtles1132', 'language': 'italian', 'city': 'valletta', 'date': 14}
# {'mobile': 0, 'avatar_name': 'turtles1133', 'language': 'polish', 'city': 'vilnius', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles1134', 'language': 'slovene', 'city': 'madrid', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles1134', 'language': 'slovene', 'city': 'madrid', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles1134', 'language': 'slovene', 'city': 'madrid', 'date': 26}
# {'mobile': 0, 'avatar_name': 'turtles1134', 'language': 'slovene', 'city': 'madrid', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles1135', 'language': 'romanian', 'city': 'rome', 'date': 33}
# {'mobile': 0, 'avatar_name': 'turtles1135', 'language': 'romanian', 'city': 'amsterdam', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles1136', 'language': 'greek', 'city': 'copenhagen', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles1137', 'language': 'finnish', 'city': 'sofia', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles1137', 'language': 'finnish', 'city': 'sofia', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles1138', 'language': 'greek', 'city': 'paris', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles1139', 'language': 'polish', 'city': 'rome', 'date': 31}
# {'mobile': 0, 'avatar_name': 'turtles1140', 'language': 'spanish', 'city': 'paris', 'date': 39}
# {'mobile': 0, 'avatar_name': 'turtles1140', 'language': 'spanish', 'city': 'paris', 'date': 28}
# {'mobile': 1, 'avatar_name': 'turtles1140', 'language': 'spanish', 'city': 'paris', 'date': 25}
# {'mobile': 0, 'avatar_name': 'turtles1141', 'language': 'bulgarian', 'city': 'valletta', 'date': 1}
# {'mobile': 1, 'avatar_name': 'turtles1142', 'language': 'belgian', 'city': 'rome', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles1142', 'language': 'belgian', 'city': 'rome', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles1142', 'language': 'belgian', 'city': 'rome', 'date': 0}
# {'mobile': 1, 'avatar_name': 'turtles1143', 'language': 'austrian', 'city': 'vienna', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles1143', 'language': 'austrian', 'city': 'vienna', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles1143', 'language': 'austrian', 'city': 'vienna', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles1143', 'language': 'austrian', 'city': 'vienna', 'date': 4}
# {'mobile': 1, 'avatar_name': 'turtles1144', 'language': 'latvian', 'city': 'sofia', 'date': 41}
# {'mobile': 1, 'avatar_name': 'turtles1144', 'language': 'latvian', 'city': 'sofia', 'date': 38}
# {'mobile': 0, 'avatar_name': 'turtles1145', 'language': 'french', 'city': 'valletta', 'date': 14}
# {'mobile': 1, 'avatar_name': 'turtles1146', 'language': 'czech', 'city': 'vienna', 'date': 22}
# {'mobile': 0, 'avatar_name': 'turtles1146', 'language': 'czech', 'city': 'vienna', 'date': 1}
# {'mobile': 0, 'avatar_name': 'turtles1147', 'language': 'lithuanian', 'city': 'madrid', 'date': 37}
# {'mobile': 0, 'avatar_name': 'turtles1147', 'language': 'lithuanian', 'city': 'madrid', 'date': 19}
# {'mobile': 0, 'avatar_name': 'turtles1147', 'language': 'lithuanian', 'city': 'madrid', 'date': 2}
# {'mobile': 0, 'avatar_name': 'turtles1148', 'language': 'maltese', 'city': 'vienna', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles1149', 'language': 'lithuanian', 'city': 'madrid', 'date': 38}
# {'mobile': 1, 'avatar_name': 'turtles1149', 'language': 'lithuanian', 'city': 'rome', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles1149', 'language': 'lithuanian', 'city': 'rome', 'date': 22}
# {'mobile': 0, 'avatar_name': 'turtles1150', 'language': 'romanian', 'city': 'valletta', 'date': 0}
# {'mobile': 0, 'avatar_name': 'turtles1151', 'language': 'lithuanian', 'city': 'sofia', 'date': 9}
# {'mobile': 1, 'avatar_name': 'turtles1152', 'language': 'slovene', 'city': 'paris', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles1153', 'language': 'cypriot', 'city': 'amsterdam', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles1153', 'language': 'cypriot', 'city': 'amsterdam', 'date': 16}
# {'mobile': 0, 'avatar_name': 'turtles1154', 'language': 'swedish', 'city': 'valletta', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles1154', 'language': 'swedish', 'city': 'valletta', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles1154', 'language': 'swedish', 'city': 'valletta', 'date': 15}
# {'mobile': 1, 'avatar_name': 'turtles1154', 'language': 'swedish', 'city': 'valletta', 'date': 5}
# {'mobile': 1, 'avatar_name': 'turtles1155', 'language': 'estonian', 'city': 'vilnius', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles1155', 'language': 'estonian', 'city': 'vilnius', 'date': 9}
# {'mobile': 0, 'avatar_name': 'turtles1156', 'language': 'polish', 'city': 'sofia', 'date': 26}
# {'mobile': 1, 'avatar_name': 'turtles1156', 'language': 'polish', 'city': 'sofia', 'date': 20}
# {'mobile': 0, 'avatar_name': 'turtles1156', 'language': 'polish', 'city': 'sofia', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles1156', 'language': 'polish', 'city': 'sofia', 'date': 19}
# {'mobile': 0, 'avatar_name': 'turtles1157', 'language': 'czech', 'city': 'vilnius', 'date': 28}
# {'mobile': 0, 'avatar_name': 'turtles1157', 'language': 'czech', 'city': 'vilnius', 'date': 23}
# {'mobile': 0, 'avatar_name': 'turtles1158', 'language': 'german', 'city': 'vienna', 'date': 31}
# {'mobile': 1, 'avatar_name': 'turtles1158', 'language': 'german', 'city': 'vienna', 'date': 15}
# {'mobile': 0, 'avatar_name': 'turtles1158', 'language': 'german', 'city': 'vienna', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles1159', 'language': 'portuguese', 'city': 'amsterdam', 'date': 20}
# {'mobile': 1, 'avatar_name': 'turtles1159', 'language': 'portuguese', 'city': 'amsterdam', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles1159', 'language': 'portuguese', 'city': 'amsterdam', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles1159', 'language': 'portuguese', 'city': 'amsterdam', 'date': 6}
# {'mobile': 0, 'avatar_name': 'turtles1160', 'language': 'slovene', 'city': 'vienna', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles1160', 'language': 'slovene', 'city': 'vienna', 'date': 10}
# {'mobile': 1, 'avatar_name': 'turtles1161', 'language': 'french', 'city': 'madrid', 'date': 17}
# {'mobile': 1, 'avatar_name': 'turtles1161', 'language': 'french', 'city': 'madrid', 'date': 6}
# {'mobile': 1, 'avatar_name': 'turtles1162', 'language': 'swedish', 'city': 'sofia', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles1162', 'language': 'swedish', 'city': 'sofia', 'date': 35}
# {'mobile': 1, 'avatar_name': 'turtles1162', 'language': 'swedish', 'city': 'sofia', 'date': 34}
# {'mobile': 1, 'avatar_name': 'turtles1163', 'language': 'italian', 'city': 'rome', 'date': 12}
# {'mobile': 0, 'avatar_name': 'turtles1164', 'language': 'french', 'city': 'vienna', 'date': 32}
# {'mobile': 0, 'avatar_name': 'turtles1164', 'language': 'french', 'city': 'vienna', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles1164', 'language': 'french', 'city': 'vienna', 'date': 21}
# {'mobile': 0, 'avatar_name': 'turtles1164', 'language': 'french', 'city': 'vienna', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles1165', 'language': 'estonian', 'city': 'vienna', 'date': 43}
# {'mobile': 1, 'avatar_name': 'turtles1165', 'language': 'estonian', 'city': 'vienna', 'date': 23}
# {'mobile': 1, 'avatar_name': 'turtles1165', 'language': 'estonian', 'city': 'vienna', 'date': 11}
# {'mobile': 1, 'avatar_name': 'turtles1165', 'language': 'estonian', 'city': 'vienna', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles1166', 'language': 'slovakian', 'city': 'madrid', 'date': 34}
# {'mobile': 0, 'avatar_name': 'turtles1166', 'language': 'slovakian', 'city': 'madrid', 'date': 19}
# {'mobile': 1, 'avatar_name': 'turtles1166', 'language': 'slovakian', 'city': 'madrid', 'date': 16}
# {'mobile': 1, 'avatar_name': 'turtles1166', 'language': 'slovakian', 'city': 'madrid', 'date': 3}
# {'mobile': 1, 'avatar_name': 'turtles1167', 'language': 'lithuanian', 'city': 'paris', 'date': 30}
# {'mobile': 1, 'avatar_name': 'turtles1167', 'language': 'lithuanian', 'city': 'paris', 'date': 18}
# {'mobile': 0, 'avatar_name': 'turtles1167', 'language': 'lithuanian', 'city': 'paris', 'date': 16}
# {'mobile': 1, 'avatar_name': 'turtles1167', 'language': 'lithuanian', 'city': 'paris', 'date': 13}
# {'mobile': 0, 'avatar_name': 'turtles1168', 'language': 'austrian', 'city': 'vienna', 'date': 35}
# {'mobile': 0, 'avatar_name': 'turtles1168', 'language': 'austrian', 'city': 'vienna', 'date': 8}
# {'mobile': 1, 'avatar_name': 'turtles1169', 'language': 'romanian', 'city': 'copenhagen', 'date': 8}
# {'mobile': 0, 'avatar_name': 'turtles1170', 'language': 'maltese', 'city': 'valletta', 'date': 33}
# {'mobile': 1, 'avatar_name': 'turtles1170', 'language': 'maltese', 'city': 'valletta', 'date': 22}
# {'mobile': 1, 'avatar_name': 'turtles1170', 'language': 'maltese', 'city': 'valletta', 'date': 10}

# %%
"""stock_df_final = request_to_final_df(stock_df)
stock_df_final.to_csv('results_requests/result20.csv', index=False)"""

# %%
#r2.json()
